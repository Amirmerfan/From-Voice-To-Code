# %%
# !pip install -q -U transformers datasets accelerate peft trl bitsandbytes scipy

# %%
import torch
import os
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel, get_peft_model, prepare_model_for_kbit_training
from trl import SFTTrainer

from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model_id = "google/gemma-3-12b-it"

new_model_name = "gemma-3-12b-it-small-json"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
eos_token = tokenizer.eos_token

print(f"EOS Token: {eos_token}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# EOS Token: <eos>

# %%
print(f"Sample Data Point (check EOS):\n{train_dataset[0]['formatted_text']}")
# Out:
# Sample Data Point (check EOS):
# Convert the following food order into JSON format using this structure:
# [
#   { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
#   { "customizations": [], "name": "Another Item" }
# ]:
# Get me a lemonade, a lemon meringue pie, and add extra toppings of chocolate chips, berries, and nuts.
# [{"customizations":[],"name":"Lemonade"},{"customizations":[],"name":"Lemon Meringue Pie"},{"customizations":["Chocolate Chips","Berries","Nuts"],"name":"Extra Topping"}]<eos>

# %%
import pandas as pd

df = train_dataset.to_pandas()
num_duplicates = df.duplicated().sum()
num_duplicates
# Out:
# np.int64(0)

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1200, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-small-clean-12k' (split: 'train')...
# README.md:   0%|          | 0.00/515 [00:00<?, ?B/s]
# train-00000-of-00010.parquet:   0%|          | 0.00/423M [00:00<?, ?B/s]
# train-00001-of-00010.parquet:   0%|          | 0.00/403M [00:00<?, ?B/s]
# train-00002-of-00010.parquet:   0%|          | 0.00/572M [00:00<?, ?B/s]
# train-00003-of-00010.parquet:   0%|          | 0.00/410M [00:00<?, ?B/s]
# train-00004-of-00010.parquet:   0%|          | 0.00/451M [00:00<?, ?B/s]
# train-00005-of-00010.parquet:   0%|          | 0.00/407M [00:00<?, ?B/s]
# train-00006-of-00010.parquet:   0%|          | 0.00/381M [00:00<?, ?B/s]
# train-00007-of-00010.parquet:   0%|          | 0.00/393M [00:00<?, ?B/s]
# train-00008-of-00010.parquet:   0%|          | 0.00/395M [00:00<?, ?B/s]
# train-00009-of-00010.parquet:   0%|          | 0.00/432M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/12000 [00:00<?, ? examples/s]
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1200
# })
# Splitting dataset into train and validation sets...
# Train set size: 1080
# Validation set size: 120
# Applying formatting function to the datasets...
# Map:   0%|          | 0/1080 [00:00<?, ? examples/s]
# Map:   0%|          | 0/120 [00:00<?, ? examples/s]
# Dataset formatting complete.
# Train dataset features: {'formatted_text': Value(dtype='string', id=None)}
# Validation dataset features: {'formatted_text': Value(dtype='string', id=None)}

# %%
validation_data
# Out:
# Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 120
# })

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=False,
)

if torch.cuda.is_available() and torch.cuda.get_device_capability()[0] >= 8:
    print("GPU supports bfloat16, using torch.bfloat16")
    compute_dtype = torch.bfloat16
else:
    print("GPU does not support bfloat16, using torch.float16")
    compute_dtype = torch.float16
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_use_double_quant=False,
    )

print("BitsAndBytesConfig configured.")
# Out:
# GPU supports bfloat16, using torch.bfloat16
# BitsAndBytesConfig configured.

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto",
)

model = prepare_model_for_kbit_training(model)

print("Base model loaded and prepared for k-bit training.")
print(model)
# Out:
# config.json:   0%|          | 0.00/916 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/109k [00:00<?, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/4.60G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded and prepared for k-bit training.
# Gemma3ForConditionalGeneration(
#   (vision_tower): SiglipVisionModel(
#     (vision_model): SiglipVisionTransformer(
#       (embeddings): SiglipVisionEmbeddings(
#         (patch_embedding): Conv2d(3, 1152, kernel_size=(14, 14), stride=(14, 14), padding=valid)
#         (position_embedding): Embedding(4096, 1152)
#       )
#       (encoder): SiglipEncoder(
#         (layers): ModuleList(
#           (0-26): 27 x SiglipEncoderLayer(
#             (layer_norm1): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#             (self_attn): SiglipAttention(
#               (k_proj): Linear4bit(in_features=1152, out_features=1152, bias=True)
#               (v_proj): Linear4bit(in_features=1152, out_features=1152, bias=True)
#               (q_proj): Linear4bit(in_features=1152, out_features=1152, bias=True)
#               (out_proj): Linear4bit(in_features=1152, out_features=1152, bias=True)
#             )
#             (layer_norm2): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#             (mlp): SiglipMLP(
#               (activation_fn): PytorchGELUTanh()
#               (fc1): Linear4bit(in_features=1152, out_features=4304, bias=True)
#               (fc2): Linear4bit(in_features=4304, out_features=1152, bias=True)
#             )
#           )
#         )
#       )
#       (post_layernorm): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#     )
#   )
#   (multi_modal_projector): Gemma3MultiModalProjector(
#     (mm_soft_emb_norm): Gemma3RMSNorm((1152,), eps=1e-06)
#     (avg_pool): AvgPool2d(kernel_size=4, stride=4, padding=0)
#   )
#   (language_model): Gemma3ForCausalLM(
#     (model): Gemma3TextModel(
#       (embed_tokens): Gemma3TextScaledWordEmbedding(262208, 3840, padding_idx=0)
#       (layers): ModuleList(
#         (0-47): 48 x Gemma3DecoderLayer(
#           (self_attn): Gemma3Attention(
#             (q_proj): Linear4bit(in_features=3840, out_features=4096, bias=False)
#             (k_proj): Linear4bit(in_features=3840, out_features=2048, bias=False)
#             (v_proj): Linear4bit(in_features=3840, out_features=2048, bias=False)
#             (o_proj): Linear4bit(in_features=4096, out_features=3840, bias=False)
#             (q_norm): Gemma3RMSNorm((256,), eps=1e-06)
#             (k_norm): Gemma3RMSNorm((256,), eps=1e-06)
#           )
#           (mlp): Gemma3MLP(
#             (gate_proj): Linear4bit(in_features=3840, out_features=15360, bias=False)
#             (up_proj): Linear4bit(in_features=3840, out_features=15360, bias=False)
#             (down_proj): Linear4bit(in_features=15360, out_features=3840, bias=False)
#             (act_fn): PytorchGELUTanh()
#           )
#           (input_layernorm): Gemma3RMSNorm((3840,), eps=1e-06)
#           (post_attention_layernorm): Gemma3RMSNorm((3840,), eps=1e-06)
#           (pre_feedforward_layernorm): Gemma3RMSNorm((3840,), eps=1e-06)
#           (post_feedforward_layernorm): Gemma3RMSNorm((3840,), eps=1e-06)
#         )
#       )
#       (norm): Gemma3RMSNorm((3840,), eps=1e-06)
#       (rotary_emb): Gemma3RotaryEmbedding()
#       (rotary_emb_local): Gemma3RotaryEmbedding()
#     )
#     (lm_head): Linear(in_features=3840, out_features=262208, bias=False)
#   )
# )

# %%
peft_config = LoraConfig(
    lora_alpha=128,
    lora_dropout=0.05,
    r=16,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],
)

# %%
training_arguments = TrainingArguments(
    output_dir=new_model_name,
    num_train_epochs=3,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    optim="paged_adamw_8bit",
    eval_strategy="steps",
    eval_steps=50,
    logging_steps=10,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=(compute_dtype==torch.float16),
    bf16=(compute_dtype==torch.bfloat16),
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",
    report_to="tensorboard",
    save_strategy="steps",
    save_steps=50,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
)


from trl import SFTConfig

sft_config = SFTConfig(
    output_dir=new_model_name,
    num_train_epochs=3,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    optim="paged_adamw_8bit",
    eval_strategy="steps",
    eval_steps=50,
    logging_steps=10,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=(compute_dtype==torch.float16),
    bf16=(compute_dtype==torch.bfloat16),
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",
    report_to="tensorboard",
    save_strategy="steps",
    save_steps=50,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    max_seq_length=1024,
    packing=False,
    dataset_text_field="formatted_text",
    push_to_hub=True,
    hub_model_id=f"iTzMiNOS/{new_model_name}",
)


print("SFTConfig configured.")
# Out:
# SFTConfig configured.

# %%
if 'train_dataset' not in globals() or 'validation_dataset' not in globals() or train_dataset is None or validation_dataset is None:
     raise ValueError("Training or Validation dataset not found or not processed. Please ensure Cell 4 ran correctly after loading the tokenizer.")
if 'model' not in globals():
      raise ValueError("Model not loaded.")
if 'tokenizer' not in globals():
      raise ValueError("Tokenizer not loaded.")
if 'sft_config' not in globals():
      raise ValueError("SFTConfig not defined.")
if 'peft_config' not in globals():
      raise ValueError("peft_config not defined.")

tokenizer.chat_template = None
print("Attempting SFTTrainer initialization using SFTConfig...")
try:
    trainer = SFTTrainer(
        model=model,
        args=sft_config,
        train_dataset=train_dataset,
        eval_dataset=validation_dataset,
        peft_config=peft_config,
        processing_class=tokenizer,
    )
    print("SFTTrainer initialized successfully using SFTConfig!")

except TypeError as e:
    print(f"SFTTrainer STILL FAILED with TypeError: {e}")
    print("Check if 'tokenizer' is now the unexpected argument.")
except Exception as e:
    print(f"SFTTrainer FAILED with another error: {e}")
# Out:
# Attempting SFTTrainer initialization using SFTConfig...
# Converting train dataset to ChatML:   0%|          | 0/1080 [00:00<?, ? examples/s]
# Adding EOS to train dataset:   0%|          | 0/1080 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/1080 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/1080 [00:00<?, ? examples/s]
# Converting eval dataset to ChatML:   0%|          | 0/120 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/120 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/120 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/120 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# SFTTrainer initialized successfully using SFTConfig!

# %%
print("Starting fine-tuning...")
trainer.train()
print("Fine-tuning finished.")
# Out:
# Starting fine-tuning...
# It is strongly recommended to train Gemma3 models with the `eager` attention implementation instead of `sdpa`. Use `eager` with `AutoModelForCausalLM.from_pretrained('<path-to-checkpoint>', attn_implementation='eager')`.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='405' max='405' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [405/405 49:02, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.061900</td>
#       <td>0.268947</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.840200</td>
#       <td>0.285608</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.896200</td>
#       <td>0.251544</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.674600</td>
#       <td>0.256543</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.856100</td>
#       <td>0.219888</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.564800</td>
#       <td>0.234360</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.694600</td>
#       <td>0.217699</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.525200</td>
#       <td>0.217170</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Fine-tuning finished.

# %%
print(f"Saving fine-tuned adapters to ./{new_model_name}")
trainer.model.save_pretrained(new_model_name)
tokenizer.save_pretrained(new_model_name)
print("Adapters and tokenizer saved.")

# Optional: Clean up memory
# del model
# del trainer
# torch.cuda.empty_cache()
# Out:
# Saving fine-tuned adapters to ./gemma-3-12b-it-small-json
# Adapters and tokenizer saved.

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-small-json"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=150, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-small-json) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/274M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 8/8 [11:13<00:00, 84.20s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9823
# ✅ Exact Match Accuracy: 80.83%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                               items                                                                                                                                                                                                                                    predicted_items  similarity
# 21   Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.  [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]  [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.695652
# 24                                                                      Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                              [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                              [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Milk', 'Almond Milk', 'Oat Milk'], 'name': 'Extra Milk'}]    0.722433
# 41                                                                  Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                           [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                        [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Extra Ice Cream Scoop'], 'name': 'Ice Cream'}]    0.747664
# 107                                                                                                   I'd like a cheesecake and an apple pie.                                                                                                                                                                                         [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                               [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.760181

# %%
df.head(5)
# Out:
#                                     transcribed_text   speaker  \
# 0  I'll have some chicken and vegetarian spring r...  af_bella
# 1  Please order a chocolate cake, an apple pie, a...  af_bella
# 2  Please add extra ranch dipping sauce, extra ch...  af_bella
# 3  Can I get a lemonade, a chocolate, and extra w...  af_bella
# 4  I'll have a bottle of red wine, a slice of che...  af_bella
#
#                                                items  \
# 0  [{'customizations': ['Chicken', 'Vegetarian'],...
# 1  [{'customizations': [], 'name': 'Chocolate Cak...
# 2  [{'customizations': ['Ranch'], 'name': 'Extra ...
# 3  [{'customizations': [], 'name': 'Lemonade'}, {...
# 4  [{'customizations': ['Red'], 'name': 'Wine'}, ...
#
#                                      predicted_items  similarity  exact_match
# 0  [{'customizations': ['Chicken', 'Vegetarian'],...         1.0         True
# 1  [{'customizations': [], 'name': 'Chocolate Cak...         1.0         True
# 2  [{'customizations': ['Ranch'], 'name': 'Extra ...         1.0         True
# 3  [{'customizations': [], 'name': 'Lemonade'}, {...         1.0         True
# 4  [{'customizations': ['Red'], 'name': 'Wine'}, ...         1.0         True

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-medium-clean-18k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1800, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-medium-clean-18k' (split: 'train')...
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/24 [00:00<?, ?it/s]
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1800
# })
# Splitting dataset into train and validation sets...
# Train set size: 1620
# Validation set size: 180
# Applying formatting function to the datasets...
# Map:   0%|          | 0/1620 [00:00<?, ? examples/s]
# Map:   0%|          | 0/180 [00:00<?, ? examples/s]
# Dataset formatting complete.
# Train dataset features: {'formatted_text': Value(dtype='string', id=None)}
# Validation dataset features: {'formatted_text': Value(dtype='string', id=None)}

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-small-json"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=150, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00002-of-00005.safetensors:  84%|########3 | 4.14G/4.93G [00:00<?, ?B/s]
# model-00001-of-00005.safetensors:  80%|#######9  | 3.98G/4.98G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:  84%|########3 | 4.14G/4.93G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:  83%|########3 | 4.10G/4.93G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:  91%|#########1| 4.20G/4.60G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-small-json) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/274M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 12/12 [19:07<00:00, 95.62s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8160
# ✅ Exact Match Accuracy: 48.33%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                            transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     items                                                                                                                                                                                                                                                                                                                                                                                                                                               predicted_items  similarity
# 3                                                                                      One vegan burger with vegan mayo, a mix of Sprite and Fanta for soft drinks, both sweetened and unsweetened iced tea, a scoop of mint chocolate chip ice cream, and an extra side with veggies, fries, and rice. Also, please add BBQ sauce and extra whipped cream.                                                                                                        [{'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Veggies', 'Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 23                                                                                                                                                                                                                       I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                                                                                                                [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                        [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vanilla'], 'name': 'Ice Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.783362
# 24                                                                                        I'll have a miso soup with chili oil and toasted sesame seeds, a garden salad with balsamic and ranch, a sweetened iced tea, a lager craft beer, cocktails including an old fashioned and a mojito, a cheesecake, and extra toppings of nuts and chocolate chips.                                                                                             [{'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 41   Ordering tomato soup with cheddar cheese, cream of mushroom with truffle oil and chopped parsley, spicy coleslaw, a vegan burger with vegan mayo, ketchup, no cheese, mustard, and vegan cheese, plus soft drinks including Sprite, Coke, and Fanta, craft beer options of pale ale, lager, and IPA, and an extra side of mashed potatoes and veggies.  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Mustard', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 43                                                        Can I get a Garden Salad with vinaigrette, a Grilled Salmon topped with lemon dill and garlic butter, a Shrimp Cocktail with spicy cocktail sauce, Fish and Chips with onion rings and extra crispy, Grilled Tofu with chili lime, a slice of Lemon Meringue Pie, and an extra bun or bread roll?                                                                               [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 47                                                                 Ordering a Chicken Soup with fresh parsley, mozzarella sticks with ranch and marinara, a grilled chicken breast with BBQ sauce, fresh orange juice, and a selection of cocktails including a margarita, old fashioned, and mojito. Also, adding an extra bun and some gravy on the side.                                                                                        [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 55                   I'll take a Caesar Salad with grilled chicken, a Greek Salad with falafel, some BBQ spicy Buffalo chicken wings, a Shrimp Cocktail with lemon herb and spicy cocktail sauce, three cocktails: an Old Fashioned, a Mojito, and a Margarita. For dessert, I'll go with a slice of chocolate cake and some mint chocolate chip ice cream.                                              [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Old Fashioned', 'Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 56                                                                                                                               I'll have the chicken soup with fresh parsley and a lemon wedge, spring rolls with chicken, fish and chips with fries and crispy onion rings, a lemonade, a chocolate cake, a chocolate, and flavored syrups with vanilla.                                                                                                                          [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                      [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken', 'Fish'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.284981
# 66                          Can I get a Caesar Salad with grilled shrimp, a vegetable stir-fry with garlic soy and teriyaki, grilled tofu with soy ginger, peanut sauce, and chili lime, a selection of cocktails including an Old Fashioned, Margarita, and Mojito, along with cheesecake, chocolate, and some milk alternatives like almond and oat milk?                                                      [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Old Fashioned', 'Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 75         I'll have a Garden Salad with vinaigrette, balsamic, and ranch, a Vegan Burger with vegan mayo, ketchup, no cheese, and vegan cheese. For drinks, I'll take an Old Fashioned and a Mojito. For dessert, I'd like a cheesecake, and I'll finish off with some flavored syrups in vanilla and caramel. Also, add an extra shot of rum and whiskey.                                                                                                [{'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 81                                             I want a Garden Salad with Balsamic, Ranch, and Vinaigrette, a Vegetable Stir-fry with Teriyaki, Peanut Sauce, and Garlic Soy, a Vegan Burger with Ketchup, Mustard, no cheese, Vegan Mayo, and Vegan Cheese, Grilled Tofu with Soy Ginger, Peanut Sauce, and Chili Lime, and a flavored syrup with Vanilla.                                                                                                     [{'customizations': ['Balsamic', 'Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Teriyaki', 'Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'No Cheese', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 86                                                                                  I'll have spring rolls with chicken and vegetarian, mozzarella sticks with ranch and marinara, grilled tofu with chili lime and peanut sauce, a lemonade, a slice of lemon meringue pie, extra whipped cream, and extra toppings of nuts, chocolate chips, and berries.                                                                                 [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 90                                                                                    I want to order Chicken Soup with a lemon wedge and fresh parsley, Mozzarella Sticks with marinara and ranch, Onion Rings with BBQ and ranch, a craft beer with lager and IPA, an apple pie, a fruit salad, and some extra dipping sauces with ranch and blue cheese.                                                                                                  [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 100                                                                             I'll have coleslaw with mild dressing, vegetarian spring rolls, grilled salmon with garlic butter and lemon dill, shrimp cocktail with spicy cocktail sauce and lemon herb, a side of fruit salad, an extra bun, and an extra shot of alcohol with whiskey, rum, and vodka.                                                                                [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 103                                                                                                Miso Soup with toasted sesame seeds, spicy chicken wings with BBQ and buffalo sauce, grilled salmon with lemon dill, an extra bread roll, mashed potatoes as an extra side, flavored syrups in caramel and vanilla, and oat milk as my milk alternative.                                                                               [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 106                                                                                         Grilled chicken breast with BBQ sauce, vegetable stir-fry with garlic soy, peanut sauce, and teriyaki, a vegan burger with vegan mayo, mint chocolate chip ice cream, extra blue cheese dipping sauce, extra whipped cream, and toppings with berries and nuts.                                                                             [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 108                                            Ordering a Garden Salad with balsamic vinaigrette, some spicy buffalo and BBQ chicken wings, grilled salmon with garlic butter, soft drinks including Sprite, Fanta, and Coke, cocktails with a mix of margarita, old fashioned, and mojito, a glass of white wine, and finishing off with a chocolate cake.                                                                          [{'customizations': ['Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 114                                                                                    Grilled Chicken Breast with garlic butter, vegetable stir-fry with garlic soy and peanut sauce, fruit salad, extra dipping sauces of ranch and blue cheese, extra whipped cream, extra toppings of chocolate chips, nuts, and berries, and an extra shot of whiskey.                                                     [{'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 116                                 Ordering the spicy coleslaw and onion rings with ranch. I'll also have the vegetable stir-fry with garlic soy and peanut sauce, a pale ale craft beer, and mint chocolate chip for dessert. For sides, please include fries, veggies, rice, and mashed potatoes, and don't forget the extra topping of chocolate chips.                                                                           [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Fries', 'Veggies', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 117                                                            Ordering a Caesar Salad with grilled shrimp and no protein, some chicken and vegetarian spring rolls, a selection of craft beer including IPA, lager, and pale ale, an apple pie for dessert, extra cheese, an extra bun or bread roll, and extra toppings with berries and chocolate chips.                                                                                        [{'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 126                                                                            I'll have the Chicken Soup with a lemon wedge, a Greek Salad without any protein, Fish and Chips with crispy onion rings and extra crispy fries, Grilled Tofu with chili lime, an Apple Pie, a Berry Parfait, and some milk alternatives including oat milk and almond milk.                                                                                        [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy Onion Rings', 'Extra Crispy Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.410072
# 128                                                                                                                                                      Miso soup with chili oil, onion rings with BBQ and ranch, a glass of lemonade, fresh juices with apple and orange, rose and red wine, an extra bun, and an extra side of fries, veggies, and rice.                                                                                                                                [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Fries', 'Veggies', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 135            Ordering a bowl of Tomato Soup with cheddar cheese, croutons, and basil pesto, a Chicken Soup with fresh parsley and a lemon wedge, a Miso Soup topped with toasted sesame seeds and chili oil, a Shrimp Cocktail with lemon herb and spicy cocktail sauce, a refreshing lemonade, an extra bread roll, and a side of oat milk for my drink.                                           [{'customizations': ['Cheddar Cheese', 'Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 144                                                                                              Miso soup with chili oil and toasted sesame seeds, onion rings with ranch and BBQ, fish and chips with fries, extra crispy, onion rings, and crispy, craft beer with pale ale and lager, berry parfait, extra blue cheese dipping sauce, and extra cheese.                                                                     [{'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Fries', 'Extra Crispy', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 146                                                                       Ordering a cream of mushroom soup with chopped parsley and truffle oil, a Caesar salad with grilled chicken and grilled shrimp, vegetable stir-fry with teriyaki, garlic soy, and peanut sauce, chocolate dessert, strawberry dessert, berry parfait, and an extra side of fries.                               [{'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Teriyaki', 'Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Veggies', 'Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 151                                                                          I'm ordering a tomato soup with croutons, a chicken soup with a lemon wedge and fresh parsley, onion rings with ranch and BBQ, shrimp cocktail with lemon herb and spicy cocktail sauce, a vanilla ice cream, a strawberry ice cream, and an extra topping of chocolate chips.                                                                                                          [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 156                                        Get me a Cream of Mushroom with truffle oil, a grilled salmon with garlic butter, a vegetable stir-fry with peanut sauce, and a vegan burger with ketchup, no cheese, vegan mayo, and vegan cheese. For dessert, I'll have strawberry and mint chocolate chip, and add an extra shot of vodka, rum, and whiskey.                                                        [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'No Cheese', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 157                                                    Can I get some spicy BBQ chicken wings, a sweetened iced tea, a fresh juice blend with orange, carrot, and apple, a craft beer selection of pale ale, IPA, and lager, a slice of lemon meringue pie, a scoop of mint chocolate chip ice cream, and an extra shot of vodka, rum, and whiskey? Thanks!                                                                                  [{'customizations': ['Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Orange', 'Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 160                                                                I'll have some chicken wings with BBQ, spicy, and buffalo sauce, a grilled salmon with lemon dill, a vegetable stir-fry with teriyaki sauce, and a berry parfait. Also, please add extra cheese, extra BBQ sauce, and pesto for sauces, and a bit of extra whipped cream on the parfait.                                                                                                      [{'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 167                                                        I want a Greek Salad with grilled chicken and falafel, a mild and spicy coleslaw, chicken and vegetarian spring rolls, a shrimp cocktail with lemon herb and spicy cocktail sauce, a slice of lemon meringue pie, an apple crumble, and some extra sauces including gravy, BBQ sauce, and pesto.                                                           [{'customizations': ['No Protein', 'Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Gravy', 'BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 169                                                                                             Spring Rolls with vegetarian filling, Grilled Salmon with garlic butter and lemon dill, Shrimp Cocktail with lemon herb, Fish and Chips with fries and onion rings, extra crispy and crispy, a slice of Lemon Meringue Pie, a Strawberry, and extra cheese.                                                                                          [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Fries', 'Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 170                      I'll have a Tomato Soup with croutons, cheddar cheese, and basil pesto, a Chicken Soup with fresh parsley, a Grilled Salmon with garlic butter and lemon dill, Fish and Chips extra crispy with fries, crispy onion rings, and some soft drinks including Coke, Sprite, and Fanta. Also add almond milk for the milk alternatives.                                                                      [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          None    0.000000
# 178                                                                                                                                                                                                            Caesar Salad with grilled chicken but no protein, Fish and chips extra crispy with crispy fries, Apple pie, Berry parfait, and extra cheese.                                                                                                                                                                                                                                          [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                 [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Crispy Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.409253

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-large-clean-12k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1200, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-small-json"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=150, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/tqdm/contrib/concurrent.py in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      50                           initargs=(lk,)) as ex:
# ---> 51             return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#      52
#
# /usr/local/lib/python3.11/dist-packages/tqdm/notebook.py in __iter__(self)
#     249             it = super().__iter__()
# --> 250             for obj in it:
#     251                 # return super(tqdm...) will not catch exception
#
# /usr/local/lib/python3.11/dist-packages/tqdm/std.py in __iter__(self)
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result_iterator()
#     618                     if timeout is None:
# --> 619                         yield _result_or_cancel(fs.pop())
#     620                     else:
#
# /usr/lib/python3.11/concurrent/futures/_base.py in _result_or_cancel(***failed resolving arguments***)
#     316         try:
# --> 317             return fut.result(timeout)
#     318         finally:
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     326             if timeout is None:
# --> 327                 waiter.acquire()
#     328                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-da22bea22983> in <cell line: 0>()
#      70 # --- Load Base Model with Quantization ---
#      71 print(f"Loading base model ({base_model_id}) with quantization...")
# ---> 72 model = AutoModelForCausalLM.from_pretrained(
#      73     base_model_id,
#      74     quantization_config=bnb_config,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569             if model_class.config_class == config.sub_configs.get("text_config", None):
#     570                 config = config.get_text_config()
# --> 571             return model_class.from_pretrained(
#     572                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in _wrapper(*args, **kwargs)
#     277         old_dtype = torch.get_default_dtype()
#     278         try:
# --> 279             return func(*args, **kwargs)
#     280         finally:
#     281             torch.set_default_dtype(old_dtype)
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4258             )
#    4259
# -> 4260         checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4261             pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4262             subfolder=subfolder,
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash)
#    1150     sharded_metadata = None
#    1151     if is_sharded:
# -> 1152         checkpoint_files, sharded_metadata = get_checkpoint_shard_files(
#    1153             pretrained_model_name_or_path,
#    1154             resolved_archive_file,
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1113     # At this stage pretrained_model_name_or_path is a model identifier on the Hub. Try to get everything from cache,
#    1114     # or download the files
# -> 1115     cached_filenames = cached_files(
#    1116         pretrained_model_name_or_path,
#    1117         shard_filenames,
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     437             )
#     438         else:
# --> 439             snapshot_download(
#     440                 path_or_repo_id,
#     441                 allow_patterns=full_filenames,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/_snapshot_download.py in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     294             _inner_hf_hub_download(file)
#     295     else:
# --> 296         thread_map(
#     297             _inner_hf_hub_download,
#     298             filtered_repo_files,
#
# /usr/local/lib/python3.11/dist-packages/tqdm/contrib/concurrent.py in thread_map(fn, *iterables, **tqdm_kwargs)
#      67     """
#      68     from concurrent.futures import ThreadPoolExecutor
# ---> 69     return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#      70
#      71
#
# /usr/local/lib/python3.11/dist-packages/tqdm/contrib/concurrent.py in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47     with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48         # share lock in case workers are already using `tqdm`
# ---> 49         with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                           initargs=(lk,)) as ex:
#      51             return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     645
#     646     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647         self.shutdown(wait=True)
#     648         return False
#     649
#
# /usr/lib/python3.11/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.11/threading.py in join(self, timeout)
#    1117
#    1118         if timeout is None:
# -> 1119             self._wait_for_tstate_lock()
#    1120         else:
#    1121             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.11/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1137
#    1138         try:
# -> 1139             if lock.acquire(block, timeout):
#    1140                 lock.release()
#    1141                 self._stop()
#
# KeyboardInterrupt:
