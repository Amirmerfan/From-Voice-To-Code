# %%
# !pip install -q -U transformers datasets accelerate peft trl bitsandbytes scipy

# %%
import torch
import os
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel, get_peft_model, prepare_model_for_kbit_training
from trl import SFTTrainer

from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# # **Load Small Dataset**

# %%
model_id = "google/gemma-3-1b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
eos_token = tokenizer.eos_token

print(f"EOS Token: {eos_token}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# EOS Token: <eos>

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1200, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-small-clean-12k' (split: 'train')...
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1200
# })
# Splitting dataset into train and validation sets...
# Train set size: 1080
# Validation set size: 120
# Applying formatting function to the datasets...
# Dataset formatting complete.
# Train dataset features: {'formatted_text': Value(dtype='string', id=None)}
# Validation dataset features: {'formatted_text': Value(dtype='string', id=None)}

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-small-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) with quantization...
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-small-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/52.2M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 8/8 [05:46<00:00, 43.37s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9216
# ✅ Exact Match Accuracy: 45.83%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                     transcribed_text                                                                                                                                                                                                                                                                                    items                                                                                                                                                                                                                                                                                                                                        predicted_items  similarity
# 2                                                                                Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]  [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Cheese'], 'name': 'Extra Cheese'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]    0.740594
# 3                                                                                                                                Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                         [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                            [{'customizations': ['Lemonade', 'Chocolate', 'Whipped Cream'], 'name': 'Drinks'}, {'customizations': ['Lemonade', 'Chocolate', 'Whipped Cream'], 'name': 'Extra Topping'}]    0.648464
# 6    Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                              [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                    [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Onion Rings', 'Ranch'], 'name': 'Side'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]    0.561151
# 21                                                          Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.       [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                      [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.695652
# 26                                                                                         Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                             [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                             [{'customizations': ['Extra Cheese', 'Flavored Syrups'], 'name': 'Pizza'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.418605
# 41                                                                                                                         Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                  [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Extra Ice Cream'], 'name': 'Ice Cream'}]    0.721154
# 55                                                       I'm ordering a Caesar Salad with no protein, a Fish and Chips that's crispy, Grilled Tofu with soy ginger, and an extra scoop of ice cream.         [{'customizations': ['No Protein', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                   [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.596273
# 61                                                                                                                      Caesar Salad with no protein, extra cheese, and an extra scoop of ice cream.                                                                                                                    [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                      [{'customizations': ['No Protein', 'Extra Cheese', 'Extra Ice Cream'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Something Else'}]    0.655172
# 66                                                                                                                                          Can I get a chocolate with extra chocolate chips on top?                                                                                                                                                                          [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                         [{'customizations': ['Chocolate', 'Extra Chocolate Chips'], 'name': 'Chocolate'}, {'customizations': ['Vanilla', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.648221
# 68                                   Just ordering a Caesar Salad without protein but with grilled shrimp and grilled chicken, a Grilled Salmon with garlic butter, and an extra scoop of ice cream.                                                              [{'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                          [{'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.518018
# 79                                                                                                  Can I get a vanilla with extra dipping sauce in blue cheese and some extra whipped cream on top?                                                                                                                   [{'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                 [{'customizations': ['Vanilla'], 'name': 'Extra Dipping Sauce in Blue Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.794326
# 107                                                                                                                                                          I'd like a cheesecake and an apple pie.                                                                                                                                                                                              [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                       [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vanilla'], 'name': 'Iced Tea'}]    0.774194
# 109                          Can I get some chicken spring rolls, grilled salmon with garlic butter and lemon dill, a spicy shrimp cocktail, and extra sauces including BBQ sauce, pesto, and gravy?  [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                            [{'customizations': ['Chicken', 'Grilled'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Salmon'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Shrimp Cocktail'}]    0.387097
# 110          Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                               [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                   [{'customizations': ['Chopped Parsley', 'Onion Rings', 'Grilled Salmon', 'IPA', 'Pale Ale'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ Sauce'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]    0.256705
# 112                                             Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                   [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Grilled Salmon'], 'name': 'Lemon Dill and Garlic Butter'}]    0.732394

# %% [markdown]
# ### **Medium 1b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-medium-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) with quantization...
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-medium-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/52.2M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches:  38%|███▊      | 3/8 [02:11<02:49, 33.90s/it]
# Warning: Could not parse JSON: Expecting ':' delimiter: line 1 column 268 (char 267).
# Attempted to parse (after extraction): '[{"customizations":["Toasted Sesame Seeds","Chili Oil"],"name":"Miso Soup"},{"customizations":[],"name":"Chocolate"},{"customizations":[],"name":"Strawberry"},{"customizations":[],"name":"Berry Parfait"},{"customizations":["Extra Berries"],"name":"Mashed Potatoes",""customizations":["Rice","Fries"],"name":"Mashed Potatoes"}]'
# Inference Batches: 100%|██████████| 8/8 [06:07<00:00, 45.98s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.6947
# ✅ Exact Match Accuracy: 6.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                     transcribed_text                                                                                                                                                                                                                                                                                         items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 predicted_items  similarity
# 0                                                                                       I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                         [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Vanilla'}]    0.790787
# 1                                                                                                                                  Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                              [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                        [{'customizations': ['Chocolate Cake', 'Apple Pie', 'Berry Parfait'], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vanilla', 'Strawberry'], 'name': 'Extra Ice Cream'}]    0.550725
# 2                                                                                Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                     [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vanilla'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.799145
# 3                                                                                                                                Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                              [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Lemonade', 'Chocolate', 'Extra Whipped Cream'], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternative'}]    0.608696
# 4                                                                                                           I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                       [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                       [{'customizations': ['Red Wine'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Syrups'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Craft Beer', 'IPA', 'Lager'], 'name': 'Drinks'}]    0.555085
# 5                                                                                                   Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                               [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                      [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Sauces'}, {'customizations': ['Rice', 'Mashed Potatoes'], 'name': 'Side'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.551938
# 6    Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                   [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.672158
# 8                                                                                                                                        Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                 [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None    0.000000
# 10                                                                             Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                      [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                     [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}]    0.702988
# 11                                                                                                                                       I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                        [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['White Wine', 'Mint Chocolate Chip'], 'name': 'White Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Nuts', 'Pecans', 'Walnuts', 'Almonds'], 'name': 'Extra Topping'}]    0.520548
# 12                                                                                                                                                  Could I get a pale ale and an extra bun, please?                                                                                                                                                           [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Pale Ale', 'Extra Bun'], 'name': 'Drink'}, {'customizations': ['Chicken', 'Vegetable'], 'name': 'Stir-fry'}, {'customizations': ['Teriyaki'], 'name': 'Dessert'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.496203
# 16                                                                                                                  Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                              [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Chicken', 'Spring Rolls'], 'name': 'Chicken Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Fresh Strawberries'}]    0.600000
# 18                                                                                               Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                          [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Syrups'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.525114
# 20                                                                           I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                    [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Grilled Chicken', 'Greek Salad'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ Sauce'], 'name': 'Chicken'}, {'customizations': ['Vanilla'], 'name': 'Drink'}]    0.742991
# 21                                                          Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.            [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.695652
# 22                                                                                                                      Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                            [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Apple Juice'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.687927
# 23                                                                                                                                           Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                       [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                       [{'customizations': ['Lemon Meringue Pie', 'Apple Crumble'], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.380952
# 24                                                                                                                             Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                        [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                 [{'customizations': ['Chocolate', 'Extra Ice Cream Scoop'], 'name': 'Chocolate Ice Cream'}, {'customizations': ['Lemon'], 'name': 'Lemon Ice Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.375286
# 25                                                                                                                                                Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                      [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                            [{'customizations': ['Ranch', 'Chocolate'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Mojito', 'Margarita', 'Red Wine'], 'name': 'Dessert'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple'}, {'customizations': [], 'name': 'Extra Topping'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.357274
# 26                                                                                         Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                  [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Extra Cheese', 'Flavored Syrups'], 'name': 'Pizza'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mint Chocolate Chip'], 'name': 'Ice Cream'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.370000
# 27                                                                                                  I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                               [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.698113
# 28                                                                         Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                        [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}]    0.635135
# 29                                                                                                    Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                       [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Chocolate Mint'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.745192
# 30                                                                          Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                  [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Craft Beer', 'Apple Juice'], 'name': 'Non-Alcoholic Drink'}, {'customizations': [], 'name': 'Whipped Cream'}, {'customizations': ['Caramel'], 'name': 'Extra Topping'}]    0.600000
# 31                                                                                    Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                     [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.603390
# 33                                                                   Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                            [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                            [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Veggies', 'Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}]    0.649606
# 34                                                                                      Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                                  [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Iced Tea'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.631579
# 37                                                    I'll have a Garden Salad with ranch, balsamic, and vinaigrette, some vegetarian Spring Rolls, and a Grilled Chicken Breast with garlic butter.                                                                       [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                                                                                                                                                                            [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Fresh Fruit Salad'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]    0.437383
# 39                                                                      Can I get an order of Mozzarella Sticks with Ranch and Marinara, a Vegetable Stir-fry with Peanut Sauce, and some Chocolate?                                                                                                     [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.768889
# 40                                                                                       Can I get some spicy coleslaw, buffalo chicken wings with a spicy kick, and an extra shot of vodka, please?                                                                                                [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.662921
# 41                                                                                                                         Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                                     [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                              [{'customizations': ['Extra Cheese', 'Ice Cream', 'Extra Scoop'], 'name': 'Pizza'}, {'customizations': ['Apple Juice', 'Vanilla Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vodka', 'Whiskey'], 'name': 'Extra Shot'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Lemon'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.367347
# 43                                                                                               Can I get a miso soup with toasted sesame seeds and chili oil, and a chocolate on the side, please?                                                                                                                                                                 [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None    0.000000
# 44                                                                                  Can I get a Chicken Soup with a lemon wedge and a Cream of Mushroom topped with chopped parsley and truffle oil?                                                                                                                                            [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}]                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Lemon Wedge', 'Cream of Mushroom'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra BBQ Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.611973
# 47                                                                                                                                                    Can I get a vanilla and a fruit salad? Thanks!                                                                                                                                                                                                    [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Vanilla', 'Fruit Salad'], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple'}]    0.537217
# 49                                                         Can I get some mozzarella sticks with marinara, a slice of chocolate cake, some strawberries, and flavored syrups in vanilla and caramel?                                                        [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                               [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.784530
# 51                                                                                                                   Can I get some mozzarella sticks with marinara sauce and a glass of white wine?                                                                                                                                                                                [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Marinara', 'White Wine'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Rice', 'BBQ Sauce'], 'name': 'Extra Side'}, {'customizations': ['BBQ Sauce', 'Extra Topping', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.588589
# 53                                                                          Getting a mix of craft beer including IPA, pale ale, and lager along with some wine options, specifically rosÃ© and red.                                                                                                                                                                 [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                              [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Side Dish'}, {'customizations': ['Mashed Potatoes', 'Broccoli', 'Carrot'], 'name': 'Extra Side'}]    0.521542
# 56                              Cream of Mushroom with truffle oil and chopped parsley, Caesar salad with grilled shrimp, no protein, and grilled chicken, vegan burger with no cheese, and vanilla.  [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['No Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Vegan Burger'}, {'customizations': ['No Cheese'], 'name': 'Vanilla'}]    0.790960
# 57                                                                             I'll go with mozzarella sticks with ranch, an apple pie, and some extra sauces including gravy, pesto, and BBQ sauce.                                                                                                         [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Chili Lime', 'Garlic Butter'], 'name': 'Spicy Topping'}, {'customizations': [], 'name': 'Vanilla'}]    0.750000
# ...
# 102                                   I'll have a Vegetable Stir-fry with Garlic Soy, Peanut Sauce, and Teriyaki, a Vegan Burger with Mustard, no cheese, vegan cheese, and Ketchup, and a Lemonade.                                                   [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}]                                                                                                                                                                                                                                                                     [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.744027
# 103                                                                                                                         One chocolate cake, one apple pie, and some extra whipped cream, please.                                                                                                                                        [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                             [{'customizations': ['Chocolate Cake', 'Apple Pie'], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Mashed Potatoes', 'Carrots', 'Fries'], 'name': 'Side Dish'}]    0.557114
# 104                                                                                                                  I'm ordering a fruit salad and an extra sauce with pesto, BBQ sauce, and gravy.                                                                                                                                                                   [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Fruit Salad'], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.674556
# 105                                                                                         Order a Greek Salad with grilled chicken but no additional protein, and a mint chocolate chip ice cream.                                                                                                                                                         [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.551724
# 106                                                                                                Can I get a fresh orange juice, an extra side of mashed potatoes and fries, and some almond milk?                                                                                            [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Orange Juice'], 'name': 'Fresh Orange Juice'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Almond Milk'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.752174
# 107                                                                                                                                                          I'd like a cheesecake and an apple pie.                                                                                                                                                                                                   [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Cheesecake', 'Apple Pie'], 'name': 'Cheesecake'}, {'customizations': ['Apple Pie'], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]    0.464088
# 108                                                                                Ordering a Vegetable Stir-fry with peanut sauce and garlic soy, a chocolate cake, and an extra gravy on the side.                                                                                                    [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Gravy'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.747300
# 112                                             Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                        [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                                                         [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Extra Shot of Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.556213
# 113                                                                                                    I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                    [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                               [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Craft Beer'], 'name': 'Iced Tea'}, {'customizations': ['Iced Tea'], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.579235
# 114                                              I want an order of Chicken Wings with BBQ and Spicy sauce, a slice of Cheesecake, a Chocolate treat, and some Extra Dipping Sauce with Blue Cheese.                                                                [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                     [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Dipping Sauce with Blue Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.718336
# 115                                                                                                                          Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                         [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Vinaigrette', 'Spicy'], 'name': 'Garden Salad'}, {'customizations': ['Fries', 'Crispy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.500000
# 116                                                                              Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                 [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.731377
# 118                                                                                I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                             [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Fresh Parsley', 'Extra Shot of Alcohol', 'Whiskey', 'Vodka', 'Rum'], 'name': 'Chicken Soup'}, {'customizations': ['Marinara Sauce', 'Spicy Chicken Wings'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}]    0.511628

# %% [markdown]
# ### **Large 1b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-large-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) with quantization...
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-large-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/52.2M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 8/8 [05:08<00:00, 38.57s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.5369
# ✅ Exact Match Accuracy: 1.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                                                       items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     predicted_items  similarity
# 0                                                                                                                I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                               [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo', 'Chicken'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Side'}, {'customizations': ['Grilled Chicken', 'No Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Strawberry', 'Chocolate'], 'name': 'Dessert'}, {'customizations': ['Vanilla', 'Lemonade', 'Mojito'], 'name': 'Drinks'}]    0.366522
# 1                                                                                                                                                           Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                            [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                             [{'customizations': ['Chocolate Cake', 'Apple Pie', 'Berry Parfait', 'Nuts', 'Chocolate Chips'], 'name': 'Dessert'}, {'customizations': [], 'name': 'Apple Juice'}, {'customizations': ['Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.178707
# 2                                                                                                         Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                                   [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Cider'}]    0.717850
# 3                                                                                                                                                         Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                            [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                              [{'customizations': ['Lemonade', 'Chocolate', 'Extra Whipped Cream'], 'name': 'Dessert'}, {'customizations': ['BBQ Sauce', 'Onion Rings', 'Chicken Salad', 'Vegetarian Rolls'], 'name': 'Chicken Wraps'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Nuts'}, {'customizations': ['Mashed Potatoes', 'Nuts'], 'name': 'Appetizer'}]    0.447059
# 4                                                                                                                                    I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                                     [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                  [{'customizations': ['Red Wine', 'White Wine', 'Rose Wine'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Spicy Chicken', 'BBQ Chicken'], 'name': 'Appetizer'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Grilled Chicken Breast', 'Garlic Butter'], 'name': 'Main Course'}, {'customizations': ['Ranch Dressing'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]    0.381093
# 5                                                                                                                            Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                                                                                                                                      [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Strawberry Lemonade'}, {'customizations': ['Strawberry', 'Orange'], 'name': 'Juice'}]    0.633452
# 6                             Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                          [{'customizations': ['Cream of Mushroom', 'Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Onion Rings', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Red Wine'], 'name': 'Wine'}]    0.672630
# 7                       Can I get a Garden Salad with Ranch, a dozen Spicy Buffalo BBQ Chicken Wings, Fish and Chips with crispy batter and onion rings on the side, and a Craft Beer with a mix of Lager, IPA, and Pale Ale?                          [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy Buffalo BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Side'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}]    0.783034
# 8                                                                                                                                                                 Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                               [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                  [{'customizations': ['Truffle Oil', 'Extra Bun'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies'], 'name': 'Side Dishes'}, {'customizations': ['No Protein', 'Protein', 'Greek Salad'], 'name': 'Chicken Salad'}, {'customizations': ['Croutons', 'Basil'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]    0.395644
# 9                                       Hey, can I get some mozzarella sticks with marinara and ranch, fish and chips with extra crispy fries, an extra topping of chocolate chips and berries, and a drink with almond milk?  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                      [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Pie'}]    0.767647
# 10                                                                                                      Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                                    [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['No Cheese', 'Butter'], 'name': 'Muffuletta'}]    0.787402
# 11                                                                                                                                                                I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                                      [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                None    0.000000
# 12                                                                                                                                                                           Could I get a pale ale and an extra bun, please?                                                                                                                                                                         [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Pale Ale', 'Extra Bun'], 'name': 'Drink'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Ranch', 'Bacon'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.464865
# 13                                                                                                 Can I get a Garden Salad with vinaigrette and ranch, a spicy order of chicken wings, a chocolate cake, and some chocolate?                                                                               [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                 [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Apple', 'Apple'], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake with Berries'}]    0.638498
# 14                                                                                                    Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}]    0.745455
# 15                                                    Ordering a Tomato Soup with Cheddar Cheese, a Caesar Salad topped with Grilled Shrimp and Grilled Chicken, a slice of Chocolate Cake, and a scoop of Vanilla ice cream.                                                             [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                   [{'customizations': ['Tomato Soup', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Vanilla'], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Spicy Chicken Wings'], 'name': 'Chicken Wings'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Cheesecake'}]    0.430199
# 16                                                                                                                                           Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]      [{'customizations': ['Chicken', 'Spring Rolls'], 'name': 'Chicken Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['None', 'Salt', 'Pepper'], 'name': 'Vanilla'}, {'customizations': ['Vanilla', 'Caramel', 'Chocolate'], 'name': 'Flavored Syrups'}, {'customizations': ['Chocolate Chip', 'Double Chocolate Chip'], 'name': 'Extra Chocolate Chips'}, {'customizations': ['None', 'Extra Cheese'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Chicken', 'Vegetarian', 'Lamb'], 'name': 'Chicken Wraps'}, {'customizations': ['Extra Cheese'], 'name': 'Fajitas'}, {'customizations': ['Butter', 'Basil', 'Rosemary'], 'name': 'Lemonade'}]    0.288066
# 17                                                                                              Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                                                     [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Grilled Chicken', 'Grilled Chicken Breast', 'BBQ', 'Garlic Butter'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Juice'}]    0.617647
# 18                                                                                                                        Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                          [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Mashed Potatoes'], 'name': 'Gravy'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Cheese'], 'name': 'Extra Cheese'}]    0.379786
# 19                                                    Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                                              [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                            [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'name': 'Extra Spicy'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Topping'}, {'customizations': ['Grilled Chicken Breast', 'Garlic Butter'], 'name': 'Side Dish'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Side Dish'}]    0.635659
# 20                                                                                                    I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                                  [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                    [{'customizations': ['Grilled Chicken', 'Greek Salad'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic', 'Garden Salad'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Marinara Sauce'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Rice Pudding'}, {'customizations': ['Coconut Milk', 'Vanilla'], 'name': 'Rice Pudding with Coconut Milk and Vanilla'}]    0.486983
# 21                                                                                   Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.                          [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Grilled Shrimp', 'Greek Salad', 'Apple Pie', 'Blue Cheese'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Apple Crumble'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple,'}]    0.263918
# 22                                                                                                                                               Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                                          [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                   [{'customizations': ['Apple Juice', 'Extra Cheese', 'Extra Bun or Bread Roll', 'Chicken Wings', 'BBQ Sauce', 'Spicy Sauce', 'Buffalo Sauce'], 'name': 'Fresh Juice'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Teriyaki', 'Vegetable Stir-fry', 'Coleslaw'], 'name': 'Stir-fry'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['BBQ Sauce', 'Spicy Sauce'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.404826
# 23                                                                                                                                                                    Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                                     [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                   [{'customizations': ['Lemon', 'Meringue'], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Apple Crisp'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Ice Cream'], 'name': 'Chocolate'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Basil'], 'name': 'Tomato Soup'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}]    0.386318
# 24                                                                                                                                                      Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                    [{'customizations': ['Extra Ice Cream Scoop', 'Chocolate'], 'name': 'Chocolate Ice Cream'}, {'customizations': ['Margarita'], 'name': 'Cocktail'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Sprinkles'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['BBQ Sauce'], 'name': 'Chicken Wings'}, {'customizations': ['Coleslaw'], 'name': 'Side Dish'}]    0.324853
# 25                                                                                                                                                                         Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Chocolate Cake'], 'name': 'Cake'}, {'customizations': ['Strawberry'], 'name': 'Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Cheese'], 'name': 'Vegan Burger'}]    0.464380
# 26                                                                                                                  Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                               [{'customizations': ['Extra Cheese', 'Flavored Syrups'], 'name': 'Pizza'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Grilled Chicken Breast', 'Rice'], 'name': 'Grilled Tofu'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetarian'}, {'customizations': [], 'name': 'White Wine'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Extra Topping'], 'name': 'None'}]    0.301676
# 27                                                                                                                           I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                             [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                      [{'customizations': ['Ranch', 'White', 'Red'], 'name': 'Garden Salad'}, {'customizations': ['Chicken', 'Spring Rolls'], 'name': 'Chicken Wings'}, {'customizations': ['White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.543689
# 28                                                                                                  Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                                      [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['BBQ Sauce'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Rice'], 'name': 'Side Dish'}]    0.648276
# 29                                                                                                                             Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                                     [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.748792
# 30                                                                                                   Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                              [{'customizations': ['BBQ Sauce', 'Extra Dipping Sauce'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Ice Cream'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternative'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.515625
# 31                                                                                                             Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                              [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                          [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lime', 'Garlic Butter'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Carrot Cake'], 'name': 'Carrot Cake'}]    0.576052
# 32                                                                                                      Can I get an extra ranch dipping sauce, an extra side of veggies, and flavored syrups in vanilla and caramel, please?                                                                                                                [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                      [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Apple', 'Berry'], 'name': 'Fruit Combinations'}]    0.568659
# 33                                                                                            Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                                          [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Butter', 'Gravy'], 'name': 'Mashed Potatoes'}]    0.683230
# 34                                                                                                               Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                                                [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                                                                               [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-Fry'}, {'customizations': ['Fries'], 'name': 'Extra'}, {'customizations': ['No Dressing'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Strawberry'], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.518664
# 35                                                                                              Can I get a spicy and mild coleslaw, grilled salmon with garlic butter, crispy fish and chips, and extra BBQ and pesto sauce?                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['BBQ', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': [], 'name': 'Apple Pie'}]    0.799290
# 36                                         Ordering some chicken wings with buffalo, BBQ, and spicy sauces, a grilled tofu with peanut sauce and chili lime, an apple crumble for dessert, and can't forget the extra cheese.                                                     [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Red Wine'], 'name': 'Wine'}, {'customizations': ['Cheese'], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Mashed Potatoes'}]    0.758497
# ...
# 107                                                                                                                                                                                   I'd like a cheesecake and an apple pie.                                                                                                                                                                                                                 [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                 [{'customizations': ['Cream of Mushroom', 'Cinnamon'], 'name': 'Cheesecake'}, {'customizations': ['Classic Apple Pie', 'Apple Crumble'], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Strawberry Ice Cream'}, {'customizations': ['Vanilla', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Crumbs'], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]    0.343558
# 108                                                                                                         Ordering a Vegetable Stir-fry with peanut sauce and garlic soy, a chocolate cake, and an extra gravy on the side.                                                                                                                  [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                    [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Berry and Nut Topping'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Caesar Salad', 'No Dressing'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple Crumble'], 'name': 'Dessert'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.546311
# 109                                                   Can I get some chicken spring rolls, grilled salmon with garlic butter and lemon dill, a spicy shrimp cocktail, and extra sauces including BBQ sauce, pesto, and gravy?                     [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                    [{'customizations': ['Chicken', 'Spring Rolls'], 'name': 'Chicken Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy', 'Shrimp Cocktail'], 'name': 'Spicy Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla Cake'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.340548
# 110                                   Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                                                  [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                None    0.000000
# 111                                  Can I get some coleslaw, make it mild and spicy? Also, I'd like the fish and chips with onion rings, extra crispy, and some fries on the side. For dessert, please add an apple crumble.                                                                                                        [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['BBQ Sauce', 'Cheese'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Pizza'}]    0.694656
# 112                                                                      Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                                      [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                                         [{'customizations': ['Vegetarian', 'Spring Rolls'], 'name': 'Vegetarian Spring Rolls'}, {'customizations': ['Chicken', 'Spring Rolls'], 'name': 'Chicken Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Lemon', 'Garlic'], 'name': 'Apple Sauce'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Chicken Soup'}]    0.503704
# 113                                                                                                                             I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                                  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                      [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Extra Chocolate Chips'], 'name': 'Berry'}, {'customizations': ['Apple Crumble'], 'name': 'Apple Crisp'}]    0.477477
# 114                                                                       I want an order of Chicken Wings with BBQ and Spicy sauce, a slice of Cheesecake, a Chocolate treat, and some Extra Dipping Sauce with Blue Cheese.                                                                              [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                    [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Mozzarella Sticks', 'Ranch', 'Spicy'], 'name': 'Extra Cheese Sticks'}, {'customizations': [], 'name': 'Grilled Chicken Breast'}, {'customizations': ['BBQ'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Rice'}]    0.644654
# 115                                                                                                                                                   Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Grilled Salmon'}, {'customizations': ['Lemon Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Something else'}]    0.591398
# 116                                                                                                       Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegan Cheese', 'Almond Milk'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.679245
# 117                                                                                  Can I get some vegetarian spring rolls, a cheesecake, a fruit salad, and for the extra topping, please include nuts and chocolate chips?                                                                         [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                     [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Crispy', 'Extra Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['BBQ Sauce'], 'name': 'Grilled Chicken Breast'}]    0.686275
# 118                                                                                                         I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                           [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                None    0.000000
# 119                                                                                                                     Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                           [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                             [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Garlic Butter', 'Mild'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Cheddar', 'Mayo'], 'name': 'Grilled Cheese'}, {'customizations': ['Cokes'], 'name': 'Mashed Potatoes'}, {'customizations': ['Mint Chocolate Chip'], 'name': 'Extra Ice Cream'}]    0.535714

# %% [markdown]
# ### **Medium 4b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-medium-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-4b-it...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) with quantization...
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-medium-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/131M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 8/8 [13:38<00:00, 102.29s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.7279
# ✅ Exact Match Accuracy: 11.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                    transcribed_text                                                                                                                                                                                                                                                                               items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       predicted_items  similarity
# 1                                                                                                 Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                    [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]    0.782353
# 3                                                                                               Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                    [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla', 'Strawberry'], 'name': 'Milkshakes'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.650367
# 4                                                                          I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                             [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Syrups'}, {'customizations': [], 'name': 'Extra Topping'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.663291
# 8                                                                                                       Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                       [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]  [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemon', 'Orange', 'Apple'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Bun or Bread Roll'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.268487
# 11                                                                                                      I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                              [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.473815
# 12                                                                                                                 Could I get a pale ale and an extra bun, please?                                                                                                                                                 [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.431290
# 14                                          Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                      [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.706897
# 16                                                                                 Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                    [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.634441
# 17                                    Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                             [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Blueberries'}, {'customizations': [], 'name': 'Raspberries'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.600639
# 18                                                              Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.668464
# 21                         Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.  [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.695652
# 22                                                                                     Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                  [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.678652
# 23                                                                                                          Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                             [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}]    0.469438
# 24                                                                                            Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                              [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.567164
# 25                                                                                                               Order onion rings with ranch and a chocolate cake.                                                                                                                                                                            [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.480198
# 26                                                        Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Iced Tea', 'Lemonade'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.350476
# 27                                                                 I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                     [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]    0.612836
# 28                                        Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                              [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktail'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.588727
# 29                                                                   Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                             [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.712644
# 30                                         Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                        [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.648649
# 31                                                   Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                      [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Scoop'}, {'customizations': [], 'name': 'Chocolate Scoop'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.664179
# 33                                  Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                  [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}]    0.690377
# 37                   I'll have a Garden Salad with ranch, balsamic, and vinaigrette, some vegetarian Spring Rolls, and a Grilled Chicken Breast with garlic butter.                                                             [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.780583
# 38                         Can I get a Miso Soup with toasted sesame seeds and chili oil, some Mozzarella Sticks with ranch on the side, and a slice of cheesecake?                                                                                          [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.617021
# 39                                     Can I get an order of Mozzarella Sticks with Ranch and Marinara, a Vegetable Stir-fry with Peanut Sauce, and some Chocolate?                                                                                           [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.760440
# 40                                                      Can I get some spicy coleslaw, buffalo chicken wings with a spicy kick, and an extra shot of vodka, please?                                                                                      [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.629630
# 41                                                                                        Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                           [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': [], 'name': 'Ice Cream'}, {'customizations': ['Vanilla', 'Strawberry'], 'name': 'Flavors'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.397022
# 43                                                              Can I get a miso soup with toasted sesame seeds and chili oil, and a chocolate on the side, please?                                                                                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.551887
# 44                                                 Can I get a Chicken Soup with a lemon wedge and a Cream of Mushroom topped with chopped parsley and truffle oil?                                                                                                                                  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Red'], 'name': 'Wine'}]    0.600000
# 45                                                         Ordering some spicy buffalo chicken wings, a lemonade, and I'll take almond milk as my milk alternative.                                                                                                   [{'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Mashed Potatoes'}, {'customizations': [], 'name': 'Rice'}, {'customizations': [], 'name': 'Fries'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}]    0.658683
# 47                                                                                                                   Can I get a vanilla and a fruit salad? Thanks!                                                                                                                                                                                          [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.528662
# 48                                                               Grilled Chicken Breast with BBQ sauce, Fanta and Sprite to drink, and a side of vanilla ice cream.                                                                                                          [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]    0.734884
# 51                                                                                  Can I get some mozzarella sticks with marinara sauce and a glass of white wine?                                                                                                                                                                      [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Lemon Wedges'], 'name': 'Extra Sauce'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]    0.522843
# 53                                         Getting a mix of craft beer including IPA, pale ale, and lager along with some wine options, specifically rosÃ© and red.                                                                                                                                                       [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Margarita', 'Old Fashioned'], 'name': 'Cocktails'}]    0.771812
# 57                                            I'll go with mozzarella sticks with ranch, an apple pie, and some extra sauces including gravy, pesto, and BBQ sauce.                                                                                               [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.670659
# ...
# 98                                     Can I get some chicken wings with buffalo, BBQ, and spicy sauces? Also, I'll have a cheesecake and a strawberry on the side.                                                                                                              [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Strawberry'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.708333
# 99                                                                                Grilled Tofu with Peanut Sauce, a bottle of red wine, and an extra side of fries.                                                                                                                    [{'customizations': ['Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.628692
# 101                                                        Can I get a miso soup with chili oil, a grilled chicken breast with BBQ sauce, and a sweetened iced tea?                                                                                                      [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.636719
# 102  I'll have a Vegetable Stir-fry with Garlic Soy, Peanut Sauce, and Teriyaki, a Vegan Burger with Mustard, no cheese, vegan cheese, and Ketchup, and a Lemonade.                                         [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.785586
# 104                                                                                 I'm ordering a fruit salad and an extra sauce with pesto, BBQ sauce, and gravy.                                                                                                                                                         [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.629834
# 105                                                        Order a Greek Salad with grilled chicken but no additional protein, and a mint chocolate chip ice cream.                                                                                                                                               [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Grilled Chicken', 'No Additional Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.561404
# 107                                                                                                                         I'd like a cheesecake and an apple pie.                                                                                                                                                                                         [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Extra Creamy', 'Extra Whipped Cream'], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}]    0.545455
# 112            Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                              [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Orange Juice', 'Apple Juice'], 'name': 'Fresh Juices'}]    0.592437
# 113                                                                   I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                          [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.657025
# 115                                                                                         Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                               [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}]    0.526316
# 116                                             Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                       [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla'], 'name': 'Apple Pie'}]    0.682105
# 118                                               I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.459930

# %% [markdown]
# ### **Large 4b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-large-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-large-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/131M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 8/8 [15:25<00:00, 115.66s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.5536
# ✅ Exact Match Accuracy: 3.33%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                                                       items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   predicted_items  similarity
# 0                                                                                                                I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Side'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Peanut Sauce', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Spicy Margarita'], 'name': 'Cocktails'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}]    0.646782
# 1                                                                                                                                                           Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                            [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Chocolate Chips', 'Vanilla'], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Caramel Sauce', 'Extra Butter'], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ Sauce'], 'name': 'Chicken Wing'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.492248
# 2                                                                                                         Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                                   [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]  [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Margarita'], 'name': 'Extra Cocktail'}, {'customizations': [], 'name': 'Extra Chocolate'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Red'], 'name': 'Wine'}]    0.287471
# 3                                                                                                                                                         Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                            [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Whipped Cream'], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauces'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}]    0.462609
# 4                                                                                                                                    I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                                     [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Unsweetened', 'Lemonade'], 'name': 'Iced Tea'}, {'customizations': ['Buffalo', 'Blue Cheese'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['BBQ'], 'name': 'Extra Sauce'}]    0.529301
# 5                                                                                                                            Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Croutons', 'Basil'], 'name': 'Tomato Soup'}, {'customizations': ['Lemon', 'Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red'], 'name': 'Wine'}]    0.408726
# 6                             Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Fresh Dill'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Vinaigrette'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Garlic Butter'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.552097
# 7                       Can I get a Garden Salad with Ranch, a dozen Spicy Buffalo BBQ Chicken Wings, Fish and Chips with crispy batter and onion rings on the side, and a Craft Beer with a mix of Lager, IPA, and Pale Ale?                          [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Red'], 'name': 'Wine'}]    0.784929
# 8                                                                                                                                                                 Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                               [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Buffalo'], 'name': 'Sauce'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy'], 'name': 'Mashed Potatoes'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemonade'}]    0.356209
# 9                                       Hey, can I get some mozzarella sticks with marinara and ranch, fish and chips with extra crispy fries, an extra topping of chocolate chips and berries, and a drink with almond milk?  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Extra Crispy Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Mashed Potatoes'], 'name': 'Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.654450
# 11                                                                                                                                                                I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                                      [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Lemonade'], 'name': 'Drinks'}, {'customizations': ['Chocolate Milk'], 'name': 'Drinks'}]    0.303514
# 12                                                                                                                                                                           Could I get a pale ale and an extra bun, please?                                                                                                                                                                         [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternative'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}]    0.352159
# 13                                                                                                 Can I get a Garden Salad with vinaigrette and ranch, a spicy order of chicken wings, a chocolate cake, and some chocolate?                                                                               [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemonade'}]    0.697436
# 14                                                                                                    Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Extra Sauce'], 'name': 'Gravy'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.676923
# 15                                                    Ordering a Tomato Soup with Cheddar Cheese, a Caesar Salad topped with Grilled Shrimp and Grilled Chicken, a slice of Chocolate Cake, and a scoop of Vanilla ice cream.                                                             [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]    0.785841
# 16                                                                                                                                           Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': [], 'name': 'Chicken Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Lemon Juice', 'Fresh Parsley'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Mozzarella Sticks'}, {'customizations': ['Marinara'], 'name': 'Extra Sauce'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.356215
# 18                                                                                                                        Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Pie'}]    0.454212
# 19                                                    Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                                              [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Coleslaw', 'Mashed Potatoes', 'Fries'], 'name': 'Sides'}, {'customizations': ['Strawberry', 'Chocolate'], 'name': 'Milkshakes'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}]    0.669935
# 20                                                                                                    I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                                  [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Fresh Parsley'], 'name': 'Vegetable Soup'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Caramel'], 'name': 'Apple Pie'}]    0.460203
# 21                                                                                   Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.                          [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.695652
# 22                                                                                                                                               Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                                          [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Apple'], 'name': 'Juice'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Parmesan'], 'name': 'Mashed Potatoes'}, {'customizations': ['Garlic Butter', 'Fresh Parsley'], 'name': 'Grilled Chicken Breast'}]    0.477612
# 23                                                                                                                                                                    Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                                     [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Extra Berries'], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Chocolate Shake'}, {'customizations': ['Extra Chocolate'], 'name': 'Chocolate Shake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Mashed Potatoes'}, {'customizations': ['White Wine'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.304279
# 24                                                                                                                                                      Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': [], 'name': 'Chocolate Ice Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.323129
# 25                                                                                                                                                                         Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Soft Drink'], 'name': 'Soft Drinks'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.323333
# 26                                                                                                                  Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Fries'], 'name': 'Side'}]    0.345216
# ...
# 111                                  Can I get some coleslaw, make it mild and spicy? Also, I'd like the fish and chips with onion rings, extra crispy, and some fries on the side. For dessert, please add an apple crumble.                                                                                                        [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemonade', 'Unsweetened'], 'name': 'Soft Drinks'}, {'customizations': ['Lager', 'IPA'], 'name': 'Beer'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.682927
# 112                                                                      Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                                      [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Vanilla'], 'name': 'Ice Cream'}, {'customizations': ['Lemonade', 'Spicy Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Fries'}]    0.575510
# 113                                                                                                                             I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                                  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Chicken'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Strawberry Cake'}, {'customizations': ['Lemon-Lime'], 'name': 'Soft Drinks'}, {'customizations': ['Vanilla'], 'name': 'Milk Drinks'}, {'customizations': [], 'name': 'Chocolate'}]    0.476048
# 114                                                                       I want an order of Chicken Wings with BBQ and Spicy sauce, a slice of Cheesecake, a Chocolate treat, and some Extra Dipping Sauce with Blue Cheese.                                                                              [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Strawberry'}]    0.741410
# 115                                                                                                                                                   Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.418251
# 116                                                                                                       Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemonade', 'Sweetened Iced Tea'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Mashed Potatoes', 'Veggies'], 'name': 'Sides'}, {'customizations': ['Tomato Sauce'], 'name': 'Extra Sauce'}]    0.498462
# 117                                                                                  Can I get some vegetarian spring rolls, a cheesecake, a fruit salad, and for the extra topping, please include nuts and chocolate chips?                                                                         [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Garlic Soy'], 'name': 'Chicken Stir-fry'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]    0.656250
# 118                                                                                                         I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                           [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Cream of Mushroom'], 'name': 'Cream of Mushroom'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Coleslaw'], 'name': 'Side'}, {'customizations': [], 'name': 'Lemonade'}]    0.460237
# 119                                                                                                                     Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                           [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Fries', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.487805

# %% [markdown]
# ### **Medium 12b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-medium-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
    attn_implementation="eager"
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-medium-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 8/8 [46:22<00:00, 347.77s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.6712
# ✅ Exact Match Accuracy: 5.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                           transcribed_text                                                                                                                                                                                                                                                                                            items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 predicted_items  similarity
# 0                                                                                             I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                            [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                  [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.691680
# 1                                                                                                                                        Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                 [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                [{'customizations': ['Extra Chocolatey'], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Lemonade'], 'name': 'Lemonade'}, {'customizations': ['Vanilla'], 'name': 'Vanilla Shake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.526733
# 3                                                                                                                                      Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                 [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.703704
# 4                                                                                                                 I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                          [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                               [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]    0.531309
# 5                                                                                                         Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                  [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]  [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Mustard', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.500703
# 6          Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                      [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Red Wine'], 'name': 'Wine'}]    0.787645
# 7    Can I get a Garden Salad with Ranch, a dozen Spicy Buffalo BBQ Chicken Wings, Fish and Chips with crispy batter and onion rings on the side, and a Craft Beer with a mix of Lager, IPA, and Pale Ale?               [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                              [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings (Dozen)'}, {'customizations': ['Crispy Batter', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.415493
# 8                                                                                                                                              Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                    [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                            [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['No Protein', 'Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Crispy Fries', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.404803
# 10                                                                                   Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                         [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                            [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.694444
# 11                                                                                                                                             I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                           [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                       [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Extra Whipped Cream', 'Strawberry'], 'name': 'Extra Topping'}, {'customizations': ['Vanilla', 'Chocolate'], 'name': 'Flavored Syrups'}]    0.490956
# 12                                                                                                                                                        Could I get a pale ale and an extra bun, please?                                                                                                                                                              [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Pale Ale'], 'name': 'Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}]    0.566667
# 16                                                                                                                        Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                 [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.465632
# 17                                                                           Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                                          [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                       [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.660808
# 18                                                                                                     Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                             [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                     [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.518828
# 19                                 Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                                   [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                  [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.753676
# 20                                                                                 I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                       [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                        [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.665272
# 21                                                                Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.               [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.754420
# 22                                                                                                                            Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                               [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                      [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Chocolate Chips', 'Berries', 'Nuts'], 'name': 'Extra Topping'}]    0.659389
# 23                                                                                                                                                 Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                     [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.477612
# 24                                                                                                                                   Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                           [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.475000
# 25                                                                                                                                                      Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                         [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                           [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.487437
# 26                                                                                               Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                     [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                          [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Vanilla'], 'name': 'Milk Alternatives'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.453202
# 27                                                                                                        I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                             [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.685185
# 28                                                                               Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                           [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                       [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.651270
# 29                                                                                                          Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                          [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                   [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Toppings'}]    0.714286
# 30                                                                                Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                     [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                      [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Ketchup', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.621176
# 31                                                                                          Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                   [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                            [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Mashed Potatoes', 'Veggies', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.659259
# 33                                                                         Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                               [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                                                 [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Mashed Potatoes', 'Fries', 'Veggies'], 'name': 'Extra Side'}]    0.634615
# 34                                                                                            Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                                     [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                                                                      [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.622642
# 37                                                          I'll have a Garden Salad with ranch, balsamic, and vinaigrette, some vegetarian Spring Rolls, and a Grilled Chicken Breast with garlic butter.                                                                          [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                                                                        [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.728261
# 38                                                                Can I get a Miso Soup with toasted sesame seeds and chili oil, some Mozzarella Sticks with ranch on the side, and a slice of cheesecake?                                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                           [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.686391
# 40                                                                                             Can I get some spicy coleslaw, buffalo chicken wings with a spicy kick, and an extra shot of vodka, please?                                                                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                        [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.503704
# 41                                                                                                                               Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                        [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Extra Scoop'], 'name': 'Ice Cream'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.462396
# 42       I'm ordering a miso soup with toasted sesame seeds, a garden salad with vinaigrette, a grilled chicken breast with BBQ and garlic butter, and a grilled salmon with garlic butter and lemon dill.  [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}]                                                                                                                                   [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.784257
# 43                                                                                                     Can I get a miso soup with toasted sesame seeds and chili oil, and a chocolate on the side, please?                                                                                                                                                                    [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                 [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.465209
# 44                                                                                        Can I get a Chicken Soup with a lemon wedge and a Cream of Mushroom topped with chopped parsley and truffle oil?                                                                                                                                               [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}]                                                                                                                                                     [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip Shake'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.513966
# 45                                                                                                Ordering some spicy buffalo chicken wings, a lemonade, and I'll take almond milk as my milk alternative.                                                                                                                [{'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                 [{'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Almond Milk', 'Oat Milk', 'Milk and Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.597826
# 46                        I want a Greek Salad with grilled chicken and falafel, a side of onion rings with BBQ sauce, a shrimp cocktail with lemon herb and spicy cocktail sauce, and no dessert for now.                     [{'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                           [{'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.667660
# 47                                                                                                                                                          Can I get a vanilla and a fruit salad? Thanks!                                                                                                                                                                                                       [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                              [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Fries', 'Rice', 'Veggies', 'Mashed Potatoes'], 'name': 'Extra Side'}]    0.453552
# 48                                                                                                      Grilled Chicken Breast with BBQ sauce, Fanta and Sprite to drink, and a side of vanilla ice cream.                                                                                                                       [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                    [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Vanilla'], 'name': 'Ice Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.698630
# 51                                                                                                                         Can I get some mozzarella sticks with marinara sauce and a glass of white wine?                                                                                                                                                                                   [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                   [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}]    0.412000
# 52                                                                                        Can I get a couple of soft drinks, please? One Sprite and one Fanta. Also, I'll take an apple pie and a vanilla.                                                                                                                                         [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                 [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['BBQ Sauce', 'Ranch'], 'name': 'Extra Sauce'}]    0.622222
# ...
# 101                                                                                               Can I get a miso soup with chili oil, a grilled chicken breast with BBQ sauce, and a sweetened iced tea?                                                                                                                   [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}]                                                                                                                                                                                  [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}]    0.611632
# 102                                         I'll have a Vegetable Stir-fry with Garlic Soy, Peanut Sauce, and Teriyaki, a Vegan Burger with Mustard, no cheese, vegan cheese, and Ketchup, and a Lemonade.                                                      [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}]                                                                                                                                                 [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.705502
# 103                                                                                                                               One chocolate cake, one apple pie, and some extra whipped cream, please.                                                                                                                                           [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.643519
# 104                                                                                                                        I'm ordering a fruit salad and an extra sauce with pesto, BBQ sauce, and gravy.                                                                                                                                                                      [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                         [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.527778
# 105                                                                                               Order a Greek Salad with grilled chicken but no additional protein, and a mint chocolate chip ice cream.                                                                                                                                                            [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                 [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Mashed Potatoes', 'Fries', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.511416
# 106                                                                                                      Can I get a fresh orange juice, an extra side of mashed potatoes and fries, and some almond milk?                                                                                               [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                   [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.738337
# 107                                                                                                                                                                I'd like a cheesecake and an apple pie.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.450402
# 108                                                                                      Ordering a Vegetable Stir-fry with peanut sauce and garlic soy, a chocolate cake, and an extra gravy on the side.                                                                                                       [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                             [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.754881
# 109                                Can I get some chicken spring rolls, grilled salmon with garlic butter and lemon dill, a spicy shrimp cocktail, and extra sauces including BBQ sauce, pesto, and gravy?          [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                     [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.753623
# 112                                                   Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                           [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                       [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.558416
# 115                                                                                                                                Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                            [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Vanilla Milkshake'}, {'customizations': [], 'name': 'Strawberry Milkshake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.468085
# 116                                                                                    Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                    [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                            [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chili Lime', 'Peanut Sauce', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.636542
# 118                                                                                      I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                          [{'customizations': ['Fresh Parsley', 'Whiskey', 'Vodka', 'Rum'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]    0.510251
# 119                                                                                                  Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                       [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.681818

# %% [markdown]
# ### **Large 12b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-large-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-large-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/274M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 8/8 [38:32<00:00, 289.04s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.5419
# ✅ Exact Match Accuracy: 1.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                                                       items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     predicted_items  similarity
# 0                                                                                                                I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                   [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Sprite'], 'name': 'Soft Drink'}, {'customizations': ['Garlic Butter', 'Mashed Potatoes'], 'name': 'Grilled Chicken Breast'}]    0.597968
# 1                                                                                                                                                           Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                            [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                         [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Mashed Potatoes'}, {'customizations': [], 'name': 'Rice'}, {'customizations': ['Unsweetened'], 'name': 'Lemonade'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Spicy Cocktail', 'Lemon Wedges'], 'name': 'Shrimp Cocktail'}]    0.367911
# 2                                                                                                         Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                                   [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                              [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Strawberry Cheesecake'}]    0.545190
# 3                                                                                                                                                         Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                            [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Fries'], 'name': 'Side'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Sweetened', 'Extra Sugar'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.479279
# 4                                                                                                                                    I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                                     [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                        [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}]    0.492091
# 5                                                                                                                            Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                                                         [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Strawberries'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.502825
# 6                             Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}]    0.772727
# 8                                                                                                                                                                 Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                               [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                 [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Rice Serving'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}]    0.406897
# 9                                       Hey, can I get some mozzarella sticks with marinara and ranch, fish and chips with extra crispy fries, an extra topping of chocolate chips and berries, and a drink with almond milk?  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Cheesecake'}]    0.797468
# 10                                                                                                      Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                                    [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]    0.651466
# 11                                                                                                                                                                I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                                      [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Sides'}, {'customizations': ['Coke', 'Sprite'], 'name': 'Soft Drinks'}]    0.403397
# 12                                                                                                                                                                           Could I get a pale ale and an extra bun, please?                                                                                                                                                                         [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                  [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Vegan Mayo', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['No Dressing'], 'name': 'Grilled Chicken Salad'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}]    0.350081
# 13                                                                                                 Can I get a Garden Salad with vinaigrette and ranch, a spicy order of chicken wings, a chocolate cake, and some chocolate?                                                                               [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                             [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Unsweetened'], 'name': 'Lemonade'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.516456
# 14                                                                                                    Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                       [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Lemon'], 'name': 'Iced Tea'}]    0.634675
# 15                                                    Ordering a Tomato Soup with Cheddar Cheese, a Caesar Salad topped with Grilled Shrimp and Grilled Chicken, a slice of Chocolate Cake, and a scoop of Vanilla ice cream.                                                             [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                      [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Orange'], 'name': 'Fresh Juice'}]    0.597577
# 16                                                                                                                                           Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Whipped Cream'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Lemonade'], 'name': 'Lemonade'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}]    0.388235
# 18                                                                                                                        Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate'}]    0.497992
# 19                                                    Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                                              [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                             [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['No Protein'], 'name': 'Vegan Caesar Salad'}, {'customizations': [], 'name': 'Lemonade'}]    0.637636
# 20                                                                                                    I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                                  [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Coffee'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.562832
# 21                                                                                   Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.                          [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                 [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}]    0.453804
# 22                                                                                                                                               Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                                          [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauces'}, {'customizations': ['Broccoli', 'Carrots', 'Green Beans'], 'name': 'Veggies'}]    0.554128
# 23                                                                                                                                                                    Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                                     [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Extra Whipped Cream'], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Extra Ice Cream Scoop', 'Fresh Strawberries'], 'name': 'Dessert'}, {'customizations': ['Extra Crispy'], 'name': 'Apple Crumble'}, {'customizations': ['Onion Rings', 'Crispy Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Mashed Potatoes', 'Extra Side'], 'name': 'Side Dish'}, {'customizations': ['BBQ Sauce', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}]    0.304279
# 24                                                                                                                                                      Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                             [{'customizations': [], 'name': 'Chocolate Ice Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Mashed Potatoes', 'Steamed Veggies'], 'name': 'Side'}, {'customizations': ['Orange'], 'name': 'Fresh Juice'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.313531
# 25                                                                                                                                                                         Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                     [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemonade', 'Sweetened Iced Tea'], 'name': 'Drinks'}, {'customizations': ['Mashed Potatoes'], 'name': 'Sides'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom Soup'}, {'customizations': ['Garlic Butter', 'Side Salad'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange Juice'], 'name': 'Fresh Juices'}, {'customizations': ['Red Wine'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}]    0.313409
# 26                                                                                                                  Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}]    0.393162
# 27                                                                                                                           I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                             [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Vanilla'], 'name': 'Ice Cream'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}]    0.553271
# 28                                                                                                  Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                                      [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.593684
# 29                                                                                                                             Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                                     [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                       [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}]    0.494418
# 30                                                                                                   Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                       [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}]    0.470588
# 31                                                                                                             Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                              [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                   [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Mashed Potatoes', 'Coleslaw', 'Garden Salad with Vinaigrette'], 'name': 'Extra Sides'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]    0.467806
# 32                                                                                                      Can I get an extra ranch dipping sauce, an extra side of veggies, and flavored syrups in vanilla and caramel, please?                                                                                                                [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.618629
# 33                                                                                            Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                                          [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                      [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.463483
# 34                                                                                                               Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                                                [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['White Wine'], 'name': 'Wine'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}]    0.572668
# 35                                                                                              Can I get a spicy and mild coleslaw, grilled salmon with garlic butter, crispy fish and chips, and extra BBQ and pesto sauce?                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                        [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['BBQ Sauce', 'Pesto Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}]    0.629428
# 36                                         Ordering some chicken wings with buffalo, BBQ, and spicy sauces, a grilled tofu with peanut sauce and chili lime, an apple crumble for dessert, and can't forget the extra cheese.                                                     [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                          [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Mashed Potatoes'}]    0.667643
# ...
# 108                                                                                                         Ordering a Vegetable Stir-fry with peanut sauce and garlic soy, a chocolate cake, and an extra gravy on the side.                                                                                                                  [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                 [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['White Wine'], 'name': 'Wine'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]    0.573311
# 109                                                   Can I get some chicken spring rolls, grilled salmon with garlic butter and lemon dill, a spicy shrimp cocktail, and extra sauces including BBQ sauce, pesto, and gravy?                     [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}]    0.675325
# 110                                   Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                                                  [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'Lemon Vinaigrette'], 'name': 'Caesar Salad'}]    0.728125
# 111                                  Can I get some coleslaw, make it mild and spicy? Also, I'd like the fish and chips with onion rings, extra crispy, and some fries on the side. For dessert, please add an apple crumble.                                                                                                        [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemonade', 'Strawberry'], 'name': 'Fresh Juices'}, {'customizations': ['Buffalo', 'BBQ'], 'name': 'Chicken Wings'}]    0.741344
# 112                                                                      Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                                      [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Apple Cider', 'Lemonade'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['Mashed Potatoes', 'Veggies'], 'name': 'Side'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.570850
# 113                                                                                                                             I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                                  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                 [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.466960
# 114                                                                       I want an order of Chicken Wings with BBQ and Spicy sauce, a slice of Cheesecake, a Chocolate treat, and some Extra Dipping Sauce with Blue Cheese.                                                                              [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}]    0.673235
# 115                                                                                                                                                   Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.385965
# 116                                                                                                       Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Lemonade'], 'name': 'Lemonade'}, {'customizations': ['Sweet', 'Unsweetened'], 'name': 'Iced Tea'}]    0.606742
# 117                                                                                  Can I get some vegetarian spring rolls, a cheesecake, a fruit salad, and for the extra topping, please include nuts and chocolate chips?                                                                         [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Chicken Breast'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Cheddar Cheese', 'Basil'], 'name': 'Tomato Soup'}]    0.548303
# 118                                                                                                         I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                           [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                     [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Coleslaw'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Red Wine'], 'name': 'Wine'}]    0.445902
# 119                                                                                                                     Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                           [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                     [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Spicy'], 'name': 'Margarita'}, {'customizations': ['Mojito'], 'name': 'Cocktail'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}]    0.469484

# %% [markdown]
# # **Load Medium Dataset**

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-medium-clean-18k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1800, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-medium-clean-18k' (split: 'train')...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/518 [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/28 [00:00<?, ?files/s]
# train-00000-of-00028.parquet:   0%|          | 0.00/487M [00:00<?, ?B/s]
# train-00001-of-00028.parquet:   0%|          | 0.00/408M [00:00<?, ?B/s]
# train-00002-of-00028.parquet:   0%|          | 0.00/380M [00:00<?, ?B/s]
# train-00003-of-00028.parquet:   0%|          | 0.00/449M [00:00<?, ?B/s]
# train-00004-of-00028.parquet:   0%|          | 0.00/381M [00:00<?, ?B/s]
# train-00005-of-00028.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# train-00006-of-00028.parquet:   0%|          | 0.00/610M [00:00<?, ?B/s]
# train-00007-of-00028.parquet:   0%|          | 0.00/516M [00:00<?, ?B/s]
# train-00008-of-00028.parquet:   0%|          | 0.00/473M [00:00<?, ?B/s]
# train-00009-of-00028.parquet:   0%|          | 0.00/415M [00:00<?, ?B/s]
# train-00010-of-00028.parquet:   0%|          | 0.00/358M [00:00<?, ?B/s]
# train-00011-of-00028.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# train-00012-of-00028.parquet:   0%|          | 0.00/453M [00:00<?, ?B/s]
# train-00013-of-00028.parquet:   0%|          | 0.00/383M [00:00<?, ?B/s]
# train-00014-of-00028.parquet:   0%|          | 0.00/450M [00:00<?, ?B/s]
# train-00015-of-00028.parquet:   0%|          | 0.00/385M [00:00<?, ?B/s]
# train-00016-of-00028.parquet:   0%|          | 0.00/357M [00:00<?, ?B/s]
# train-00017-of-00028.parquet:   0%|          | 0.00/407M [00:00<?, ?B/s]
# train-00018-of-00028.parquet:   0%|          | 0.00/346M [00:00<?, ?B/s]
# train-00019-of-00028.parquet:   0%|          | 0.00/365M [00:00<?, ?B/s]
# train-00020-of-00028.parquet:   0%|          | 0.00/408M [00:00<?, ?B/s]
# train-00021-of-00028.parquet:   0%|          | 0.00/344M [00:00<?, ?B/s]
# train-00022-of-00028.parquet:   0%|          | 0.00/386M [00:00<?, ?B/s]
# train-00023-of-00028.parquet:   0%|          | 0.00/380M [00:00<?, ?B/s]
# train-00024-of-00028.parquet:   0%|          | 0.00/326M [00:00<?, ?B/s]
# train-00025-of-00028.parquet:   0%|          | 0.00/451M [00:00<?, ?B/s]
# train-00026-of-00028.parquet:   0%|          | 0.00/419M [00:00<?, ?B/s]
# train-00027-of-00028.parquet:   0%|          | 0.00/357M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/18000 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/24 [00:00<?, ?it/s]
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1800
# })
# Splitting dataset into train and validation sets...
# Train set size: 1620
# Validation set size: 180
# WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.

# %% [markdown]
# ### **Small 1b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-small-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) with quantization...
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-small-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches:  25%|██▌       | 3/12 [01:59<07:37, 50.78s/it]
# Warning: Could not parse JSON: Expecting ',' delimiter: line 1 column 109 (char 108).
# Attempted to parse (after extraction): '[{"customizations":["Spicy"],"name":"Coleslaw"},{"customizations":["Fries","Fish and Chips"],"name":"Crispy"]'
# Inference Batches:  33%|███▎      | 4/12 [02:09<04:38, 34.85s/it]
# Warning: Could not parse JSON: Expecting ':' delimiter: line 1 column 233 (char 232).
# Attempted to parse (after extraction): '[{"customizations":["BBQ","Spicy"],"name":"Chicken Wings"},{"customizations":["Soy Ginger","Peanut Sauce"],"name":"Grilled Tofu"},{"customizations":["Coke","Lemonade","Extra Whipped Cream"],"name":"Soft Drinks","Extra Whipped Cream"}]'
# Inference Batches: 100%|██████████| 12/12 [07:59<00:00, 39.96s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8279
# ✅ Exact Match Accuracy: 20.56%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                 transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        predicted_items  similarity
# 0    I want a Cream of Mushroom soup with truffle oil, some spring rolls with vegetarian and chicken, a portion of chicken wings with BBQ, Buffalo, and spicy sauces, a grilled chicken breast with BBQ, and a selection of soft drinks including Fanta, Coke, and Sprite. Also, add some craft beer â€” a mix of lager, pale ale, and IPA, and I'll need extra sauces like pesto and BBQ sauce.         [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                          [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ', 'Spicy'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Craft Beer'}]    0.784516
# 13                                                                                                                                                            Caesar Salad with grilled shrimp and grilled chicken, Greek Salad with grilled chicken, Vegetable Stir-fry with peanut sauce, garlic soy, and teriyaki, Lemon Meringue Pie, Fruit Salad, and an extra side of ranch dipping sauce.                                                                            [{'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                            [{'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ranch'], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}]    0.734536
# 14                                                                                                                                                                                       I'll have a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a side of mild and spicy coleslaw, a sweetened iced tea, extra cheese, extra whipped cream, and an extra shot of vodka.                                                                                                            [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                       [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Extra Cheese', 'Extra Whipped Cream'], 'name': 'Milk Alternatives'}, {'customizations': ['Vodka'], 'name': 'Shot of Alcohol'}]    0.648256
# 23                                                                                                                                                                                                                                                            I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                                                                    [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                               [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Lemonade'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.124352
# 26                                                                                                                                                                                                                                       Can I get a spicy coleslaw and a shrimp cocktail with lemon herb? Also, a lemonade, a mojito, a glass of rosÃ© wine, and some extra cheese on the side.                                                                                                                                                                                     [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                              [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Rose Wine'}, {'customizations': ['Extra Cheese'], 'name': 'Topping'}]    0.770294
# 37                                                                                                                                                                            I'm ordering chicken spring rolls, grilled salmon with lemon dill and garlic butter, a sweetened iced tea, an Old Fashioned cocktail, cheesecake, mint chocolate chip, and flavored syrups in vanilla and caramel.                                                                       [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                        [{'customizations': ['Chicken', 'Spring Rolls'], 'name': 'Grilled Salmon'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Sweetened Iced Tea'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.656294
# 38                                                                                                                 I'm ordering a Garden Salad with balsamic and ranch dressing, Spring Rolls with a mix of vegetarian and chicken, some spicy Chicken Wings with BBQ and buffalo sauce, Grilled Salmon with lemon dill, Fish and Chips that are crispy with fries, and to finish, an Apple Pie.                                                                                                            [{'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                        [{'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo'], 'name': 'Spicy Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}]    0.697479
# 40                                                                                                                                                                                                                                         A Greek salad with falafel, mozzarella sticks with ranch, a fruit salad, extra dipping sauces of ranch and blue cheese, and some extra whipped cream.                                                                                                                                                                                                       [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                         [{'customizations': ['Falafel', 'Mozzarella Sticks', 'Ranch'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Dipping Sauce (Ranch/Blue Cheese)'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.321970
# 42                                                                                                                                                                                             Miso soup with toasted sesame seeds and chili oil, mild coleslaw, vegetable stir-fry with peanut sauce, teriyaki, and garlic soy, a chocolate cake, a cheesecake, and flavored syrups in vanilla.                                                                                                                  [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Peanut Sauce', 'Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                              [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Peanut Sauce', 'Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vanilla'], 'name': 'Chocolate Cake'}, {'customizations': ['Cheesecake'], 'name': 'Vanilla Cheesecake'}, {'customizations': ['Flavored Syrups'], 'name': 'Vanilla'}]    0.708277
# 44                                                                                                                 Getting a spicy coleslaw, crispy fries with the fish and chips, a vegetable stir-fry with peanut sauce, a vegan burger with ketchup, mustard, vegan mayo, no cheese, and vegan cheese, grilled tofu with peanut sauce, chili lime, and soy ginger, plus a lemon meringue pie.                                                     [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Mayo', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Peanut Sauce', 'Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   None    0.000000
# 47                                                                                                      Ordering a Chicken Soup with fresh parsley, mozzarella sticks with ranch and marinara, a grilled chicken breast with BBQ sauce, fresh orange juice, and a selection of cocktails including a margarita, old fashioned, and mojito. Also, adding an extra bun and some gravy on the side.                                            [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                   [{'customizations': ['Fresh Parsley', 'Ranch', 'Marinara'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ Sauce', 'Marinara'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange Juice'], 'name': 'Fresh Juices'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]    0.665054
# 54                                                                                                                                                                                                                  Order some BBQ and spicy chicken wings, grilled tofu with soy ginger and peanut sauce, a Coke, lemonade, a slice of lemon meringue pie, and extra whipped cream on the side.                                                                                                                                                     [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   None    0.000000
# 55                                                        I'll take a Caesar Salad with grilled chicken, a Greek Salad with falafel, some BBQ spicy Buffalo chicken wings, a Shrimp Cocktail with lemon herb and spicy cocktail sauce, three cocktails: an Old Fashioned, a Mojito, and a Margarita. For dessert, I'll go with a slice of chocolate cake and some mint chocolate chip ice cream.  [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Old Fashioned', 'Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                    [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'BBQ Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Old Fashioned', 'Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Mint Chocolate Chip'], 'name': 'Ice Cream'}]    0.392199
# 57                                                                                                                                                      I'm ordering a Tomato Soup with Cheddar Cheese and Croutons, a Chocolate Cake, a Lemon Meringue Pie, Extra Whipped Cream, an Extra Topping with Berries, Chocolate Chips, and Nuts, and Milk Alternatives with Almond Milk and Oat Milk.                                                                                                 [{'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.767213
# 62                                               I want a Greek Salad with no protein, add falafel and grilled chicken. Also, get a Vegetable Stir-fry with peanut sauce and teriyaki. For dessert, include a chocolate cake and some mint chocolate chip ice cream. Don't forget extra dipping sauces with blue cheese and ranch, and add extra toppings of berries, chocolate chips, and nuts.                                                          [{'customizations': ['No Protein', 'Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]                                                                                                                                                          [{'customizations': ['No Protein', 'Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chocolate Cake', 'Mint Chocolate Chip'], 'name': 'Dessert'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.607053
# 65                                                                                                                                                               Going for some spicy chicken wings and a grilled chicken breast with BBQ sauce. I'll take a glass of red wine with that. Also, I'd like some extra nuts on top and I'll need almond milk and oat milk for my milk alternatives.                                                                                                                                                                                                     [{'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.453333
# 69                                                                                                                                                                                       I'll have chicken spring rolls, a craft beer that includes IPA, lager, and pale ale, a glass of red wine, a slice of lemon meringue pie, an extra bread roll, and some pesto and BBQ sauce on the side.                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                  [{'customizations': ['Chicken Spring Rolls'], 'name': 'Chicken Spring Rolls'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Red Wine'], 'name': 'Wine'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bread Roll'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.180741
# 75                                              I'll have a Garden Salad with vinaigrette, balsamic, and ranch, a Vegan Burger with vegan mayo, ketchup, no cheese, and vegan cheese. For drinks, I'll take an Old Fashioned and a Mojito. For dessert, I'd like a cheesecake, and I'll finish off with some flavored syrups in vanilla and caramel. Also, add an extra shot of rum and whiskey.                                                    [{'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                [{'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.551893
# 78                                                                                                                                                                                Garden Salad with Vinaigrette, Balsamic, and Ranch, Onion Rings with BBQ and Ranch, Fresh Juices with Carrot, Orange, and Apple, Extra Cheese, and an Extra Side of Fries, Mashed Potatoes, Rice, and Veggies.                                                                                                                                         [{'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Mashed Potatoes', 'Rice', 'Veggies'], 'name': 'Extra Side'}]                                                                                                         [{'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Extra Cheese'], 'name': 'Extra Cheese'}, {'customizations': ['Fries'], 'name': 'Extra Side of Fries'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Veggies'], 'name': 'Extra Side of Mashed Potatoes, Rice, and Veggies'}]    0.669291
# 85                                                                                                                                     The order includes a Greek Salad with grilled chicken, a Garden Salad with balsamic dressing, onion rings with ranch and BBQ sauce, craft beer featuring lager and pale ale, a glass of white wine, extra cheese, and extra toppings of berries and nuts.                                                                                     [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]                                                                                                                                                                            [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Ranch', 'BBQ Sauce'], 'name': 'Onion Rings'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['White Wine'], 'name': 'Wine'}, {'customizations': ['Extra Cheese', 'Extra Toppings'], 'name': 'Extra Cheese and Nuts'}]    0.772727
# 86                                                                                                                       I'll have spring rolls with chicken and vegetarian, mozzarella sticks with ranch and marinara, grilled tofu with chili lime and peanut sauce, a lemonade, a slice of lemon meringue pie, extra whipped cream, and extra toppings of nuts, chocolate chips, and berries.                                     [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                             [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Extra Whipped Cream', 'Extra Topping'], 'name': 'Extra Toppings'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.793651
# 87         Going for a Garden Salad with balsamic dressing, a bunch of Chicken Wings tossed in buffalo, BBQ, and spicy sauces, and some crispy Fish and Chips served with onion rings and fries. Also adding a refreshing Fruit Salad, extra BBQ sauce, pesto, and gravy on the side, plus an extra scoop of ice cream. Gotta top it all off with some extra berries, nuts, and chocolate chips.               [{'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                          [{'customizations': ['Balsamic', 'Buffalo', 'Spicy'], 'name': 'Garden Salad'}, {'customizations': ['Chicken', 'BBQ', 'Spicy'], 'name': 'Wings'}, {'customizations': ['Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.495437
# 88                                                                                                                                                                        I'll have a Greek Salad with grilled chicken, some mozzarella sticks with marinara, a couple of soft drinksâ€”Coke and Fanta, a slice of lemon meringue pie, extra cheese, and for toppings, chocolate chips and nuts.                                                                                                                                 [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]                                                                                                                                                                                                  [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Topping'}]    0.192140
# 102                                                                                                                                                                                       I'll have some chicken spring rolls, grilled tofu with soy ginger, a sweetened iced tea, a craft beer with IPA, lager, and pale ale, an apple crumble, and an extra side of fries and mashed potatoes.                                                                                                                                 [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}]                                                                                                                                                                                     [{'customizations': ['Chicken Spring Rolls'], 'name': 'Chicken Spring Rolls'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}]    0.183119
# 103                                                                                                                                     Miso Soup with toasted sesame seeds, spicy chicken wings with BBQ and buffalo sauce, grilled salmon with lemon dill, an extra bread roll, mashed potatoes as an extra side, flavored syrups in caramel and vanilla, and oat milk as my milk alternative.                                   [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                       [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['BBQ', 'Buffalo'], 'name': 'Spicy Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Bread Roll'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternative'}]    0.264151
# 106                                                                                                                              Grilled chicken breast with BBQ sauce, vegetable stir-fry with garlic soy, peanut sauce, and teriyaki, a vegan burger with vegan mayo, mint chocolate chip ice cream, extra blue cheese dipping sauce, extra whipped cream, and toppings with berries and nuts.                                 [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]                                                                                                                                                 [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vegan Mayo', 'Mint Chocolate Chip'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Extra Blue Cheese Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Topping'}]    0.794189
# 108                                                                                 Ordering a Garden Salad with balsamic vinaigrette, some spicy buffalo and BBQ chicken wings, grilled salmon with garlic butter, soft drinks including Sprite, Fanta, and Coke, cocktails with a mix of margarita, old fashioned, and mojito, a glass of white wine, and finishing off with a chocolate cake.                              [{'customizations': ['Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                               [{'customizations': ['Balsamic Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Soft Drinks'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'White Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.614699
# 112                                                                                                                                                       I want an iced tea sweetened, a fresh juice mix with apple, orange, and carrot, a craft beer IPA, a fruit salad, extra ranch dipping sauce, flavored syrups in vanilla and caramel, and some almond and oat milk as milk alternatives.                                        [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                              [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juice Mix'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.318772
# 116                                                                      Ordering the spicy coleslaw and onion rings with ranch. I'll also have the vegetable stir-fry with garlic soy and peanut sauce, a pale ale craft beer, and mint chocolate chip for dessert. For sides, please include fries, veggies, rice, and mashed potatoes, and don't forget the extra topping of chocolate chips.                               [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Fries', 'Veggies', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                [{'customizations': ['Spicy', 'Onion Rings', 'Ranch'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.627168
# 117                                                                                                 Ordering a Caesar Salad with grilled shrimp and no protein, some chicken and vegetarian spring rolls, a selection of craft beer including IPA, lager, and pale ale, an apple pie for dessert, extra cheese, an extra bun or bread roll, and extra toppings with berries and chocolate chips.                                            [{'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                [{'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Chicken', 'Vegetarian Spring Rolls'], 'name': 'Chicken and Vegetarian Rolls'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Extra Cheese', 'Extra Bun/Roll', 'Extra Topping'], 'name': 'Extra Sides'}]    0.336735
# ...
# 151                                                                                                               I'm ordering a tomato soup with croutons, a chicken soup with a lemon wedge and fresh parsley, onion rings with ranch and BBQ, shrimp cocktail with lemon herb and spicy cocktail sauce, a vanilla ice cream, a strawberry ice cream, and an extra topping of chocolate chips.                                                              [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                               [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley', 'Ranch', 'BBQ'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail Sauce'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.737361
# 153                                                                                                                                                                                                                       Can I get a fresh juice with carrot, orange, and apple, a glass of white wine, a cheesecake, an extra bun or bread roll, and some chocolate chips as an extra topping?                                                                                                                                                                                                         [{'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                    [{'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juice'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.438849
# 155                                                                                                                                                                                              Can I get a Cream of Mushroom with chopped parsley, some onion rings with BBQ sauce, a shrimp cocktail with lemon herb, a glass of rosÃ© wine, and some extra BBQ sauce on the side? Thank you!                                                                                                                                                                                                             [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                              [{'customizations': ['Chopped Parsley', 'Onion Rings', 'BBQ Sauce'], 'name': 'Cream of Mushroom'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}]    0.328185
# 156                                                                             Get me a Cream of Mushroom with truffle oil, a grilled salmon with garlic butter, a vegetable stir-fry with peanut sauce, and a vegan burger with ketchup, no cheese, vegan mayo, and vegan cheese. For dessert, I'll have strawberry and mint chocolate chip, and add an extra shot of vodka, rum, and whiskey.            [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'No Cheese', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                            [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'No Cheese', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}]    0.766074
# 163                                                                                                                                                                                                                             I'll have chicken and vegetarian spring rolls, fish and chips with onion rings, a cheesecake, some chocolate, a fruit salad, apple crumble, and a berry parfait.                                                                                                                            [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                   [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Fish and Chips', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.328103
# 166                                                                                                                                                                                                                                      Spicy coleslaw, mozzarella sticks with marinara, grilled chicken breast with garlic butter, chocolate, apple crumble, and extra chocolate chips on top.                                                                                                                                                   [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                             [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Mozzarella Sticks'], 'name': 'Chicken Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.293663
# 170                                                           I'll have a Tomato Soup with croutons, cheddar cheese, and basil pesto, a Chicken Soup with fresh parsley, a Grilled Salmon with garlic butter and lemon dill, Fish and Chips extra crispy with fries, crispy onion rings, and some soft drinks including Coke, Sprite, and Fanta. Also add almond milk for the milk alternatives.                          [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                               [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy Onion Rings', 'Soft Drinks'], 'name': 'Fish and Chips'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.741463
# 173                                                                                                                                                                                                    I'll have the Chicken Soup with fresh parsley and a lemon wedge, a mild coleslaw, chicken wings with buffalo, spicy, and BBQ sauces, a shrimp cocktail with lemon herb, and a cheesecake.                                                                                                                                                                                       [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                                            [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]    0.731449
# 176                                                                                                                             Can I get a Garden Salad with balsamic dressing, a side of onion rings with BBQ sauce, grilled salmon topped with garlic butter, grilled tofu with soy ginger, an iced tea that's sweetened, a scoop of mint chocolate chip ice cream, and an extra bun, please?                                                                           [{'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                            [{'customizations': ['Balsamic', 'BBQ'], 'name': 'Garden Salad'}, {'customizations': ['Onion Rings', 'BBQ'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun'}]    0.157827
# 177                                                                                                                                                                                                                                                       I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                        [{'customizations': ['Lemonade'], 'name': 'Lemonade'}, {'customizations': ['Lemon Meringue Pie'], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Chocolate'], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.711111

# %% [markdown]
# ### **Large 1b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-large-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) with quantization...
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-large-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches:  58%|█████▊    | 7/12 [05:17<05:23, 64.75s/it]
# Warning: Could not parse JSON: Expecting ',' delimiter: line 7 column 3 (char 344).
# Attempted to parse (after extraction): '[
#   { "customizations": [], "name": "Grilled Chicken Breast" },
#   { "customizations": ["Garlic Butter"], "name": "Grilled Salmon" },
#   { "customizations": ["Lemon Dill","Garlic Butter"],"name":"Grilled Tofu" },
#   { "customizations": ["Chili Lime","Soy Ginger"],"name":"Mint Chocolate Chip" },
#   { "customizations": [], "name":"Almond Milk" }
#   { "customizations": ["Oat Milk","Almond Milk"],"name":"Milk Alternatives" }
# ]'
# Inference Batches:  67%|██████▋   | 8/12 [06:00<03:51, 57.89s/it]
# Warning: Could not parse JSON: Expecting ',' delimiter: line 1 column 474 (char 473).
# Attempted to parse (after extraction): '[{"customizations":["Lemon Wedge"],"name":"Chicken Soup"},{"customizations":["No Protein"],"name":"Greek Salad"},{"customizations":["Crispy Onion Rings","Extra Crispy Fries"],"name":"Fish and Chips"},{"customizations":["Chili Lime"],"name":"Grilled Tofu"},{"customizations":[],"name":"Apple Pie"},{"customizations":[],"name":"Berry Parfait"},{"customizations":["Milk Alternatives"],"name":"Oat Milk","name":"Almond Milk"},{"customizations":["Extra Cheese"],"name":"Cheese"}}]'
# Inference Batches: 100%|██████████| 12/12 [09:12<00:00, 46.02s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.7267
# ✅ Exact Match Accuracy: 12.22%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                 transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             predicted_items  similarity
# 0    I want a Cream of Mushroom soup with truffle oil, some spring rolls with vegetarian and chicken, a portion of chicken wings with BBQ, Buffalo, and spicy sauces, a grilled chicken breast with BBQ, and a selection of soft drinks including Fanta, Coke, and Sprite. Also, add some craft beer â€” a mix of lager, pale ale, and IPA, and I'll need extra sauces like pesto and BBQ sauce.  [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ', 'Pale Ale', 'IPA'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Soft Drinks'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}]    0.704444
# 1                                                                                                                  Ordering some mozzarella sticks with marinara and ranch, a grilled chicken breast with BBQ and garlic butter, fresh juices with carrot, apple, and orange, an apple pie, and both vanilla and chocolate. Also, I'd like extra toppings of nuts, berries, and chocolate chips.                                          [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Apple Pie'], 'name': 'Apple'}, {'customizations': ['Vanilla', 'Chocolate'], 'name': 'Vanilla'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.794081
# 8                                                                                                                                                             Ordering a Caesar Salad with grilled shrimp, a mild and spicy coleslaw, a grilled chicken breast with BBQ sauce, a chocolate cake, extra pesto sauce, an extra scoop of ice cream, and milk alternatives with almond and oat milk.                                                              [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Grilled Shrimp', 'Mild', 'Spicy', 'Coleslaw'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto', 'Extra Ice Cream', 'Milk Alternatives'], 'name': 'Extra Sauce'}, {'customizations': ['BBQ Sauce'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Basil', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Garlic Sauce'], 'name': 'Grilled Tofu Bowl'}, {'customizations': ['Lemon Butter'], 'name': 'Grilled Salmon'}]    0.409586
# 10                                                                                                                                                                                I'll have a tomato soup with croutons, a miso soup with chili oil and toasted sesame seeds, a mojito cocktail, an extra topping of chocolate chips, and an extra shot of alcohol with rum, whiskey, and vodka.                                                                                                                                                     [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Tomato Soup', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Miso Soup', 'Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Mojito'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Chicken Breast', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Lemonade'], 'name': 'Lemonade'}]    0.719424
# 14                                                                                                                                                                                       I'll have a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a side of mild and spicy coleslaw, a sweetened iced tea, extra cheese, extra whipped cream, and an extra shot of vodka.                                                                                                     [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Extra Cheese', 'Extra Whipped Cream'], 'name': 'Extra Topping'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.689855
# 15                                                                                                                                                                                             I'm ordering a Cream of Mushroom with truffle oil and chopped parsley, two soft drinks â€” one Fanta and one Coke, a Pale Ale craft beer, a cheesecake, a lemon meringue pie, and some chocolate.                                                                                                                                           [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Fanta'}, {'customizations': [], 'name': 'Coke'}, {'customizations': ['Pale Ale']}, {'customizations': ['Cheesecake', 'Lemon Meringue Pie'], 'name': 'Dessert'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Extra Scoop'], 'name': 'Ice Cream'}]    0.532544
# 18                                                                               I'll have the chicken soup with a lemon wedge, grilled salmon topped with garlic butter and lemon dill. For dessert, I'd like a slice of cheesecake, and also, please include the chocolate and strawberry. Additionally, a side of fruit salad and extra sauces of gravy, pesto, and BBQ sauce would be great.                                                                                       [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Lemon Wedge', 'Garlic Butter', 'Lemon Dill'], 'name': 'Chicken Soup'}, {'customizations': ['Cheesecake'], 'name': 'Dessert'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Fruit Salad'], 'name': 'Side Dish'}, {'customizations': [], 'name': 'Extra Ice Cream'}]    0.603675
# 21                                                                                                                                                                I'll have a Chicken Soup with fresh parsley, a Caesar Salad with grilled chicken, BBQ chicken wings, grilled salmon with lemon dill and garlic butter, a spicy shrimp cocktail, and soft drinks including a Sprite and a Coke.                                                                                                [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                          [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ Chicken'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Iced Tea'}, {'customizations': ['Sweetened'], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Extra Whipped Cream'], 'name': 'Vanilla Ice Cream'}]    0.767613
# 22                                                                                                                                                                                             Caesar Salad with no protein, spicy and mild coleslaw, onion rings with BBQ sauce, iced tea half unsweetened and half sweetened, a chocolate cake, a cheesecake, and an extra scoop of ice cream.                                                                                             [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['no protein'], 'name': 'Caesar Salad'}, {'customizations': ['spicy', 'mild'], 'name': 'Coleslaw'}, {'customizations': ['onion rings', 'BBQ sauce'], 'name': 'Onion Rings'}, {'customizations': ['half unsweetened', 'half sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.634211
# 23                                                                                                                                                                                                                                                            I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                                                             [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Cheesecake', 'Lemon Meringue Pie', 'Vanilla'], 'name': 'Extra Dessert'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Ice Cream'}]    0.354610
# 26                                                                                                                                                                                                                                       Can I get a spicy coleslaw and a shrimp cocktail with lemon herb? Also, a lemonade, a mojito, a glass of rosÃ© wine, and some extra cheese on the side.                                                                                                                                                                              [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Sugar', 'Diet'], 'name': 'Lemonade'}, {'customizations': ['Margarita'], 'name': 'Mojito'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.462585
# 27                                                                                                                                                                                           Ordering Chicken Soup with a lemon wedge and fresh parsley, a Greek Salad without protein, a Margarita cocktail, a side of strawberries, extra ranch dipping sauce, and an extra bun or bread roll.                                                                                                                               [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktail'}, {'customizations': ['Strawberries'], 'name': 'Side'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['BBQ', 'Buffalo'], 'name': 'Chicken Wings'}]    0.554804
# 28                                                                                                                                                                                                                                                   Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                                                                [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Lemon Juice'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.700549
# 32                                                                                                                                                                                                            I'll have a Greek Salad with falafel, Spring Rolls with chicken, a side of chocolate, extra ranch dipping sauce, an extra scoop of ice cream, and oat milk as my milk alternative.                                                                                                                                                   [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Falafel', 'No Eggs'], 'name': 'Greek Salad'}, {'customizations': ['Chicken', 'Chicken', 'No Eggs'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternative'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'BBQ Sauce'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Pie'}]    0.763224
# 33                                                                                                                                                                                                                                                             I'll have the Shrimp Cocktail with Lemon Herb and Spicy Cocktail, a Sprite to drink, Chocolate Cake, Apple Pie, and some Vanilla.                                                                                                                                                                                                                     [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Drink'}, {'customizations': ['Chocolate Cake', 'Apple Pie', 'Vanilla'], 'name': 'Desserts'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Spicy Chicken Wings', 'BBQ Sauce', 'Ranch'], 'name': 'Chicken Wings'}, {'customizations': ['Onion Rings'], 'name': 'Potato Salad'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Chicken Breast'}]    0.361355
# 37                                                                                                                                                                            I'm ordering chicken spring rolls, grilled salmon with lemon dill and garlic butter, a sweetened iced tea, an Old Fashioned cocktail, cheesecake, mint chocolate chip, and flavored syrups in vanilla and caramel.                                                                [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                            [{'customizations': ['Chicken', 'Spring Rolls'], 'name': 'Chicken Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktail'}, {'customizations': ['Cheesecake'], 'name': 'Cheesecake'}, {'customizations': ['Mint Chocolate Chip'], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Apple Pie'], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.101266
# 39                                                                                                                                                                                                                                                                        Can I get an order of Onion Rings with BBQ and Ranch, an Apple Pie, some Chocolate, a Berry Parfait, and Extra Cheese?                                                                                                                                                                                                                                               [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Chocolate'], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Basil', 'Garlic'], 'name': 'Tomato Soup'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Broccoli'], 'name': 'Extra Side'}, {'customizations': ['Cocktail Sauce'], 'name': 'Shrimp Cocktail'}]    0.376812
# 44                                                                                                                 Getting a spicy coleslaw, crispy fries with the fish and chips, a vegetable stir-fry with peanut sauce, a vegan burger with ketchup, mustard, vegan mayo, no cheese, and vegan cheese, grilled tofu with peanut sauce, chili lime, and soy ginger, plus a lemon meringue pie.                                              [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Mayo', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Peanut Sauce', 'Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Fries', 'Fish and Chips'], 'name': 'Crispy'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Mayo', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Chili Lime', 'Soy Ginger'], 'name': 'Vegan Chili Lime'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.775604
# 46                                                                                                                                          I'll have the Cream of Mushroom with truffle oil and chopped parsley, a Miso Soup with chili oil and toasted sesame seeds, an Iced Tea both unsweetened and sweetened, a Margarita for cocktails, and some chocolate along with mint chocolate chip.                                                                                                [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Chocolate', 'Mint Chocolate Chip'], 'name': 'Dessert'}, {'customizations': ['Vanilla', 'Caramel Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Cheesecake'}]    0.712195
# 47                                                                                                      Ordering a Chicken Soup with fresh parsley, mozzarella sticks with ranch and marinara, a grilled chicken breast with BBQ sauce, fresh orange juice, and a selection of cocktails including a margarita, old fashioned, and mojito. Also, adding an extra bun and some gravy on the side.                                     [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ Sauce'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange Juice'], 'name': 'Fresh Juice'}, {'customizations': ['Margarita', 'Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]    0.657109
# 49                                                                                                                               Ordering a vegan burger with mustard, vegan mayo, and ketchup. Also getting a mix of soft drinks with Sprite and Coke, plus both sweetened and unsweetened iced tea. Don't forget a side of chocolate and some milk alternatives with almond milk and oat milk.                                                                                                                                                     [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Garlic Butter'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Grilled Chicken Breast'}, {'customizations': ['BBQ Sauce'], 'name': 'Grilled Chicken Breast'}]    0.768850
# 52                                                                                                                                                                  Please bring me some Chicken Soup with fresh parsley, a Shrimp Cocktail with spicy cocktail sauce, a Vegan Burger with vegan mayo, a slice of Lemon Meringue Pie, and an extra shot of alcohol with vodka, rum, and whiskey.                                                                                                                                                                 [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Vanilla', 'Ice Cream'], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.768647
# 53                                                                                                                                                                                                                Ordering a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a Vegan Burger with vegan cheese and ketchup, an Apple Pie, extra cheese, and an extra bun or bread roll.                                                                                                                                                                                     [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Spicy Cocktail Sauce', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Extra Cheese', 'Extra Bun or Bread Roll'], 'name': 'Extra Cheese'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Whiskey'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Cheesecake'}]    0.675900
# 57                                                                                                                                                      I'm ordering a Tomato Soup with Cheddar Cheese and Croutons, a Chocolate Cake, a Lemon Meringue Pie, Extra Whipped Cream, an Extra Topping with Berries, Chocolate Chips, and Nuts, and Milk Alternatives with Almond Milk and Oat Milk.                                                                                          [{'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                    [{'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip ice cream'}]    0.792696
# ...
# 163                                                                                                                                                                                                                             I'll have chicken and vegetarian spring rolls, fish and chips with onion rings, a cheesecake, some chocolate, a fruit salad, apple crumble, and a berry parfait.                                                                                                                     [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Fish', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Fries'], 'name': 'Side Dish'}]    0.259675
# 166                                                                                                                                                                                                                                      Spicy coleslaw, mozzarella sticks with marinara, grilled chicken breast with garlic butter, chocolate, apple crumble, and extra chocolate chips on top.                                                                                                                                            [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Mozzarella Sticks', 'Marinara'], 'name': 'Extra Cheese'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.313725
# 168                                                                                                                                                                                                                 Ordering a tomato soup with croutons and basil pesto, a Greek salad topped with grilled chicken and falafel, a strawberry, a berry parfait, and an extra scoop of ice cream.                                                                                                                                                                                            [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Tomato Soup', 'Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Strawberry'], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Ice Cream'}, {'customizations': ['Extra Scoop'], 'name': 'Ice Cream'}]    0.705128
# 170                                                           I'll have a Tomato Soup with croutons, cheddar cheese, and basil pesto, a Chicken Soup with fresh parsley, a Grilled Salmon with garlic butter and lemon dill, Fish and Chips extra crispy with fries, crispy onion rings, and some soft drinks including Coke, Sprite, and Fanta. Also add almond milk for the milk alternatives.                   [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        None    0.000000
# 171                                                                                                                                                                                                                         I'll have coleslaw with mild sauce, grilled tofu with soy ginger, peanut sauce, and chili lime, a glass of white wine, chocolate, and mint chocolate chip ice cream.                                                                                                                                                                                                        [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Mild', 'Soy Ginger'], 'name': 'Coleslaw'}, {'customizations': ['Grilled Tofu', 'Soy Ginger'], 'name': 'Tofu with Soy Ginger'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'White Wine'}, {'customizations': ['Chocolate'], 'name': 'Chocolate'}, {'customizations': ['Mint Chocolate Chip', 'Ice Cream'], 'name': 'Mint Chocolate Chip'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}]    0.145161
# 174                                                                                                                                                                                                   Grilled Chicken Breast with BBQ sauce, a Fresh Carrot Juice, Craft Beer featuring both IPA and Lager, a slice of Chocolate Cake, a Berry Parfait, and Almond Milk for my milk alternative.                                                                                                                                               [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]  [{'customizations': ['BBQ Sauce'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot Juice'], 'name': 'Fresh Carrot Juice'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternative'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Shrimp Cocktail'], 'name': 'Grilled Shrimp'}, {'customizations': ['Onion Rings', 'BBQ Sauce'], 'name': 'Grilled Chicken'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Grilled Chicken Salad'}, {'customizations': ['Blue Cheese'], 'name': 'Creamy Blue Cheese'}, {'customizations': ['Caesar Salad'], 'name': 'No Protein, Grilled Chicken'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}]    0.197574
# 175                                                                                                                                                                                       I want a Chicken Soup with fresh parsley and a lemon wedge, a side of spicy buffalo chicken wings, a carrot fresh juice, a pale ale craft beer, a chocolate cake, vanilla, and an extra shot of vodka.                                                                         [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                          [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Orange'], 'name': 'Fresh Carrot Juice'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Vodka'}, {'customizations': [], 'name': 'Mashed Potatoes'}, {'customizations': ['Fries', 'Grilled Chicken'], 'name': 'Extra Side'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.711479
# 177                                                                                                                                                                                                                                                       I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                                                                 [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Lemonade', 'Extra Cheese', 'Extra Whipped Cream'], 'name': 'Fruit and Dairy'}, {'customizations': ['Lemon Meringue Pie', 'Chocolate'], 'name': 'Dessert'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['White', 'Extra Sauce'], 'name': 'Mashed Potatoes'}]    0.228873
# 179                                                                                                                                                                        I'll have some Sprite and Fanta for the soft drinks. For craft beer, please add Pale Ale, IPA, and Lager. Also, getting an apple pie and an apple crumble. And don't forget the extra cheese and extra whipped cream.                                                                                                                                                          [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Cheese', 'Extra Whipped Cream'], 'name': 'Extra Topping'}, {'customizations': ['Grilled Salmon', 'Chicken Caesar Salad'], 'name': 'Grilled Protein'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.714483

# %% [markdown]
# ### **Small 4b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-small-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-small-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/131M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 12/12 [05:34<00:00, 27.85s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9651
# ✅ Exact Match Accuracy: 55.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                             transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              predicted_items  similarity
# 86                                                   I'll have spring rolls with chicken and vegetarian, mozzarella sticks with ranch and marinara, grilled tofu with chili lime and peanut sauce, a lemonade, a slice of lemon meringue pie, extra whipped cream, and extra toppings of nuts, chocolate chips, and berries.              [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Lemonade'], 'name': 'A Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Toppings'}]    0.551564
# 106                                                          Grilled chicken breast with BBQ sauce, vegetable stir-fry with garlic soy, peanut sauce, and teriyaki, a vegan burger with vegan mayo, mint chocolate chip ice cream, extra blue cheese dipping sauce, extra whipped cream, and toppings with berries and nuts.          [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]                                                                                                                     [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese', 'Whipped Cream'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Toppings'}]    0.765700
# 116  Ordering the spicy coleslaw and onion rings with ranch. I'll also have the vegetable stir-fry with garlic soy and peanut sauce, a pale ale craft beer, and mint chocolate chip for dessert. For sides, please include fries, veggies, rice, and mashed potatoes, and don't forget the extra topping of chocolate chips.        [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Fries', 'Veggies', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                   [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.781382
# 126                                             I'll have the Chicken Soup with a lemon wedge, a Greek Salad without any protein, Fish and Chips with crispy onion rings and extra crispy fries, Grilled Tofu with chili lime, an Apple Pie, a Berry Parfait, and some milk alternatives including oat milk and almond milk.                     [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                 [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy Onion Rings', 'Extra Crispy Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.410072
# 131                                                                                                                                                                      I'll have a grilled chicken breast with garlic butter and BBQ, a lemonade, fresh carrot juice, extra cheese, almond milk, and an extra shot of rum.                                                                                                                   [{'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                    [{'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemonade', 'Carrot Juice'], 'name': 'Fresh Juices'}, {'customizations': ['Extra Cheese'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.341463
# 134                                                                                                         Caesar Salad with no protein, Grilled Chicken, and Grilled Shrimp; Grilled Chicken Breast with BBQ and Garlic Butter; Chocolate Cake; Apple Crumble; Extra Cheese; Extra Sauce with Gravy, Pesto, and BBQ Sauce.                                                                       [{'customizations': ['No Protein', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                              [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Grilled Chicken'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.736390
# 144                                                               Miso soup with chili oil and toasted sesame seeds, onion rings with ranch and BBQ, fish and chips with fries, extra crispy, onion rings, and crispy, craft beer with pale ale and lager, berry parfait, extra blue cheese dipping sauce, and extra cheese.  [{'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Fries', 'Extra Crispy', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}]  [{'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Extra Onion Rings'}, {'customizations': [], 'name': 'Crispy'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.542735
# 153                                                                                                                                                   Can I get a fresh juice with carrot, orange, and apple, a glass of white wine, a cheesecake, an extra bun or bread roll, and some chocolate chips as an extra topping?                                                                                                                                                                                  [{'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                      [{'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juice'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Bun', 'Bread Roll'], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.759358
# 158                                                                                                                                                                                       I want a shrimp cocktail with spicy cocktail sauce, an extra crispy fish and chips, a lemonade, some chocolate, and a fruit salad.                                                                                                                                                                                                            [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                          [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Lemonade'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.611111

# %% [markdown]
# ### **Large 4b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-large-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA L4
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-large-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 12/12 [08:24<00:00, 42.03s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9113
# ✅ Exact Match Accuracy: 28.33%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                      transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           predicted_items  similarity
# 7                                                                                                                                      Ordering a Shrimp Cocktail with spicy cocktail sauce, sweetened iced tea, a mix of red and rose wine, an extra side of mashed potatoes, and oat milk for the milk alternative.                                                                                                                                                                                       [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                             [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}]    0.772414
# 14                                                                                                            I'll have a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a side of mild and spicy coleslaw, a sweetened iced tea, extra cheese, extra whipped cream, and an extra shot of vodka.                                                                                                  [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                  [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['BBQ'], 'name': 'Chicken Breast'}, {'customizations': ['Mashed Potatoes'], 'name': 'Side'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}]    0.751092
# 28                                                                                                                                                                        Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                                                             [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                     [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.726761
# 33                                                                                                                                                                                  I'll have the Shrimp Cocktail with Lemon Herb and Spicy Cocktail, a Sprite to drink, Chocolate Cake, Apple Pie, and some Vanilla.                                                                                                                                                                                                                  [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}]    0.744118
# 39                                                                                                                                                                                             Can I get an order of Onion Rings with BBQ and Ranch, an Apple Pie, some Chocolate, a Berry Parfait, and Extra Cheese?                                                                                                                                                                                                                                            [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                              [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Lettuce', 'Tomato'], 'name': 'Vegan Burger'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}]    0.637640
# 45                                                                                                                                                                    Can I get a sweetened iced tea, some extra cheese, an extra bun, flavored syrups with caramel and vanilla, and oat milk as my milk alternative?                                                                                                                                                                                            [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                            [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternative'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.637824
# 49                                                    Ordering a vegan burger with mustard, vegan mayo, and ketchup. Also getting a mix of soft drinks with Sprite and Coke, plus both sweetened and unsweetened iced tea. Don't forget a side of chocolate and some milk alternatives with almond milk and oat milk.                                                                                                                                                  [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                     [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Tomato', 'Basil'], 'name': 'Pizza'}, {'customizations': ['Extra Cheese'], 'name': 'Extra Topping'}, {'customizations': ['Fresh Parsley', 'Oregano'], 'name': 'Extra Ingredients'}]    0.729191
# 51                                                                                                                      Ordering some onion rings with ranch and BBQ, a grilled chicken breast with garlic butter, shrimp cocktail with lemon herb, an extra whipped cream on the side, and an extra shot of whiskey.                                                                                                                                                                      [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                 [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Balsamic Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Cake Toppings'}]    0.755725
# 53                                                                                                                                     Ordering a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a Vegan Burger with vegan cheese and ketchup, an Apple Pie, extra cheese, and an extra bun or bread roll.                                                                                                                                                                                  [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                         [{'customizations': ['Spicy Cocktail Sauce', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Grilled', 'Medium-Rare'], 'name': 'Burger'}, {'customizations': ['Lemon Juice'], 'name': 'Lemonade'}]    0.717172
# 63                                                                                                                                                                                                    Ordering a vegan burger with mustard, cheesecake, apple pie, lemon meringue pie, strawberry, and apple crumble.                                                                                                                                                                                           [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                   [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Red Wine'], 'name': 'Bottle of Wine'}, {'customizations': ['Vegan'], 'name': 'Mac and Cheese'}, {'customizations': [], 'name': 'Fries'}]    0.724138
# 65                                                                                    Going for some spicy chicken wings and a grilled chicken breast with BBQ sauce. I'll take a glass of red wine with that. Also, I'd like some extra nuts on top and I'll need almond milk and oat milk for my milk alternatives.                                                                                                                                                                                           [{'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                        [{'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Chicken', 'Vegetable'], 'name': 'Spring Rolls'}]    0.777465
# 67                                                                                                                                                                             Ordering a Fresh Juice with Orange, Apple, and Carrot, a Craft Beer IPA, an Apple Pie, a Lemon Meringue Pie, and some Extra BBQ Sauce.                                                                                                                                                                                                         [{'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                           [{'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juice'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Mustard', 'Ketchup', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.708447
# 88                                                                                             I'll have a Greek Salad with grilled chicken, some mozzarella sticks with marinara, a couple of soft drinksâ€”Coke and Fanta, a slice of lemon meringue pie, extra cheese, and for toppings, chocolate chips and nuts.                                                                                                                       [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]                                                         [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Toppings'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Fries', 'Onion Rings'], 'name': 'Sides'}, {'customizations': ['Coleslaw'], 'name': 'Salads'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.685300
# 89                                                                                                                                                                    Miso soup with toasted sesame seeds, a Caesar salad with no protein and grilled chicken, a lemonade, a pale ale craft beer, and some chocolate.                                                                                                                                                                                                 [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                            [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternative'}]    0.682680
# 93                                                                                                                          I'll have a Tomato Soup with Cheddar Cheese, a Cream of Mushroom with Truffle Oil and Chopped Parsley, a selection of Red, White, and Rose wine, a Lemon Meringue Pie, and a Fruit Salad.                                                                                                                                                                             [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                        [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch'], 'name': 'Onion Ring'}, {'customizations': ['Lemon Juice'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla'}]    0.711990
# 113                                                                                                                                              Can I get an order of mozzarella sticks with marinara, shrimp cocktail with lemon herb and spicy cocktail, an apple pie, a lemon meringue pie, and an apple crumble?                                                                                                                                                                                                [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                            [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Mild'], 'name': 'Craft Beer'}, {'customizations': ['Citrusy'], 'name': 'IPA'}, {'customizations': ['Roasted Barley'], 'name': 'Lager'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Red'], 'name': 'Wine'}]    0.686076
# 115                                                                                                                                                                 I'll have the spicy coleslaw, grilled salmon with garlic butter, a lemonade, mint chocolate chip ice cream, and an extra shot of whiskey and rum.                                                                                                                                                                                            [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                         [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Peanut Sauce'], 'name': 'Chicken and Veggie Stir-fry'}, {'customizations': ['Mashed Potatoes'], 'name': 'Side'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}]    0.722598
# 120                                                                          Ordering Fish and Chips with extra crispy, crispy, onion rings, and fries. Also, getting a Mint Chocolate Chip and a Berry Parfait. Plus, adding an extra scoop of ice cream and extra toppings with berries, nuts, and chocolate chips.                                                                                                                                            [{'customizations': ['Extra Crispy', 'Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                            [{'customizations': ['Extra crispy', 'Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Toppings'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.798489
# 121                                                        I'll have the Cream of Mushroom with truffle oil, a Miso Soup topped with toasted sesame seeds, some onion rings with ranch and BBQ sauce, a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a slice of Lemon Meringue Pie, and a Berry Parfait.                                                                                                          [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                      [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}]    0.786592
# 123                                                                                                                                                        I'll have the crispy Fish and Chips, an Old Fashioned cocktail, a slice of Lemon Meringue Pie, extra cheese, and an extra shot of vodka, rum, and whiskey.                                                                                                                                                                                      [{'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                            [{'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Asparagus'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}]    0.727273
# 126                                      I'll have the Chicken Soup with a lemon wedge, a Greek Salad without any protein, Fish and Chips with crispy onion rings and extra crispy fries, Grilled Tofu with chili lime, an Apple Pie, a Berry Parfait, and some milk alternatives including oat milk and almond milk.                                  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                              [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy Onion Rings', 'Extra Crispy Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.410072
# 134                                                                                                  Caesar Salad with no protein, Grilled Chicken, and Grilled Shrimp; Grilled Chicken Breast with BBQ and Garlic Butter; Chocolate Cake; Apple Crumble; Extra Cheese; Extra Sauce with Gravy, Pesto, and BBQ Sauce.                                                                                    [{'customizations': ['No Protein', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Grilled Chicken'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.718881
# 144                                                        Miso soup with chili oil and toasted sesame seeds, onion rings with ranch and BBQ, fish and chips with fries, extra crispy, onion rings, and crispy, craft beer with pale ale and lager, berry parfait, extra blue cheese dipping sauce, and extra cheese.               [{'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Fries', 'Extra Crispy', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                         [{'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Onion Rings'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Extra Blue Cheese Dipping Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.482255
# 147                                                                                                                                        Order a Chicken Soup with a lemon wedge and fresh parsley, a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a lemonade, a mojito, and some vanilla for dessert.                                                                                                                                                                                         [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                    [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.774825
# 156  Get me a Cream of Mushroom with truffle oil, a grilled salmon with garlic butter, a vegetable stir-fry with peanut sauce, and a vegan burger with ketchup, no cheese, vegan mayo, and vegan cheese. For dessert, I'll have strawberry and mint chocolate chip, and add an extra shot of vodka, rum, and whiskey.  [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'No Cheese', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]  [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'No Cheese', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Orange'], 'name': 'Fresh Juice'}, {'customizations': ['Lemonade', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]    0.796099
# 158                                                                                                                                                                                I want a shrimp cocktail with spicy cocktail sauce, an extra crispy fish and chips, a lemonade, some chocolate, and a fruit salad.                                                                                                                                                                                                                         [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                                          [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}]    0.745098
# 168                                                                                                                                      Ordering a tomato soup with croutons and basil pesto, a Greek salad topped with grilled chicken and falafel, a strawberry, a berry parfait, and an extra scoop of ice cream.                                                                                                                                                                                         [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                  [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Spicy Vinaigrette'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla', 'Chocolate'], 'name': 'Ice Cream'}, {'customizations': ['Grilled Chicken Breast'], 'name': 'Grilled Chicken'}]    0.740642
# 177                                                                                                                                                                            I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                                                              [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                         [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Apple Juice'}, {'customizations': ['Spicy'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}]    0.540024

# %% [markdown]
# ### **Small 12b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-small-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# config.json:   0%|          | 0.00/916 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/109k [00:00<?, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/4.60G [00:00<?, ?B/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-small-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/274M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 12/12 [19:37<00:00, 98.08s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9718
# ✅ Exact Match Accuracy: 51.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                               items                                                                                                                                                                                                                                                                                                                                                                                                                                               predicted_items  similarity
# 38              I'm ordering a Garden Salad with balsamic and ranch dressing, Spring Rolls with a mix of vegetarian and chicken, some spicy Chicken Wings with BBQ and buffalo sauce, Grilled Salmon with lemon dill, Fish and Chips that are crispy with fries, and to finish, an Apple Pie.                                                                  [{'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}]                                                               [{'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo'], 'name': 'Spicy Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}]    0.703081
# 56                                                                 I'll have the chicken soup with fresh parsley and a lemon wedge, spring rolls with chicken, fish and chips with fries and crispy onion rings, a lemonade, a chocolate cake, a chocolate, and flavored syrups with vanilla.                                    [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                         [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken', 'Fish'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Crispy Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.285714
# 126              I'll have the Chicken Soup with a lemon wedge, a Greek Salad without any protein, Fish and Chips with crispy onion rings and extra crispy fries, Grilled Tofu with chili lime, an Apple Pie, a Berry Parfait, and some milk alternatives including oat milk and almond milk.  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy Onion Rings', 'Extra Crispy Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.410072
# 160  I'll have some chicken wings with BBQ, spicy, and buffalo sauce, a grilled salmon with lemon dill, a vegetable stir-fry with teriyaki sauce, and a berry parfait. Also, please add extra cheese, extra BBQ sauce, and pesto for sauces, and a bit of extra whipped cream on the parfait.                [{'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                     [{'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.725275
# 164                                                      Ordering Fish and Chips with onion rings, crispy fries, and extra crispy. Also getting a lemonade, vanilla ice cream, mint chocolate chip ice cream, an extra scoop of ice cream, and I'll go with oat milk for my milk alternative.                                                                                            [{'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                 [{'customizations': ['Onion Rings', 'Crispy Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Lemonade'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.356083

# %% [markdown]
# ### **Large 12b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-large-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-large-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/274M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 12/12 [16:35<00:00, 82.94s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8859
# ✅ Exact Match Accuracy: 27.22%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                        transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                               items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       predicted_items  similarity
# 2                               I'll have the Cream of Mushroom with chopped parsley and truffle oil, a lemonade, fresh juices mixed with carrot and orange, a craft beer with lager and pale ale, and a side of extra dipping sauce with ranch. Also, throw in the strawberry and extra whipped cream.                             [{'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                [{'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.738938
# 7                                                                                                                        Ordering a Shrimp Cocktail with spicy cocktail sauce, sweetened iced tea, a mix of red and rose wine, an extra side of mashed potatoes, and oat milk for the milk alternative.                                                                                                                                                       [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternative'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.791429
# 9                                                                                     Order a Cream of Mushroom with truffle oil and chopped parsley, a side of onion rings with ranch and BBQ sauce, an iced tea that's sweetened, a refreshing lemonade, and some fresh juices with orange and apple.                                                                                                                                              [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                                                                [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.706897
# 23                                                                                                                                                                   I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                          [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                              [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}]    0.726552
# 26                                                                                                                                              Can I get a spicy coleslaw and a shrimp cocktail with lemon herb? Also, a lemonade, a mojito, a glass of rosÃ© wine, and some extra cheese on the side.                                                                                                                                           [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.798295
# 28                                                                                                                                                          Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                             [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                      [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.688000
# 33                                                                                                                                                                    I'll have the Shrimp Cocktail with Lemon Herb and Spicy Cocktail, a Sprite to drink, Chocolate Cake, Apple Pie, and some Vanilla.                                                                                                                                                                                  [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                         [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Mashed Potatoes'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}]    0.633292
# 39                                                                                                                                                                               Can I get an order of Onion Rings with BBQ and Ranch, an Apple Pie, some Chocolate, a Berry Parfait, and Extra Cheese?                                                                                                                                                                                                            [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                    [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.617687
# 40                                                                                                                                                A Greek salad with falafel, mozzarella sticks with ranch, a fruit salad, extra dipping sauces of ranch and blue cheese, and some extra whipped cream.                                                                                                                                                             [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                           [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauces'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.692794
# 45                                                                                                                                                      Can I get a sweetened iced tea, some extra cheese, an extra bun, flavored syrups with caramel and vanilla, and oat milk as my milk alternative?                                                                                                                                                            [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                               [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauces'}]    0.675291
# 51                                                                                                        Ordering some onion rings with ranch and BBQ, a grilled chicken breast with garlic butter, shrimp cocktail with lemon herb, an extra whipped cream on the side, and an extra shot of whiskey.                                                                                                                                      [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dressing'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.772432
# 52                                                                         Please bring me some Chicken Soup with fresh parsley, a Shrimp Cocktail with spicy cocktail sauce, a Vegan Burger with vegan mayo, a slice of Lemon Meringue Pie, and an extra shot of alcohol with vodka, rum, and whiskey.                                                                                                                              [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.683915
# 60                                                                                   Can I get a spicy coleslaw and some onion rings with BBQ and ranch sauce? Also, please include a mix of Sprite and Coke. For dessert, I'll take some strawberries and I need almond milk for my milk alternatives.                                                                                                                                                             [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                        [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': [], 'name': 'Chocolate Ice Cream'}, {'customizations': ['Sprinkles', 'Chocolate Chips'], 'name': 'Ice Cream Toppings'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.696452
# 63                                                                                                                                                                                      Ordering a vegan burger with mustard, cheesecake, apple pie, lemon meringue pie, strawberry, and apple crumble.                                                                                                                                                           [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}]                            [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Coleslaw'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternative'}]    0.547643
# 67                                                                                                                                                               Ordering a Fresh Juice with Orange, Apple, and Carrot, a Craft Beer IPA, an Apple Pie, a Lemon Meringue Pie, and some Extra BBQ Sauce.                                                                                                                                                                         [{'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juice'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Fanta'], 'name': 'Soft Drinks'}]    0.762463
# 68                                                                                                                             Can I get a Cream of Mushroom with truffle oil, an apple pie, extra cheese, flavored syrups with caramel, and some milk alternatives including almond milk and oat milk?                                                                                                                                                           [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                         [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Garlic Butter', 'Lemon Herb'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.734043
# 70                                                                                                                        I'll have the Cream of Mushroom with truffle oil, an unsweetened and sweetened iced tea, a slice of chocolate cake, a chocolate bar, an extra bun, and a drink with oat milk.                                                                                                   [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                     [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate Bar'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.672150
# 77   Ordering the Cream of Mushroom with truffle oil and chopped parsley, a Greek Salad topped with grilled chicken and falafel, a Shrimp Cocktail with lemon herb, a refreshing Apple juice, and a selection of craft beers including IPA, pale ale, and lager. Also adding a fruit salad on the side.                                                       [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Coffee'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]    0.798701
# 79                                                                           Caesar Salad with grilled chicken and grilled shrimp, vegetarian and chicken spring rolls, unsweetened and sweetened iced tea, mint chocolate chip ice cream, an extra bun or bread roll, and an extra scoop of ice cream.                                                         [{'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.162450
# 82                                                                                                                                         Ordering a Greek Salad with grilled chicken and falafel, a cheesecake, an apple pie, a fruit salad, an extra scoop of ice cream, and an extra shot of vodka.                                                                                                        [{'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                      [{'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Strawberry Ice Cream'}]    0.745476
# 83                                                                                             I'll have a Mojito, an Old Fashioned, and a Margarita for cocktails. For wine, please get me a RosÃ© and a White. I'll take some cheesecake and chocolate as well. And I'll need oat milk for my drinks.                                                                                                                                                                [{'customizations': ['Mojito', 'Old Fashioned', 'Margarita'], 'name': 'Cocktails'}, {'customizations': ['Rose', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                        [{'customizations': ['Mojito', 'Old Fashioned', 'Margarita'], 'name': 'Cocktails'}, {'customizations': ['Rose', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate'}]    0.612903
# 95                                                                                                                                                       I'll have coleslaw with mild dressing, a lemonade, a lager craft beer, a margarita cocktail, a cheesecake, and some extra gravy sauce, please.                                                                                                                                                     [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                        [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}]    0.743009
# 99                                                                                                                                I'll have an Apple Pie, a Lemon Meringue Pie, and a Strawberry. Also, please add a Fruit Salad, with extra Pesto sauce on the side. For drinks, I prefer Almond Milk.                                                                                                                                            [{'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['No Cheese', 'Lettuce', 'Tomato', 'Vegan Mayo'], 'name': 'Vegan Burger'}]    0.752941
# 107                                                                                        Need a Shrimp Cocktail with Lemon Herb, Grilled Tofu with Soy Ginger, a mix of Mojito, Margarita, and Old Fashioned cocktails, an Apple Pie, and some Extra Topping with Chocolate Chips, Nuts, and Berries.                                                                                                                    [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                               [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.755448
# 113                                                                                                                                Can I get an order of mozzarella sticks with marinara, shrimp cocktail with lemon herb and spicy cocktail, an apple pie, a lemon meringue pie, and an apple crumble?                                                                                                                                                                [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                     [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.633918
# 123                                                                                                                                          I'll have the crispy Fish and Chips, an Old Fashioned cocktail, a slice of Lemon Meringue Pie, extra cheese, and an extra shot of vodka, rum, and whiskey.                                                                                                                                                      [{'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                             [{'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}]    0.704403
# 125                                                                                                                     I'll take some vegetarian spring rolls, onion rings with ranch, a grilled chicken breast with BBQ, a lemonade, strawberries, and extra dipping sauces of ranch and blue cheese.                                                                                                            [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                     [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Chocolate Chips'], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}]    0.730813
# 126                        I'll have the Chicken Soup with a lemon wedge, a Greek Salad without any protein, Fish and Chips with crispy onion rings and extra crispy fries, Grilled Tofu with chili lime, an Apple Pie, a Berry Parfait, and some milk alternatives including oat milk and almond milk.  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                               [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Extra Crispy Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Garlic Soy'], 'name': 'Vegetable Stir-fry'}]    0.422947
# ...
# 131                                                                                                                                                 I'll have a grilled chicken breast with garlic butter and BBQ, a lemonade, fresh carrot juice, extra cheese, almond milk, and an extra shot of rum.                                                                                                [{'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                     [{'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot'], 'name': 'Fresh Juice'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Berries'], 'name': 'Cheesecake Topping'}, {'customizations': ['Chocolate Frosting'], 'name': 'Chocolate Cake'}, {'customizations': ['Mashed Potatoes'], 'name': 'Side Dish'}]    0.710441
# 132                                                                                                      I want a Chicken Soup with fresh parsley and a lemon wedge, some mozzarella sticks with marinara, a Coke and a Fanta to drink, a strawberry, and a fruit salad. Also, please add extra cheese.                                                                                                            [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                              [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.793017
# 136                                                                                                Can I get a Caesar Salad with grilled chicken and grilled shrimp, a Greek Salad with grilled chicken and falafel, a glass of white wine, a cheesecake, and some caramel and vanilla flavored syrups?                                                                                                      [{'customizations': ['No Protein', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                              [{'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}]    0.712753
# 140                                                                                                                                                           I'll have a Vegetable Stir-fry with teriyaki and peanut sauce, a lager craft beer, some chocolate, extra cheese, and extra whipped cream.                                                                                                                                                                           [{'customizations': ['Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                   [{'customizations': ['Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.638821
# 147                                                                                                                          Order a Chicken Soup with a lemon wedge and fresh parsley, a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a lemonade, a mojito, and some vanilla for dessert.                                                                                                                                                         [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                           [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mint', 'Lime Juice'], 'name': 'Mojito'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Rose', 'White'], 'name': 'Wine'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}]    0.638889
# 158                                                                                                                                                                  I want a shrimp cocktail with spicy cocktail sauce, an extra crispy fish and chips, a lemonade, some chocolate, and a fruit salad.                                                                                                                                                                                         [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]    0.716981
# 168                                                                                                                        Ordering a tomato soup with croutons and basil pesto, a Greek salad topped with grilled chicken and falafel, a strawberry, a berry parfait, and an extra scoop of ice cream.                                                                                                                                                         [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Mashed Potatoes'}, {'customizations': ['Red'], 'name': 'Wine'}]    0.793696
# 173                                                                                                           I'll have the Chicken Soup with fresh parsley and a lemon wedge, a mild coleslaw, chicken wings with buffalo, spicy, and BBQ sauces, a shrimp cocktail with lemon herb, and a cheesecake.                                                                                                                                             [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                           [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Pesto', 'Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.716418
# 177                                                                                                                                                              I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                              [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.725522
# 179                                                                               I'll have some Sprite and Fanta for the soft drinks. For craft beer, please add Pale Ale, IPA, and Lager. Also, getting an apple pie and an apple crumble. And don't forget the extra cheese and extra whipped cream.                                                                                                                       [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                 [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}]    0.780612

# %% [markdown]
# # **Load Large Dataset**

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-large-clean-12k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1200, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-large-clean-12k' (split: 'train')...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Resolving data files:   0%|          | 0/24 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/22 [00:00<?, ?it/s]
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1200
# })
# Splitting dataset into train and validation sets...
# Train set size: 1080
# Validation set size: 120
# WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.

# %% [markdown]
# ### **Small 1b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-small-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 64

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
    attn_implementation="eager"
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) with quantization...
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-small-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 64)...
# Inference Batches:  50%|█████     | 1/2 [01:44<01:44, 104.63s/it]
# Warning: Could not parse JSON: Expecting ',' delimiter: line 1 column 470 (char 469).
# Attempted to parse (after extraction): '[{"customizations":["Ranch","Blue Cheese"],"name":"Extra Dipping Sauce"},{"customizations":[],"name":"Fruit Salad"},{"customizations":["Apple"],"name":"Fresh Juices"},{"customizations":[],"name":"Berry Parfait"},{"customizations":[],"name":"Chocolate"},{"customizations":["Fanta"],"name":"Soft Drinks"},{"customizations":["Whiskey","Vodka","Rum"],"name":"Extra Shot of Alcohol"},{"customizations":["Greek"],"name":"Salad"},{"customizations":["Shrimp"],"name":"Cocktail"]'
# Warning: Could not parse JSON: Invalid control character at: line 1 column 612 (char 611).
# Attempted to parse (after extraction): '[{"customizations":["IPA","Craft Beer"],"name":"Craft Beer"},{"customizations":["Vegetarian","Chicken"],"name":"Spring Rolls"},{"customizations":["Mild","Spicy"],"name":"Coleslaw"},{"customizations":["Ranch","BBQ"],"name":"Onion Rings"},{"customizations":["Garlic Soy","Teriyaki","Peanut Sauce"],"name":"Vegetable Stir-fry"},{"customizations":["Chopped Parsley"],"name":"Cream of Mushroom"},{"customizations":["Ranch","Blue Cheese"],"name":"Extra Dipping Sauces"},{"customizations":[],"name":"Chocolate Cake"},{"customizations":["Shrimp","Chicken"],"name":"Grilled Shrimp Cocktail"},{"customConvertToJSONString(
# [{"customizations":["IPA","Craft Beer"],"name":"Craft Beer"},{"customizations":["Vegetarian","Chicken"],"name":"Spring Rolls"},{"customizations":["Mild","Spicy"],"name":"Coleslaw"},{"customizations":["Ranch","BBQ"],"name":"Onion Rings"},{"customizations":["Garlic Soy","Teriyaki","Peanut Sauce"],"name":"Vegetable Stir-fry"},{"customizations":["Chopped Parsley"],"name":"Cream of Mushroom"},{"customizations":["Ranch","Blue Cheese"],"name":"Extra Dipping Sauces"},{"customizations":[],"name":"Chocolate Cake"},{"customizations":["Shrimp","Chicken"],"name":"Grilled Shrimp Cocktail"},{"customizations":["String"],"name":"Caesar Salad"},{"customizations":[],"name":"Grilled Chicken"}]
# ]'
# Warning: Could not parse JSON: Expecting ':' delimiter: line 1 column 503 (char 502).
# Attempted to parse (after extraction): '[{"customizations":["BBQ sauce","gravy","pesto"],"name":"Extra Sauce"},{"customizations":["Mozzarella Sticks","Marinara"],"name":"Extra Topping"},{"customizations":["Vanilla"],"name":"Dessert"},{"customizations":["Cheddar Cheese","Croutons","Basil Pesto"],"name":"Extra Topping"},{"customizations":["Tomato Soup"],"name":"Grilled Chicken Breast"},{"customizations":["Garlic Butter"],"name":"Extra Topping"},{"customizations":["Onion Rings","Ranch","BBQ Sauce"],"name":"Extra Topping"},{"customConvert["Extra Sauce","Gravy","Pesto"],"name":"Customizations"}]'
# Warning: Could not parse JSON: Expecting ':' delimiter: line 1 column 317 (char 316).
# Attempted to parse (after extraction): '[{"customizations":["Vanilla","Caramel"],"name":"Flavored Syrups"},{"customizations":["Bun"],"name":"Extra Bun"},{"customizations":["Chicken Soup"],"name":"Fresh Parsley"},{"customizations":["Cream of Mushroom"],"name":"Chopped Parsley & Truffle Oil"},{"customizations":["Vegan Burger"],"name":"Vegan Mayo","Ketchup","No Cheese","Vegan Cheese","Mustard"},{"customizations":["Grilled Salmon"],"name":"Garlic Butter & Lemon Dill"},{"customizations":["Sweetened Iced Tea"],"name":"Iced Tea"},{"customconvertations":["Fruit Salad"],"name":"Fries"},{"convertations":["Caesar Salad"],"name":"Grilled Shrimp (No Protein) & Grilled Chicken?"}]'
# Inference Batches: 100%|██████████| 2/2 [03:28<00:00, 104.03s/it]
# Warning: Could not parse JSON: Expecting ',' delimiter: line 1 column 545 (char 544).
# Attempted to parse (after extraction): '[{"customizations":["Lemon Wedge","Fresh Parsley","Ranch"],"name":"Chicken Soup"},{"customizations":["Ranch","BBQ Sauce"],"name":"Onion Rings"},{"customizations":["Blue Cheese","Ranch"],"name":"Extra Dipping Sauce"},{"customizations":["Carrot","Apple","Orange"],"name":"Fresh Juices"},{"customizations":["Falafel","Grilled Chicken"],"name":"Greek Salad"},{"customizations":["Lager","IPA"],"name":"Craft Beer"},{"customizations":["Crispy"],"name":"Fish and Chips"},{"customizations":["Lemon Herb","Spicy Cocktail Sauce"],"name":"Shrimp Cocktail"]'
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.4988
# ✅ Exact Match Accuracy: 2.50%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  predicted_items  similarity
# 1                                                                                                                                                                                                                                                                                                                                         Ordering Fish and Chips with Onion Rings, an Apple Crumble, and a Berry Parfait on the side. Iâ€™ll have sweetened Iced Tea and a drink with an extra shot of Rum. Please add some Vanilla, extra toppings of Berries, and extra BBQ Sauce and Gravy.                                                                                                                                                                                                                                                                    [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Onion Rings', 'Sweetened Iced Tea', 'Rum'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Vanilla', 'Berries'], 'name': 'Extra Toppings'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]    0.381333
# 2                                                                                                                                                                                                                                                                                                               Order a Chocolate Cake, an Extra Ice Cream Scoop, a Vegan Burger with Ketchup, an Iced Tea that's sweetened, a Fruit Salad, an Apple Crumble, and a Chicken Soup with a lemon wedge and fresh parsley. Also, add an Extra Topping of chocolate chips and an Extra Side of rice.                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             None    0.000000
# 3                                                                                                                                                                                                                                                           Can I get an apple crumble and a lemonade? Also, I'd like a vegan burger with ketchup and vegan mayo, along with mozzarella sticks served with ranch. Please add a vegetable stir-fry with teriyaki sauce, a fruit salad, and a lemon meringue pie. Also, throw in an apple pie and some extra sauces: pesto, BBQ sauce, and gravy.                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Apple Crumble', 'Lemonade'], 'name': 'Customization 1'}, {'customizations': ['Vegetable Stir-fry', 'Fruit Salad', 'Lemon Meringue Pie'], 'name': 'Customization 2'}, {'customizations': [], 'name': 'Extra Sauce'}]    0.295224
# 4                                                                                                                                                                                                        Coleslaw with a spicy kick, cream of mushroom soup topped with truffle oil and chopped parsley, mint chocolate chip ice cream, garden salad with ranch and vinaigrette dressings, grilled salmon with lemon dill and garlic butter, chicken soup garnished with fresh parsley, a pale ale craft beer, extra whipped cream, and a mix of soft drinks including Fanta, Coke, and Sprite.                                                                                                                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Spicy Kick'], 'name': 'Coleslaw'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom Soup'}, {'customizations': ['Soft Drinks'], 'name': 'Sprite'}]    0.110512
# 5                                                                                                                                                                                                                                                                              Can I get a Sprite, mild coleslaw, an extra shot of rum and vodka, ranch dipping sauce, vegetable stir-fry with teriyaki and garlic soy, chicken soup with a lemon wedge and fresh parsley, an extra bun or bread roll, a slice of lemon meringue pie, and milk alternatives including almond milk and oat milk?                                                                                                                                                            [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                              [{'customizations': ['Sprite', 'Mild'], 'name': 'Soft Drinks'}, {'customizations': ['Coleslaw'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shots'}, {'customizations': ['Ranch'], 'name': 'Dipping Sauce'}, {'customizations': ['Vegetable'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Soup'}, {'customizations': ['Bun', 'Bread Roll'], 'name': 'Extra Side'}, {'customizations': ['Lemon Meringue Pie'], 'name': 'Dessert'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.245161
# 6                                                                                                                                                                                                                                                                                 Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                                                                                                       [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Extra Whipped Cream'], 'name': 'Drink'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.125333
# 7                                                                                                                                                                                                                                                                                                                          I'll have some mozzarella sticks with marinara, a lemonade, a fruit salad, vegetable stir-fry with teriyaki, a lemon meringue pie, a Greek salad with grilled chicken, a garden salad with ranch, grilled salmon with lemon dill, and mint chocolate chip ice cream.                                                                                                                                                                                                                                         [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                               [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Lemonade'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Greek Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Lemon Dill'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.697309
# 9                                                                                                                                                                                                                                                                                                                                           I want a chocolate, a bottle of white wine, some vegetarian spring rolls, an extra side of rice, vegetable stir-fry with peanut sauce, blue cheese for dipping, a Caesar salad with grilled chicken, an extra scoop of ice cream, and an apple pie.                                                                                                                                                                                                                           [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                              [{'customizations': ['Chocolate'], 'name': 'Mousse'}, {'customizations': ['White Wine'], 'name': 'Wine'}, {'customizations': ['Vegetarian Spring Rolls'], 'name': 'Chicken Rolls'}, {'customizations': [], 'name': 'Extra Rice'}, {'customizations': ['Peanut Sauce'], 'name': 'Chicken'}, {'customizations': [], 'name': 'Grilled Chicken'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}]    0.344207
# 11                                                                                                                                                                                                                                                                                                          I'll have a chocolate cake, mint chocolate chip ice cream, chicken and vegetarian spring rolls, an extra bun, apple crumble, a Greek salad with grilled chicken, fish and chips with onion rings, grilled tofu with soy ginger, spicy shrimp cocktail, and an unsweetened iced tea.                                                                                                                                    [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]                                                                                                                                                                                                                                                          [{'customizations': ['Chocolate Cake'], 'name': 'Chocolate Cake'}, {'customizations': ['Mint Chocolate Chip'], 'name': 'Mint Chocolate Chip Ice Cream'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'Fish and Chips', 'Onion Rings'], 'name': 'Greek Salad'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]    0.241824
# 12                                                                                                                                                                                                                                              One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                                                                                                  [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]                                                                                                                                                                                                                                       [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Extra Whipped Cream'}]    0.699620
# 13                                                                                                                                                                                                                                                                                                                                                                         Berry Parfait, Onion Rings with BBQ, Extra Cheese, Apple Pie, Cheesecake, Cream of Mushroom with chopped parsley, Flavored Syrups in caramel and vanilla, and Extra Topping with nuts, berries, and chocolate chips.                                                                                                                                                                                                                                                                                   [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Berry'], 'name': 'Parfait'}, {'customizations': ['Onion Rings', 'BBQ'], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.747368
# 15                                                                                                                                                                                                                                                                                                           I'll take some extra dipping sauce with ranch and blue cheese, a fruit salad, fresh apple juice, a berry parfait, a chocolate treat, a Fanta soft drink, an extra shot of alcohol with whiskey, vodka, and rum, a Greek salad with falafel, and a shrimp cocktail with lemon herb.                                                                                                                                                                                                                     [{'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             None    0.000000
# 17                                                                                                                                                                                                                             I'll have the tomato soup with croutons and cheddar cheese, a mild coleslaw, vegetable stir-fry with peanut sauce, teriyaki, and garlic soy, a vegan burger with vegan cheese and mustard, oat milk and almond milk as my milk alternatives, a fresh orange juice, grilled salmon with lemon dill, a slice of chocolate cake, and some strawberries on the side.                                                                                                                                                             [{'customizations': ['Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Peanut Sauce', 'Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vegan Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Strawberry'}]                                              [{'customizations': ['Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Peanut Sauce', 'Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vegan Cheese', 'Mustard', 'Garlic Soy'], 'name': 'Burger'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Fresh Orange Juice'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Slice of Chocolate Cake'}, {'customizations': ['Strawberries'], 'name': 'Topping'}, {'customizations': [], 'name': 'Unspecified Milk Alternatives'}]    0.708688
# 20                                                                                                                                                                                                                                         I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                                                                                                       [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                       [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine Selection'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Caesar', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Salads'}, {'customizations': [], 'name': 'Miso Soup with Toasted Sesame Seeds'}]    0.650678
# 21                                                                                                                                                                                                                                                             Spring Rolls vegetarian, Fish and Chips extra crispy with fries and onion rings, unsweetened and sweetened iced tea, spicy coleslaw, Grilled Salmon with lemon dill and garlic butter, extra ice cream scoop, a mix of rosÃ©, white, and red wine, mint chocolate chip ice cream, and mozzarella sticks with marinara and ranch.                                                                                                                                         [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Crispy', 'Fries', 'Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Rose', 'White', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}]                                                                                                                   [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Extra Crispy', 'Fries', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Grilled'], 'name': 'Salmon'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Extra Ice Cream'}, {'customizations': ['Rosé', 'White', 'Red'], 'name': 'Wine'}, {'customizations': ['Mint Chocolate Chip'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Extra Ice Cream'}]    0.401770
# 22                                                                                                                                                                                                                                                                                                                                                                                                  Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                                                                                                   [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito', 'Lemon Meringue Pie'], 'name': 'Cocktails'}, {'customizations': ['Sprite', 'Old Fashioned', 'Mojito', 'Lemon Meringue Pie'], 'name': 'Milk Alternatives'}]    0.302671
# 23                                                                                                   I'll have a Craft Beer IPA, a mix of Vegetarian and Chicken Spring Rolls, Coleslaw with both Mild and Spicy, Onion Rings with Ranch and BBQ sauces, Vegetable Stir-fry with Garlic Soy, Teriyaki, and Peanut Sauce, a Cream of Mushroom topped with Chopped Parsley, Extra Dipping Sauces of Ranch and Blue Cheese, a slice of Chocolate Cake, Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, and a Caesar Salad without protein, plus both Grilled Shrimp and Grilled Chicken.                              [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             None    0.000000
# 24                                                                                                                                                                                                                                                                                                            One vanilla, vegetable stir-fry with garlic soy, peanut sauce, and teriyaki, a fruit salad, tomato soup with cheddar cheese, basil pesto, and croutons, extra dipping sauces with ranch and blue cheese, mint chocolate chip, cheesecake, and cream of mushroom with truffle oil.                                                                                                                                                                                                                               [{'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}]                                                                                                                                                                                                        [{'customizations': ['Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Vegetable Stir-fry'], 'name': 'Garlic Soy Peanut Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Tomato Soup'], 'name': 'Cheddar Cheese'}, {'customizations': [], 'name': 'Basil Pesto'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Truffle Oil'], 'name': 'Extra Dipping Sauce'}]    0.640496
# 25                                                                                                                                                                                                                        Can I get a Coke, BBQ onion rings, a slice of chocolate cake, a grilled chicken breast with garlic butter, a grilled salmon with garlic butter and lemon dill, grilled tofu with peanut sauce, soy ginger, and chili lime, a craft beer with a selection of lager, pale ale, and IPA, mozzarella sticks with ranch and marinara, spicy coleslaw, and a berry parfait?                                                                                 [{'customizations': ['Coke', 'Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                               [{'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': ['BBQ Onion Rings'], 'name': 'Vegetable Sides'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Garlic Butter'], 'name': 'Chicken'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.148760
# ...
# 110                                                                                                                                                                                                                                                   Grilled Salmon with Lemon Dill, an extra scoop of ice cream, strawberry flavor, Grilled Chicken Breast with BBQ, Miso Soup with chili oil and toasted sesame seeds, Mint Chocolate Chip, extra toppings of berries and nuts, a slice of Lemon Meringue Pie, vanilla ice cream, and spring rolls with both vegetarian and chicken options.                                                                                                                                                [{'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Lemon', 'Mint Chocolate Chip'], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vanilla'], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Dairy Free Options'}, {'customizations': [], 'name': 'Strawberry'}]    0.178660
# 111                                                                                                                                                         Can I get a Berry Parfait, a Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, a Tomato Soup with Cheddar Cheese and Basil Pesto, a Garden Salad with Vinaigrette, Balsamic, and Ranch dressing, a Lemon Meringue Pie, an extra side of Veggies, Fries, Mashed Potatoes, and Rice, a Vegan Burger with Vegan Mayo, Ketchup, no Cheese, Vegan Cheese, and Mustard, a Chocolate Cake, and a Greek Salad with Grilled Chicken?                                                                                 [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             None    0.000000
# 113                                                                                                     I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                                                                                            [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                             [{'customizations': ['Mint Chocolate Chip'], 'name': 'Raspberry Cheesecake'}, {'customizations': ['Grilled Salmon'], 'name': 'Lemon Dill'}, {'customizations': ['Vegetable Stir-fry'], 'name': 'Peanut Sauce'}, {'customizations': ['Garden Salad'], 'name': 'Vinaigrette, Balsamic, and Ranch'}, {'customizations': ['Rose', 'Red', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Buns', 'Bread Rolls'], 'name': 'Extra Topping'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.175610
# 114                                                                                                                                                                                                                                                                  I'll have a cheesecake, two cocktails (Old Fashioned and Mojito), a lemonade, an apple crumble, soft drinks with Fanta, Coke, and Sprite, an extra shot of rum, fish and chips extra crispy with onion rings and fries, a Caesar salad with grilled shrimp and grilled chicken, and a garden salad with balsamic dressing.                                                                                                                                                [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}]                                                                                                                                           [{'customizations': ['Cheesecake'], 'name': 'Cheesecake'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Lemonade'], 'name': 'Lemonade'}, {'customizations': ['Apple Crumble'], 'name': 'Apple Crumble'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Rum'}, {'customizations': ['Fish and Chips', 'Onion Rings', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Caesar Salad'], 'name': 'Caesar Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}]    0.116788
# 115                                                                                                                                                                                                                                                                                                             Ordering a Caesar salad with grilled shrimp, vegetable stir-fry with teriyaki, garlic soy, and peanut sauce, apple crumble, cheesecake, grilled salmon with lemon dill and garlic butter, strawberry, onion rings with BBQ and ranch, and soft drinks including Fanta and Coke.                                                                                                                                                                                                               [{'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Teriyaki', 'Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Teriyaki', 'Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Strawberry', 'Onion Rings'], 'name': 'Soft Drinks'}]    0.784000
# 118                                                                                                                                                                          Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.                                                                               [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Fresh Orange Juice', 'Craft Lager'], 'name': 'Beverages'}, {'customizations': ['Cokes', 'Milk Alternatives'], 'name': 'Milk Alternatives'}, {'customizations': ['Cops', 'Gainsboro'], 'name': 'Vanilla'}, {'customizations': ['Chocolate Cake'], 'name': 'Extra Topping'}]    0.246914
# 119                                                                                                                                   Ordering vegetarian spring rolls and miso soup with toasted sesame seeds. I'll also need extra dipping sauces of ranch and blue cheese, along with onion rings and ranch on the side. A vegan burger comes with no cheese, ketchup, mustard, vegan mayo, and vegan cheese. Add cream of mushroom soup with chopped parsley and truffle oil, followed by a slice of chocolate cake. Lastly, include extra pesto sauce. Two chocolate bars for dessert too.                                                                                                                                          [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Miso'], 'name': 'Soup'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Onion Rings'}, {'customizations': ['Ranch'], 'name': 'Vegan Burger'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Options'}, {'customizations': ['Cream of Mushroom Soup', 'Chopped Parsley', 'Truffle Oil'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate Bars'}]    0.443869

# %%
pip install -U transformers peft bitsandbytes accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.5)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)

# %% [markdown]
# ### **Medium 1b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-medium-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
    attn_implementation="eager"
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) with quantization...
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-medium-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches:  25%|██▌       | 1/4 [00:24<01:13, 24.52s/it]
# Warning: Could not parse JSON: Invalid control character at: line 1 column 535 (char 534).
# Attempted to parse (after extraction): '[{"customizations":["BBQ Sauce","Gravy","Pesto"],"name":"Extra Sauce"},{"customizations":["Marinara"],"name":"Mozzarella Sticks"},{"customizations":["Toasted Sesame Seeds"],"name":"Miso Soup"},{"customizations":[],"name":"Vanilla"},{"customizations":[],"name":"Mint Chocolate Chip"},{"customizations":["Ranch","BBQ Sauce"],"name":"Onion Rings"},{"customizations":["Chocolate Chips","Berries"],"name":"Extra Topping"},{"customizations":["Cheddar Cheese","Croutons","Basil Pesto"],"name":"Tomato Soup"},{"customConvertToJSONStringArray(
# {"customizations":["Garlic Butter"],"name":"Grilled Chicken Breast"},{"customizations":["Fries","Veggies"],"name":"Side"}]'
# Inference Batches: 100%|██████████| 4/4 [01:22<00:00, 20.62s/it]
# Warning: Could not parse JSON: Expecting ':' delimiter: line 1 column 587 (char 586).
# Attempted to parse (after extraction): '[{"customizations":["Cheesecake","Caesar Salad","Grilled Shrimp","Grilled Chicken","Chicken Soup","Fresh Parsley","Lemon Wedge"],"name":"Cheesecake"},{"customizations":["Grilled Shrimp","Grilled Chicken"],"name":"Caesar Salad"},{"customizations":["Fresh Parsley","Lemon Wedge"],"name":"Chicken Soup"},{"customizations":["Nuts","Chocolate Chips"],"name":"Extra Topping"},{"customizations":[],"name":"Extra Ice Cream Scoop"},{"customizations":[],"name":"Extra Bun or Bread Roll"},{"customizations":["Oat Milk","Almond Milk"],"name":"Milk Alternatives"},{"customConvertToJSONStringFormat("{json}")": "Cheesecake, Caesar Salad, Grilled Shrimp, Grilled Chicken, Chicken Soup, Fresh Parsley, Lemon Wedge"},{"customizations":["Grilled Shrimp","Grilled Chicken"],"name":"Caesar Salad"},{"customizations":["Fresh Parsley","Lemon Wedge"],"name":"Chicken Soup"},{"customizations":["Nuts","Chocolate Chips"],"name":"Extra Topping"},{"customizations":[],"name":"Extra Ice Cream Scoop"},{"customizations":[],"name":"Extra Bun or Bread Roll"},{"customizations":["Oat Milk","Almond Milk"],"name":"Milk Alternatives"},{"customizations":[],"name":"Extra Whipped Cream"}]'
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.6348
# ✅ Exact Match Accuracy: 10.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   predicted_items  similarity
# 2                                                                                                                                                                                                                                                                                                               Order a Chocolate Cake, an Extra Ice Cream Scoop, a Vegan Burger with Ketchup, an Iced Tea that's sweetened, a Fruit Salad, an Apple Crumble, and a Chicken Soup with a lemon wedge and fresh parsley. Also, add an Extra Topping of chocolate chips and an Extra Side of rice.                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Chocolate Cake', 'Extra Ice Cream Scoop', 'Vegan Burger', 'Ketchup', 'Iced Tea', 'Sweetened', 'Fruit Salad', 'Apple Crumble', 'Chicken Soup', 'Lemon Wedge', 'Fresh Parsley'], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chicken Soup', 'Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Chocolate Chips', 'Rice'], 'name': 'Extra Topping'}]    0.167121
# 5                                                                                                                                                                                                                                                                              Can I get a Sprite, mild coleslaw, an extra shot of rum and vodka, ranch dipping sauce, vegetable stir-fry with teriyaki and garlic soy, chicken soup with a lemon wedge and fresh parsley, an extra bun or bread roll, a slice of lemon meringue pie, and milk alternatives including almond milk and oat milk?                                                                                                                                                            [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Sprite', 'mild coleslaw'], 'name': 'Sprite'}, {'customizations': ['Ranch'], 'name': 'Ranch dipping sauce'}, {'customizations': ['Extra Shot of Rum', 'Vodka'], 'name': 'Extra shot of alcohol'}, {'customizations': ['Couscous'], 'name': 'Vegetable stir-fry'}, {'customizations': ['Teriyaki', 'Garlic Soy'], 'name': 'Vegetable stir-fry'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Lemon soup'}, {'customizations': [], 'name': 'Extra bun or bread roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk alternatives'}]    0.233835
# 6                                                                                                                                                                                                                                                                                 Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                                                                                                       [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Extra Whipped Cream'], 'name': 'Drink'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Mint Chocolate Chip'], 'name': 'Ice Cream'}]    0.103134
# 11                                                                                                                                                                                                                                                                                                          I'll have a chocolate cake, mint chocolate chip ice cream, chicken and vegetarian spring rolls, an extra bun, apple crumble, a Greek salad with grilled chicken, fish and chips with onion rings, grilled tofu with soy ginger, spicy shrimp cocktail, and an unsweetened iced tea.                                                                                                                                    [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Chocolate Cake', 'Mint Chocolate Chip'], 'name': 'Chocolate Cake'}, {'customizations': ['Mint Chocolate Chip', 'Chicken', 'Vegetarian'], 'name': 'Mint Chocolate Chip Ice Cream'}, {'customizations': ['Bun'], 'name': 'Chicken and Vegetarian Spring Rolls'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'Fish and Chips', 'Onion Rings'], 'name': 'Greek Salad'}, {'customizations': ['Soy Ginger'], 'name': 'Spicy Shrimp Cocktail'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]    0.196664
# 12                                                                                                                                                                                                                                              One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                                                                                                  [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.703959
# 13                                                                                                                                                                                                                                                                                                                                                                         Berry Parfait, Onion Rings with BBQ, Extra Cheese, Apple Pie, Cheesecake, Cream of Mushroom with chopped parsley, Flavored Syrups in caramel and vanilla, and Extra Topping with nuts, berries, and chocolate chips.                                                                                                                                                                                                                                                                                   [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Berry Parfait'], 'name': 'Berry Parfait'}, {'customizations': ['Onion Rings with BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Cream of Mushroom with chopped parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Flavored Syrups'], 'name': 'Caramel'}, {'customizations': ['Flavored Syrups'], 'name': 'Vanilla'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.648705
# 20                                                                                                                                                                                                                                         I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                                                                                                       [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caesar', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Extra Side'}, {'customizations': ['Miso Soup', 'Toasted Sesame Seeds'], 'name': 'Extra Topping'}]    0.735079
# 22                                                                                                                                                                                                                                                                                                                                                                                                  Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                                                                                                   [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Sprite'], 'name': 'Sprite'}, {'customizations': ['Old Fashioned'], 'name': 'Old Fashioned'}, {'customizations': ['Mojito'], 'name': 'Mojito'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.108586
# 23                                                                                                   I'll have a Craft Beer IPA, a mix of Vegetarian and Chicken Spring Rolls, Coleslaw with both Mild and Spicy, Onion Rings with Ranch and BBQ sauces, Vegetable Stir-fry with Garlic Soy, Teriyaki, and Peanut Sauce, a Cream of Mushroom topped with Chopped Parsley, Extra Dipping Sauces of Ranch and Blue Cheese, a slice of Chocolate Cake, Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, and a Caesar Salad without protein, plus both Grilled Shrimp and Grilled Chicken.                              [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]  [{'customizations': ['IPA', 'Craft Beer'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken', 'Spring Rolls'], 'name': 'Vegetarian Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chocolate Cake', 'Shrimp Cocktail', 'Lemon Herb', 'Spicy Cocktail'], 'name': 'Dessert'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Caesar Salad'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Caesar Salad'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Extra Dipping Sauce'}]    0.399088
# 25                                                                                                                                                                                                                        Can I get a Coke, BBQ onion rings, a slice of chocolate cake, a grilled chicken breast with garlic butter, a grilled salmon with garlic butter and lemon dill, grilled tofu with peanut sauce, soy ginger, and chili lime, a craft beer with a selection of lager, pale ale, and IPA, mozzarella sticks with ranch and marinara, spicy coleslaw, and a berry parfait?                                                                                 [{'customizations': ['Coke', 'Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Coke'], 'name': 'Coke'}, {'customizations': ['BBQ onion rings'], 'name': 'BBQ Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.101806
# 26                                                                                                                                                                                                                                                                     Letâ€™s order some oat milk and almond milk, an apple pie, grilled chicken breast with garlic butter, a side of strawberries, a garden salad with ranch, miso soup with chili oil and toasted sesame seeds, a refreshing lemonade, vanilla, shrimp cocktail with lemon herb and spicy cocktail sauce, and a fruit salad.                                                                                                                                                     [{'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Grilled Chicken Breast with Garlic Butter'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Miso Soup', 'Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail Sauce'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.544776
# 27                                                                                                                                                                                                                                  I'll take an extra ice cream scoop, a berry parfait, a grilled chicken breast with garlic butter, tomato soup with cheddar cheese and basil pesto, miso soup with toasted sesame seeds, fish and chips with onion rings extra crispy, grilled salmon with lemon dill and garlic butter, margarita and old fashioned cocktails, and spicy BBQ chicken wings.                                                                                                                 [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Spicy', 'BBQ'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              None    0.000000
# 28                                                                                                                                                  Iâ€™ll take a sweetened iced tea, an apple crumble, onion rings with BBQ and ranch, extra sides of veggies, fries, rice, and mashed potatoes. For the soup, I want cream of mushroom with truffle oil and chopped parsley. A berry parfait and apple pie for dessert. Iâ€™d also like the grilled salmon with garlic butter and lemon dill, a craft beer with lager, IPA, and pale ale options, and an extra bun or bread roll on the side.                                                                                 [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Veggies', 'Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Veggies', 'Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Cream of Mushroom', 'Truffle Oil', 'Chopped Parsley'], 'name': 'Soup'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Salmon', 'Garlic Butter', 'Lemon Dill'], 'name': 'Extra Bun or Bread Roll'}]    0.793226
# 30                                                                                                                             Can I get an extra bun or bread roll, some chocolate, and a bowl of tomato soup with basil pesto? Also, please add a selection of veggies, rice, and fries as an extra side. For dessert, I'll have a lemon meringue pie and an apple pie. To drink, I'd like a glass of white wine. Oh, and Iâ€™ll take some mozzarella sticks with ranch and a Caesar salad that has grilled shrimp and grilled chicken but no other protein. And thatâ€™s everything, thanks!                                                                                                                     [{'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Extra bun', 'Bread roll', 'Chocolate'], 'name': 'Extra Bun'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Tomato Soup', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['White Wine'], 'name': 'Wine'}, {'customizations': ['Mozzarella Sticks', 'Ranch'], 'name': 'Extra Side'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['White Wine'], 'name': 'Extra Drink'}]    0.410714
# 31                                                                                                                      Can I get extra sauces with BBQ sauce, gravy, and pesto? Also, please add mozzarella sticks with marinara, and a bowl of miso soup topped with toasted sesame seeds. For dessert, I'll take vanilla and mint chocolate chip. Don't forget the onion rings with ranch and BBQ sauce, plus an extra topping of chocolate chips and berries. Lastly, I'd like tomato soup with cheddar cheese, croutons, and basil pesto, and a grilled chicken breast with garlic butter.                                                                                                                                        [{'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Cheddar Cheese', 'Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              None    0.000000
# 32                                                                                                                                                                                                                                             I'll have a pizza with extra cheese, some cocktails with an Old Fashioned, a scoop of vanilla, a plate of vegetarian and chicken spring rolls, a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a cup of miso soup with chili oil, a slice of apple pie, and a garden salad with vinaigrette, balsamic, and ranch dressing.                                                                                                                                                                                                                                                      [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegetarian', 'Chicken Spring Rolls'], 'name': 'Vegetable and Chicken Rolls'}, {'customizations': ['Tomato Soup'], 'name': 'Basil Pesto, Croutons, and Cheddar Cheese'}, {'customizations': ['Miso Soup'], 'name': 'Chili Oil'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]    0.395812
# ...
# 111                                                                                                                                                         Can I get a Berry Parfait, a Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, a Tomato Soup with Cheddar Cheese and Basil Pesto, a Garden Salad with Vinaigrette, Balsamic, and Ranch dressing, a Lemon Meringue Pie, an extra side of Veggies, Fries, Mashed Potatoes, and Rice, a Vegan Burger with Vegan Mayo, Ketchup, no Cheese, Vegan Cheese, and Mustard, a Chocolate Cake, and a Greek Salad with Grilled Chicken?                                                                                 [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Berry Parfait'], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard'], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vegan Burger', 'Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}]    0.066819
# 113                                                                                                     I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                                                                                            [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Mint Chocolate Chip'], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Grilled Salmon', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red', 'IPA'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.432806
# 114                                                                                                                                                                                                                                                                  I'll have a cheesecake, two cocktails (Old Fashioned and Mojito), a lemonade, an apple crumble, soft drinks with Fanta, Coke, and Sprite, an extra shot of rum, fish and chips extra crispy with onion rings and fries, a Caesar salad with grilled shrimp and grilled chicken, and a garden salad with balsamic dressing.                                                                                                                                                [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Cheesecake'], 'name': 'Cheesecake'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Rum'}, {'customizations': ['Fish and Chips', 'Extra Crispy', 'Onion Rings', 'Fries'], 'name': 'Extra Crispy Sides'}, {'customizations': ['Caesar Salad', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Grilled Protein'}, {'customizations': ['Balsamic'], 'name': 'Extra Salad Dressing'}]    0.070175
# 117                                                                                                                                                                                                                                                                                    I want a chocolate, a Caesar salad with grilled chicken and grilled shrimp, craft beer with lager and IPA, mozzarella sticks with ranch and marinara, lemon meringue pie, an extra shot of alcohol with rum and vodka, soft drinks including Fanta, Sprite, and Coke, vanilla, cheesecake, and lemonade.                                                                                                                                         [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Fanta', 'Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemonade'}]                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Chocolate', 'Caesar Salad', 'Grilled Chicken', 'Grilled Shrimp', 'Craft Beer', 'Lager', 'IPA', 'Mozzarella Sticks', 'Ranch', 'Marinara'], 'name': 'Chocolate'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'Craft Beer', 'Lager', 'IPA', 'Mozzarella Sticks', 'Ranch', 'Marinara'], 'name': 'Caesar Salad'}, {'customizations': ['Lager', 'IPA', 'Pale Ale', 'Craft Beer'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Fanta', 'Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemonade'}]    0.648485
# 118                                                                                                                                                                          Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.                                                                               [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Fresh Orange Juice', 'Craft Lager'], 'name': 'Beverages'}, {'customizations': ['Cream of Mushroom', 'Chopped Parsley'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrup'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.222026
# 119                                                                                                                                   Ordering vegetarian spring rolls and miso soup with toasted sesame seeds. I'll also need extra dipping sauces of ranch and blue cheese, along with onion rings and ranch on the side. A vegan burger comes with no cheese, ketchup, mustard, vegan mayo, and vegan cheese. Add cream of mushroom soup with chopped parsley and truffle oil, followed by a slice of chocolate cake. Lastly, include extra pesto sauce. Two chocolate bars for dessert too.                                                                                                                                          [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Miso Soup'], 'name': 'Toasted Sesame Seeds'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Onion Rings', 'Ranch'], 'name': 'Extra Side Dish'}, {'customizations': ['Vegan Burger', 'No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Options'}, {'customizations': ['Cream of Mushroom Soup'], 'name': 'Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Chocolate Bars'], 'name': 'Dessert'}]    0.364583

# %% [markdown]
# ### **Small 4b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-small-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
    attn_implementation="eager"
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-4b-it...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) with quantization...
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-small-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/131M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:21<00:00, 20.28s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8598
# ✅ Exact Match Accuracy: 20.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         predicted_items  similarity
# 1                                                                                                                                                                                                                                      Ordering Fish and Chips with Onion Rings, an Apple Crumble, and a Berry Parfait on the side. Iâ€™ll have sweetened Iced Tea and a drink with an extra shot of Rum. Please add some Vanilla, extra toppings of Berries, and extra BBQ Sauce and Gravy.                                                                                                                                                                                                            [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened Iced Tea'], 'name': 'Drinks'}, {'customizations': ['Vanilla'], 'name': 'Extra Toppings'}, {'customizations': ['Berries'], 'name': 'Extra Toppings'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]    0.677966
# 6                                                                                                                                                                              Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                                               [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                              [{'customizations': ['Extra Whipped Cream'], 'name': 'Drink'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.104294
# 12                                                                                                                                           One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                                          [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]                                                                                          [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Extra Cheese'], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Extra Whipped Cream', 'Vanilla'], 'name': 'Extra Toppings'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.162304
# 13                                                                                                                                                                                                                                                                      Berry Parfait, Onion Rings with BBQ, Extra Cheese, Apple Pie, Cheesecake, Cream of Mushroom with chopped parsley, Flavored Syrups in caramel and vanilla, and Extra Topping with nuts, berries, and chocolate chips.                                                                                                                                                                                                                           [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                             [{'customizations': ['Berry Parfait'], 'name': 'Berry Parfait'}, {'customizations': ['Onion Rings with BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Extra Cheese'], 'name': 'Extra Cheese'}, {'customizations': ['Apple Pie'], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.264929
# 20                                                                                                                                      I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                                               [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                               [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla Ice Cream'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.714740
# 22                                                                                                                                                                                                                                                                                               Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                                           [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 27                                                                                                                               I'll take an extra ice cream scoop, a berry parfait, a grilled chicken breast with garlic butter, tomato soup with cheddar cheese and basil pesto, miso soup with toasted sesame seeds, fish and chips with onion rings extra crispy, grilled salmon with lemon dill and garlic butter, margarita and old fashioned cocktails, and spicy BBQ chicken wings.                                                         [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Spicy', 'BBQ'], 'name': 'Chicken Wings'}]                                      [{'customizations': ['Extra Ice Cream Scoop'], 'name': 'Extra Ice Cream'}, {'customizations': ['Berry Parfait'], 'name': 'Parfaits'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Spicy BBQ'], 'name': 'Chicken Wings'}]    0.119328
# 30                          Can I get an extra bun or bread roll, some chocolate, and a bowl of tomato soup with basil pesto? Also, please add a selection of veggies, rice, and fries as an extra side. For dessert, I'll have a lemon meringue pie and an apple pie. To drink, I'd like a glass of white wine. Oh, and Iâ€™ll take some mozzarella sticks with ranch and a Caesar salad that has grilled shrimp and grilled chicken but no other protein. And thatâ€™s everything, thanks!                                                             [{'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                         [{'customizations': ['Extra Bun', 'Bread Roll'], 'name': 'Extra Bread'}, {'customizations': ['Chocolate'], 'name': 'Chocolate'}, {'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['White Wine'], 'name': 'Wine'}, {'customizations': ['Mozzarella Sticks', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]    0.556054
# 31                   Can I get extra sauces with BBQ sauce, gravy, and pesto? Also, please add mozzarella sticks with marinara, and a bowl of miso soup topped with toasted sesame seeds. For dessert, I'll take vanilla and mint chocolate chip. Don't forget the onion rings with ranch and BBQ sauce, plus an extra topping of chocolate chips and berries. Lastly, I'd like tomato soup with cheddar cheese, croutons, and basil pesto, and a grilled chicken breast with garlic butter.                                                                                [{'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Cheddar Cheese', 'Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                             [{'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Vanilla', 'Mint Chocolate Chip'], 'name': 'Ice Cream'}, {'customizations': ['Cheddar Cheese', 'Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]    0.793169
# 43                                                                                                              Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                                     [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                           [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.069274
# 44                                                                                                                                           I'll have a pale ale, a lemonade, an apple pie with extra toppings of berries, nuts, and chocolate chips, a shrimp cocktail with spicy cocktail sauce, extra dipping sauces of blue cheese and ranch, tomato soup with basil pesto and croutons, milk alternatives of almond milk and oat milk, an extra scoop of ice cream, and a fruit salad.                                                         [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                        [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Lemonade'], 'name': 'Soft Drinks'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Apple Pie'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.147887
# 51                                                                                                                                                                                         Milk alternatives with oat milk, fish and chips extra crispy with fries, extra ranch dipping sauce, Greek salad with no protein, extra side of veggies, fries, and mashed potatoes, extra cheese, garden salad with balsamic, vinaigrette, and ranch, lemonade, berry parfait, and mild coleslaw.                                                              [{'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}]                                             [{'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Extra Cheese'], 'name': 'Extra Cheese'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Lemonade'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}]    0.711719
# 75                                                                                                                                                   Ordering an extra scoop of ice cream, with extra dipping sauces of ranch and blue cheese. I'll have the fish and chips crispy, vanilla ice cream, and chicken soup with fresh parsley and a lemon wedge. A berry parfait on the side, along with a lemonade. For drinks, I'll take red and rose wine, and finish off with a cheesecake.                                                                                          [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                          [{'customizations': ['Extra Ice Cream Scoop'], 'name': 'Ice Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Red Wine', 'Rose Wine'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}]    0.766121
# 79                                                                                                                                                                     I'll have some onion rings with ranch and BBQ, a vegan burger topped with vegan cheese, ketchup, and vegan mayo, mint chocolate chip ice cream, chocolate ice cream, shrimp cocktail with spicy cocktail sauce, a drink with almond milk, an extra side of fries and rice, and soft drinks including Sprite and Coke.                                                                                                                                                                                    [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                           [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Almond Milk'], 'name': 'Drink'}, {'customizations': ['Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]    0.730022
# 83     I'll have oat milk and almond milk for the milk alternatives, a selection of IPA, lager, and pale ale for the craft beer, and I'll need BBQ sauce and pesto for the extra sauce. For my iced tea, I want it sweetened. Add fish and chips with fries to the order. I'll also have mojito, margarita, and old fashioned cocktails. For dessert, a berry parfait sounds good. I want some cream of mushroom with chopped parsley and chicken soup with fresh parsley and a lemon wedge.  [{'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}]                                                         [{'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Fish and Chips', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Chopped Parsley', 'Lemon Wedge'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}]    0.453947
# 89                                                                                                                                                                                                            I'll have chicken wings with BBQ sauce, sweetened iced tea, apple and carrot fresh juice, a lemonade, a strawberry, and a vanilla. For the food, I want a fruit salad, a Greek salad with falafel and no protein, crispy fish and chips, and an extra side of mashed potatoes.                                                                                                                                            [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juice'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Vanilla'}]    0.702500
# 92                                                                                Ordering tomato soup with cheddar cheese, basil pesto, and croutons. I want extra toppings with nuts, berries, and chocolate chips. Also including apple crumble and an extra shot of vodka. For the side, I'll have fruit salad and Greek salad with grilled chicken and no protein. And let's add milk alternatives with almond milk and oat milk. Finally, a side of coleslaw with both mild and spicy.                                                                                            [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                                                                                                                                                                             [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot'}, {'customizations': ['Fruit Salad', 'Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]    0.756598
# 96             I want an extra side of rice, veggies, mashed potatoes, and fries. Add extra whipped cream too. Include extra dipping sauces with ranch and blue cheese. Iâ€™ll take a strawberry and coleslaw with both mild and spicy options. For the main, Iâ€™d like vegetable stir-fry with garlic soy, teriyaki, and peanut sauce. Also, grab some mozzarella sticks with marinara. For desserts, Iâ€™ll have vanilla and chocolate, and donâ€™t forget the flavored syrup in vanilla.                                                    [{'customizations': ['Rice', 'Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                      [{'customizations': ['Rice', 'Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Strawberry', 'Coleslaw (Mild)', 'Coleslaw (Spicy)'], 'name': 'Extra Topping'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla', 'Chocolate'], 'name': 'Extra Dessert'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrup'}]    0.767502
# 102                                                                                                                                                                                                                                 I'll have spicy coleslaw, almond milk and oat milk as my milk alternatives, some extra cheese, a pale ale and a lager for craft beer, red and rosÃ© wine, a berry parfait, cheesecake, a garden salad with balsamic dressing, and an extra side of rice.                                                                                                                                                                                 [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                            [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Extra Cheese'], 'name': 'Extra Cheese'}, {'customizations': ['Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Red Wine', 'Rose Wine'], 'name': 'Wine'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]    0.356021
# 106                                                                                                                                                                                                                             I'll have a berry parfait, sweetened iced tea, gravy and BBQ sauce on the side, some chocolate, an apple pie, a lemonade, with chocolate chips as an extra topping, a garden salad with ranch and balsamic dressings, and some mozzarella sticks with ranch.                                                                                                                                                                            [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Ranch', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}]                                                                                                                                                  [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Chocolate'], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Lemonade'], 'name': 'Lemonade'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Ranch', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}]    0.570546
# 111                                                      Can I get a Berry Parfait, a Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, a Tomato Soup with Cheddar Cheese and Basil Pesto, a Garden Salad with Vinaigrette, Balsamic, and Ranch dressing, a Lemon Meringue Pie, an extra side of Veggies, Fries, Mashed Potatoes, and Rice, a Vegan Burger with Vegan Mayo, Ketchup, no Cheese, Vegan Cheese, and Mustard, a Chocolate Cake, and a Greek Salad with Grilled Chicken?                         [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}]  [{'customizations': ['Berry', 'Parfait'], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}]    0.069076
# 113  I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                                    [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                    [{'customizations': ['Mint Chocolate Chip'], 'name': 'Ice Cream'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.462874
# 118                                                                       Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.                       [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                         [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Fresh Orange Juice', 'Craft Lager'], 'name': 'Beverages'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.222618

# %% [markdown]
# ### **Medium 4b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-medium-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
    attn_implementation="eager"
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-medium-json-LoRA-4bit-128-16) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/131M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches:  75%|███████▌  | 3/4 [01:01<00:20, 20.32s/it]
# Warning: Could not parse JSON: Expecting ':' delimiter: line 1 column 80 (char 79).
# Attempted to parse (after extraction): '[{"customizations":["Teriyaki","Peanut Sauce"],"name":"Vegetable Stir-fry"},{""customizations":["BBQ"],"name":"Extra Sauce"},{""customizations":["BBQ"],"name":"Onion Rings"},{""customizations":["Truffle Oil"],"name":"Cream of Mushroom"},{""customizations":["Rum","Vodka","Whiskey"],"name":"Extra Shot of Alcohol"},{""customizations":["Garlic Butter","Lemon Dill"],"name":"Grilled Salmon"},{""customizations":["Sweetened"],"name":"Iced Tea"},{""customizations":[],"name":"Extra Whipped Cream"}]'
# Inference Batches: 100%|██████████| 4/4 [01:21<00:00, 20.43s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9019
# ✅ Exact Match Accuracy: 34.17%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              predicted_items  similarity
# 6                                                                                                                                                                                    Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                                   [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                              [{'customizations': ['Extra Whipped Cream'], 'name': 'Drink'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]    0.099318
# 12                                                                                                                                                 One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                              [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]            [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.703959
# 20                                                                                                                                            I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                                   [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                              [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.722401
# 22                                                                                                                                                                                                                                                                                                     Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                               [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                  [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 39                                                                                                                                                                                                                                             I'll have a vanilla and cheesecake, a fruit salad with nuts as an extra topping, chicken soup with fresh parsley and a lemon wedge, apple crumble, mozzarella sticks with marinara and ranch, unsweetened iced tea, and an extra bun or bread roll.                                                                                                                                                                       [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                          [{'customizations': ['Vanilla', 'Cheesecake'], 'name': 'Desserts'}, {'customizations': ['Nuts'], 'name': 'Fruit Salad'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.773455
# 43                                                                                                                    Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                         [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                     [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.068433
# 46                                                                                                                                                                                     Extra shot of whiskey, Caesar salad with grilled shrimp and grilled chicken, miso soup with chili oil, chicken soup with fresh parsley, vanilla flavored syrups, extra dipping sauces of ranch and blue cheese, extra whipped cream, fruit salad, shrimp cocktail with spicy cocktail sauce and lemon herb.                                                                       [{'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}]                     [{'customizations': ['Extra Shot of Whiskey'], 'name': 'Old Fashioned'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Spicy Cocktail Sauce', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.072889
# 64                                                                              Ordering some cocktails, specifically an Old Fashioned and a Margarita. Also want some extra whipped cream and a fruit salad on the side. Gonna grab some mozzarella sticks with ranch and marinara for dipping, plus onion rings with BBQ and ranch sauce. Iâ€™ll take my drink with oat milk, and finish off with a slice of lemon meringue pie and some grilled tofu drizzled with peanut sauce and soy ginger.                                                                                                                                                                            [{'customizations': ['Old Fashioned', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Peanut Sauce', 'Soy Ginger'], 'name': 'Grilled Tofu'}]                                                                                                                                                                           [{'customizations': ['Old Fashioned', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lemon Meringue Pie', 'Grilled Tofu'], 'name': 'Dessert'}]    0.766102
# 70                                                                                                                                                                       I'll take an Old Fashioned cocktail, flavored syrups in vanilla and caramel, extra ranch dipping sauce, a berry parfait with extra toppings of berries, nuts, and chocolate chips, an apple crumble, tomato soup with croutons, basil pesto, and cheddar cheese, a slice of chocolate cake, and miso soup with chili oil.                                                                                                     [{'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Croutons', 'Basil Pesto', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}]                                                                                                                                                                                                    [{'customizations': ['Vanilla', 'Caramel'], 'name': 'Old Fashioned'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Croutons', 'Basil Pesto', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}]    0.658037
# 72                                                                                                                                                                                                                            I want an extra scoop of ice cream, an extra side of rice, sweetened iced tea, a Coke, grilled salmon with lemon dill, an apple crumble, tomato soup with cheddar cheese, extra pesto, gravy, and BBQ sauce, spicy coleslaw, and a garden salad with ranch dressing.  [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Rice', 'Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Pesto', 'Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}]                                                                                             [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Cheddar Cheese', 'Pesto', 'Gravy', 'BBQ Sauce'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}]    0.772686
# 79                                                                                                                                                                           I'll have some onion rings with ranch and BBQ, a vegan burger topped with vegan cheese, ketchup, and vegan mayo, mint chocolate chip ice cream, chocolate ice cream, shrimp cocktail with spicy cocktail sauce, a drink with almond milk, an extra side of fries and rice, and soft drinks including Sprite and Coke.                                                                                                                                                                        [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Almond Milk'], 'name': 'Drink'}, {'customizations': ['Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]    0.730022
# 81   Want to order some Spring Rolls with chicken and vegetarian options, a couple of Craft Beers in lager and IPA, and some Extra Sauce with gravy and pesto. Don't forget the Fresh Juices, we'll go with apple and carrot, and a Garden Salad with vinaigrette and balsamic dressing. For drinks, letâ€™s have Iced Tea, half sweetened and half unsweetened. For dessert, Iâ€™ll take a Cheesecake and a Lemon Meringue Pie. Also, throw in an Extra Bun or Bread Roll and some Extra Cheese.                                                                 [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}]  [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Iced Tea', 'Sweetened', 'Unsweetened'], 'name': 'Drinks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.619173
# 87                                                                                                                                                                                 Ordering a Vegetable Stir-fry with teriyaki and peanut sauce, an extra BBQ sauce on the side, a side of onion rings with BBQ, cream of mushroom soup with truffle oil, an extra shot of rum, vodka, and whiskey, grilled salmon with garlic butter and lemon dill, sweetened iced tea, and extra whipped cream.                                                                                                                                                  [{'customizations': ['Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         None    0.000000
# 92                                                                                      Ordering tomato soup with cheddar cheese, basil pesto, and croutons. I want extra toppings with nuts, berries, and chocolate chips. Also including apple crumble and an extra shot of vodka. For the side, I'll have fruit salad and Greek salad with grilled chicken and no protein. And let's add milk alternatives with almond milk and oat milk. Finally, a side of coleslaw with both mild and spicy.                                                                                [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                                                                   [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Apple Crumble'], 'name': 'Extra Dessert'}, {'customizations': ['Vodka'], 'name': 'Extra Shot'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]    0.521087
# 96                   I want an extra side of rice, veggies, mashed potatoes, and fries. Add extra whipped cream too. Include extra dipping sauces with ranch and blue cheese. Iâ€™ll take a strawberry and coleslaw with both mild and spicy options. For the main, Iâ€™d like vegetable stir-fry with garlic soy, teriyaki, and peanut sauce. Also, grab some mozzarella sticks with marinara. For desserts, Iâ€™ll have vanilla and chocolate, and donâ€™t forget the flavored syrup in vanilla.                                        [{'customizations': ['Rice', 'Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Rice', 'Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Coleslaw'}]    0.659065
# 113        I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                        [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                    [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.485380
# 118                                                                             Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.           [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                           [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Orange Juice'], 'name': 'Fresh Juices'}, {'customizations': ['Craft Lager'], 'name': 'Beer'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.202597

# %% [markdown]
# ### **Small 12b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-small-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
    attn_implementation="eager"
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-small-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [08:36<00:00, 129.19s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9106
# ✅ Exact Match Accuracy: 33.33%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    predicted_items  similarity
# 1                                                                                                                                                                                                                                      Ordering Fish and Chips with Onion Rings, an Apple Crumble, and a Berry Parfait on the side. Iâ€™ll have sweetened Iced Tea and a drink with an extra shot of Rum. Please add some Vanilla, extra toppings of Berries, and extra BBQ Sauce and Gravy.                                                                                                                                                                                       [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                    [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum'], 'name': 'Extra Shot'}, {'customizations': ['Vanilla'], 'name': 'Flavorings'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]    0.766551
# 6                                                                                                                                                                              Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                          [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                         [{'customizations': ['Extra Whipped Cream'], 'name': 'Drink'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.104294
# 12                                                                                                                                           One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                     [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]  [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.703959
# 20                                                                                                                                      I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                          [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                 [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caesar', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.720856
# 22                                                                                                                                                                                                                                                                                               Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                      [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                        [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 43                                                                                                              Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                      [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.069274
# 44                                                                                                                                           I'll have a pale ale, a lemonade, an apple pie with extra toppings of berries, nuts, and chocolate chips, a shrimp cocktail with spicy cocktail sauce, extra dipping sauces of blue cheese and ranch, tomato soup with basil pesto and croutons, milk alternatives of almond milk and oat milk, an extra scoop of ice cream, and a fruit salad.                                    [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]                       [{'customizations': ['Pale Ale'], 'name': 'Beer'}, {'customizations': ['Lemonade'], 'name': 'Drinks'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Apple Pie'}, {'customizations': ['Spicy Cocktail Sauce'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauces'}, {'customizations': ['Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.171378
# 53                                                                                                                                                                                                  Can I get an extra ice cream scoop, some oat milk for the milk alternatives, a Greek salad with grilled chicken, fish and chips extra crispy with fries, extra cheese on the side, a serving of mozzarella sticks with marinara, an extra ranch dipping sauce, and a fresh orange juice?                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]                                                                                                                     [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'Fish'], 'name': 'Greek Salad'}, {'customizations': ['Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]    0.365801
# 65                                                                                                                                                                                Can I get a dessert order with extra whipped cream, a fruit salad, extra toppings with berries, cream of mushroom soup topped with chopped parsley, an extra bun, a cheesecake, tomato soup with croutons, basil pesto, and cheddar cheese, a lemon meringue pie, an IPA craft beer, and an apple crumble?                                                                                     [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Croutons', 'Basil Pesto', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}]                               [{'customizations': ['Extra Whipped Cream'], 'name': 'Dessert'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Berries'], 'name': 'Extra Toppings'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom Soup'}, {'customizations': [], 'name': 'Extra Bun'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Croutons', 'Basil Pesto', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.586815
# 75                                                                                                                                                   Ordering an extra scoop of ice cream, with extra dipping sauces of ranch and blue cheese. I'll have the fish and chips crispy, vanilla ice cream, and chicken soup with fresh parsley and a lemon wedge. A berry parfait on the side, along with a lemonade. For drinks, I'll take red and rose wine, and finish off with a cheesecake.                                                                     [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                             [{'customizations': ['Extra Dipping Sauces', 'Ranch', 'Blue Cheese'], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Berry Parfait'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}]    0.752495
# 89                                                                                                                                                                                                            I'll have chicken wings with BBQ sauce, sweetened iced tea, apple and carrot fresh juice, a lemonade, a strawberry, and a vanilla. For the food, I want a fruit salad, a Greek salad with falafel and no protein, crispy fish and chips, and an extra side of mashed potatoes.                                                                                                                       [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]                       [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Fruit Salad'], 'name': 'Extra Food'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy', 'Fish and Chips'], 'name': 'Extra Food'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]    0.782857
# 92                                                                                Ordering tomato soup with cheddar cheese, basil pesto, and croutons. I want extra toppings with nuts, berries, and chocolate chips. Also including apple crumble and an extra shot of vodka. For the side, I'll have fruit salad and Greek salad with grilled chicken and no protein. And let's add milk alternatives with almond milk and oat milk. Finally, a side of coleslaw with both mild and spicy.                                                                       [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                                                                                 [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Toppings'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Fruit Salad', 'Greek Salad with Grilled Chicken and No Protein'], 'name': 'Side'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]    0.584527
# 96             I want an extra side of rice, veggies, mashed potatoes, and fries. Add extra whipped cream too. Include extra dipping sauces with ranch and blue cheese. Iâ€™ll take a strawberry and coleslaw with both mild and spicy options. For the main, Iâ€™d like vegetable stir-fry with garlic soy, teriyaki, and peanut sauce. Also, grab some mozzarella sticks with marinara. For desserts, Iâ€™ll have vanilla and chocolate, and donâ€™t forget the flavored syrup in vanilla.                               [{'customizations': ['Rice', 'Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]              [{'customizations': ['Rice', 'Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Strawberry', 'Coleslaw (Mild & Spicy)'], 'name': 'Extra Treat'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla', 'Chocolate'], 'name': 'Extra Dessert'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.782533
# 113  I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                               [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                          [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.485380
# 118                                                                       Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.  [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                          [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Orange Juice', 'Craft Lager'], 'name': 'Beverages'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.222023

# %% [markdown]
# ### **Medium 12b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-medium-json-LoRA-4bit-128-16"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

# --- Check GPU Availability & L4 ---
if not torch.cuda.is_available():
    raise SystemError("CUDA is not available. This script requires a GPU.")
else:
    device_name = torch.cuda.get_device_name(0)
    print(f"CUDA is available. Using GPU: {device_name}")
    if "L4" not in device_name:
         print("Warning: The detected GPU is not an L4. Performance may vary.")
    device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Setup Quantization ---
compute_dtype = torch.bfloat16 if torch.cuda.get_device_capability(device)[0] >= 8 else torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)
print(f"Using compute dtype: {compute_dtype} for BnB config.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model with Quantization ---
print(f"Loading base model ({base_model_id}) with quantization...")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=compute_dtype,
    trust_remote_code=True,
    attn_implementation="eager"
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=1024, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# Warning: The detected GPU is not an L4. Performance may vary.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Using compute dtype: torch.bfloat16 for BnB config.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) with quantization...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-medium-json-LoRA-4bit-128-16) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:351: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [10:00<00:00, 150.18s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9411
# ✅ Exact Match Accuracy: 44.17%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 predicted_items  similarity
# 1                                                                                                                                                                                                                                      Ordering Fish and Chips with Onion Rings, an Apple Crumble, and a Berry Parfait on the side. Iâ€™ll have sweetened Iced Tea and a drink with an extra shot of Rum. Please add some Vanilla, extra toppings of Berries, and extra BBQ Sauce and Gravy.                                                                                                                                                                                       [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                 [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Vanilla'], 'name': 'Extra Flavoring'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}]    0.772679
# 22                                                                                                                                                                                                                                                                                               Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                      [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 43                                                                                                              Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                        [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.068433
# 53                                                                                                                                                                                                  Can I get an extra ice cream scoop, some oat milk for the milk alternatives, a Greek salad with grilled chicken, fish and chips extra crispy with fries, extra cheese on the side, a serving of mozzarella sticks with marinara, an extra ranch dipping sauce, and a fresh orange juice?                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]    0.524838
# 92                                                                                Ordering tomato soup with cheddar cheese, basil pesto, and croutons. I want extra toppings with nuts, berries, and chocolate chips. Also including apple crumble and an extra shot of vodka. For the side, I'll have fruit salad and Greek salad with grilled chicken and no protein. And let's add milk alternatives with almond milk and oat milk. Finally, a side of coleslaw with both mild and spicy.                                                                       [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                                                                                                                                                               [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Fruit Salad', 'Greek Salad with Grilled Chicken and No Protein'], 'name': 'Side'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]    0.585086
# 113  I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                               [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                       [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.485380
# 118                                                                       Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.  [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                       [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Orange Juice', 'Craft Lager'], 'name': 'Beverages'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.222023
# 119                                Ordering vegetarian spring rolls and miso soup with toasted sesame seeds. I'll also need extra dipping sauces of ranch and blue cheese, along with onion rings and ranch on the side. A vegan burger comes with no cheese, ketchup, mustard, vegan mayo, and vegan cheese. Add cream of mushroom soup with chopped parsley and truffle oil, followed by a slice of chocolate cake. Lastly, include extra pesto sauce. Two chocolate bars for dessert too.                                                             [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}]  [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Miso Soup', 'Toasted Sesame Seeds'], 'name': 'Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Onion Rings', 'Ranch'], 'name': 'Extra Side'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Cream of Mushroom', 'Chopped Parsley', 'Truffle Oil'], 'name': 'Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate Bar'}, {'customizations': [], 'name': 'Chocolate Bar'}]    0.765000
