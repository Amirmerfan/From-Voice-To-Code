# %%
# !pip install -q -U transformers datasets accelerate peft trl bitsandbytes scipy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.0/348.0 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
import torch
import os
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel, get_peft_model
from trl import SFTTrainer

from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model_id = "google/gemma-3-4b-it"

new_model_name = "gemma-3-4b-it-medium-json-16bit"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
eos_token = tokenizer.eos_token

print(f"EOS Token: {eos_token}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# EOS Token: <eos>

# %%
print(f"Sample Data Point (check EOS):\n{train_dataset[0]['formatted_text']}")
# Out:
# Sample Data Point (check EOS):
# Convert the following food order into JSON format using this structure:
# [
#   { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
#   { "customizations": [], "name": "Another Item" }
# ]:
# Miso soup with toasted sesame seeds and chili oil, extra crispy fish and chips with fries and onion rings, chocolate cake, apple pie, and lemon meringue pie.
# [{"customizations":["Toasted Sesame Seeds","Chili Oil"],"name":"Miso Soup"},{"customizations":["Extra Crispy","Fries","Onion Rings","Crispy"],"name":"Fish and Chips"},{"customizations":[],"name":"Chocolate Cake"},{"customizations":[],"name":"Apple Pie"},{"customizations":[],"name":"Lemon Meringue Pie"}]<eos>

# %%
import pandas as pd

df = train_dataset.to_pandas()
num_duplicates = df.duplicated().sum()
num_duplicates
# Out:
# np.int64(0)

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-medium-clean-18k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1800, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-medium-clean-18k' (split: 'train')...
# README.md:   0%|          | 0.00/518 [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/28 [00:00<?, ?files/s]
# train-00000-of-00028.parquet:   0%|          | 0.00/487M [00:00<?, ?B/s]
# train-00001-of-00028.parquet:   0%|          | 0.00/408M [00:00<?, ?B/s]
# train-00002-of-00028.parquet:   0%|          | 0.00/380M [00:00<?, ?B/s]
# train-00003-of-00028.parquet:   0%|          | 0.00/449M [00:00<?, ?B/s]
# train-00004-of-00028.parquet:   0%|          | 0.00/381M [00:00<?, ?B/s]
# train-00005-of-00028.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# train-00006-of-00028.parquet:   0%|          | 0.00/610M [00:00<?, ?B/s]
# train-00007-of-00028.parquet:   0%|          | 0.00/516M [00:00<?, ?B/s]
# train-00008-of-00028.parquet:   0%|          | 0.00/473M [00:00<?, ?B/s]
# train-00009-of-00028.parquet:   0%|          | 0.00/415M [00:00<?, ?B/s]
# train-00010-of-00028.parquet:   0%|          | 0.00/358M [00:00<?, ?B/s]
# train-00011-of-00028.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# train-00012-of-00028.parquet:   0%|          | 0.00/453M [00:00<?, ?B/s]
# train-00013-of-00028.parquet:   0%|          | 0.00/383M [00:00<?, ?B/s]
# train-00014-of-00028.parquet:   0%|          | 0.00/450M [00:00<?, ?B/s]
# train-00015-of-00028.parquet:   0%|          | 0.00/385M [00:00<?, ?B/s]
# train-00016-of-00028.parquet:   0%|          | 0.00/357M [00:00<?, ?B/s]
# train-00017-of-00028.parquet:   0%|          | 0.00/407M [00:00<?, ?B/s]
# train-00018-of-00028.parquet:   0%|          | 0.00/346M [00:00<?, ?B/s]
# train-00019-of-00028.parquet:   0%|          | 0.00/365M [00:00<?, ?B/s]
# train-00020-of-00028.parquet:   0%|          | 0.00/408M [00:00<?, ?B/s]
# train-00021-of-00028.parquet:   0%|          | 0.00/344M [00:00<?, ?B/s]
# train-00022-of-00028.parquet:   0%|          | 0.00/386M [00:00<?, ?B/s]
# train-00023-of-00028.parquet:   0%|          | 0.00/380M [00:00<?, ?B/s]
# train-00024-of-00028.parquet:   0%|          | 0.00/326M [00:00<?, ?B/s]
# train-00025-of-00028.parquet:   0%|          | 0.00/451M [00:00<?, ?B/s]
# train-00026-of-00028.parquet:   0%|          | 0.00/419M [00:00<?, ?B/s]
# train-00027-of-00028.parquet:   0%|          | 0.00/357M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/18000 [00:00<?, ? examples/s]
# Loading dataset shards:   0%|          | 0/24 [00:00<?, ?it/s]
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1800
# })
# Splitting dataset into train and validation sets...
# Train set size: 1620
# Validation set size: 180
# Applying formatting function to the datasets...
# Map:   0%|          | 0/1620 [00:00<?, ? examples/s]
# Map:   0%|          | 0/180 [00:00<?, ? examples/s]
# Dataset formatting complete.
# Train dataset features: {'formatted_text': Value(dtype='string', id=None)}
# Validation dataset features: {'formatted_text': Value(dtype='string', id=None)}

# %%
validation_data
# Out:
# Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 180
# })

# %%
if torch.cuda.is_available() and torch.cuda.get_device_capability()[0] >= 8:
  print("GPU supports bfloat16, using torch.bfloat16 for model loading and training.")
  model_dtype = torch.bfloat16
else:
  print("GPU does not support bfloat16, using torch.float16 for model loading and training.")
  model_dtype = torch.float16
# Out:
# GPU does not support bfloat16, using torch.float16 for model loading and training.

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=model_dtype,
    device_map="auto",
)

print(f"Base model loaded in {model_dtype}.")
print(model)
# Out:
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded in torch.bfloat16.
# Gemma3ForConditionalGeneration(
#   (vision_tower): SiglipVisionModel(
#     (vision_model): SiglipVisionTransformer(
#       (embeddings): SiglipVisionEmbeddings(
#         (patch_embedding): Conv2d(3, 1152, kernel_size=(14, 14), stride=(14, 14), padding=valid)
#         (position_embedding): Embedding(4096, 1152)
#       )
#       (encoder): SiglipEncoder(
#         (layers): ModuleList(
#           (0-26): 27 x SiglipEncoderLayer(
#             (layer_norm1): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#             (self_attn): SiglipAttention(
#               (k_proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (v_proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (q_proj): Linear(in_features=1152, out_features=1152, bias=True)
#               (out_proj): Linear(in_features=1152, out_features=1152, bias=True)
#             )
#             (layer_norm2): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#             (mlp): SiglipMLP(
#               (activation_fn): PytorchGELUTanh()
#               (fc1): Linear(in_features=1152, out_features=4304, bias=True)
#               (fc2): Linear(in_features=4304, out_features=1152, bias=True)
#             )
#           )
#         )
#       )
#       (post_layernorm): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#     )
#   )
#   (multi_modal_projector): Gemma3MultiModalProjector(
#     (mm_soft_emb_norm): Gemma3RMSNorm((1152,), eps=1e-06)
#     (avg_pool): AvgPool2d(kernel_size=4, stride=4, padding=0)
#   )
#   (language_model): Gemma3ForCausalLM(
#     (model): Gemma3TextModel(
#       (embed_tokens): Gemma3TextScaledWordEmbedding(262208, 2560, padding_idx=0)
#       (layers): ModuleList(
#         (0-33): 34 x Gemma3DecoderLayer(
#           (self_attn): Gemma3Attention(
#             (q_proj): Linear(in_features=2560, out_features=2048, bias=False)
#             (k_proj): Linear(in_features=2560, out_features=1024, bias=False)
#             (v_proj): Linear(in_features=2560, out_features=1024, bias=False)
#             (o_proj): Linear(in_features=2048, out_features=2560, bias=False)
#             (q_norm): Gemma3RMSNorm((256,), eps=1e-06)
#             (k_norm): Gemma3RMSNorm((256,), eps=1e-06)
#           )
#           (mlp): Gemma3MLP(
#             (gate_proj): Linear(in_features=2560, out_features=10240, bias=False)
#             (up_proj): Linear(in_features=2560, out_features=10240, bias=False)
#             (down_proj): Linear(in_features=10240, out_features=2560, bias=False)
#             (act_fn): PytorchGELUTanh()
#           )
#           (input_layernorm): Gemma3RMSNorm((2560,), eps=1e-06)
#           (post_attention_layernorm): Gemma3RMSNorm((2560,), eps=1e-06)
#           (pre_feedforward_layernorm): Gemma3RMSNorm((2560,), eps=1e-06)
#           (post_feedforward_layernorm): Gemma3RMSNorm((2560,), eps=1e-06)
#         )
#       )
#       (norm): Gemma3RMSNorm((2560,), eps=1e-06)
#       (rotary_emb): Gemma3RotaryEmbedding()
#       (rotary_emb_local): Gemma3RotaryEmbedding()
#     )
#     (lm_head): Linear(in_features=2560, out_features=262208, bias=False)
#   )
# )

# %%
peft_config = LoraConfig(
    lora_alpha=128,
    lora_dropout=0.05,
    r=32,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],
)

# %%
from trl import SFTConfig

sft_config = SFTConfig(
     output_dir=new_model_name,
     num_train_epochs=3,
     per_device_train_batch_size=2,
     gradient_accumulation_steps=4,
     optim="paged_adamw_8bit",
     eval_strategy="steps",
     eval_steps=100,
     logging_steps=10,
     learning_rate=5e-5,
     weight_decay=0.001,
     fp16=(model_dtype==torch.float16),
     bf16=(model_dtype==torch.bfloat16),
     max_grad_norm=0.3,
     max_steps=-1,
     warmup_ratio=0.03,
     group_by_length=True,
     lr_scheduler_type="cosine",
     report_to="tensorboard",
     save_strategy="steps",
     save_steps=100,
     save_total_limit=2,
     load_best_model_at_end=True,
     metric_for_best_model="eval_loss",
     greater_is_better=False,
     max_seq_length=1024,
     packing=False,
     dataset_text_field="formatted_text",
     push_to_hub=True,
     hub_model_id=f"iTzMiNOS/{new_model_name}",
)

print("SFTConfig configured.")
# Out:
# SFTConfig configured.

# %%
if 'train_dataset' not in globals() or 'validation_dataset' not in globals() or train_dataset is None or validation_dataset is None:
     raise ValueError("Training or Validation dataset not found or not processed. Please ensure Cell 4 ran correctly after loading the tokenizer.")
if 'model' not in globals():
      raise ValueError("Model not loaded.")
if 'tokenizer' not in globals():
      raise ValueError("Tokenizer not loaded.")
if 'sft_config' not in globals():
      raise ValueError("SFTConfig not defined.")
if 'peft_config' not in globals():
      raise ValueError("peft_config not defined.")

tokenizer.chat_template = None
print("Attempting SFTTrainer initialization using SFTConfig...")
try:
    trainer = SFTTrainer(
        model=model,
        args=sft_config,
        train_dataset=train_dataset,
        eval_dataset=validation_dataset,
        peft_config=peft_config,
        processing_class=tokenizer,
    )
    print("SFTTrainer initialized successfully using SFTConfig!")

except TypeError as e:
    print(f"SFTTrainer STILL FAILED with TypeError: {e}")
    print("Check if 'tokenizer' is now the unexpected argument.")
except Exception as e:
    print(f"SFTTrainer FAILED with another error: {e}")
# Out:
# Attempting SFTTrainer initialization using SFTConfig...
# Converting train dataset to ChatML:   0%|          | 0/1620 [00:00<?, ? examples/s]
# Adding EOS to train dataset:   0%|          | 0/1620 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/1620 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/1620 [00:00<?, ? examples/s]
# Converting eval dataset to ChatML:   0%|          | 0/180 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/180 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/180 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/180 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# SFTTrainer initialized successfully using SFTConfig!

# %%
print("Starting fine-tuning...")
trainer.train()
print("Fine-tuning finished.")
# Out:
# Starting fine-tuning...
# It is strongly recommended to train Gemma3 models with the `eager` attention implementation instead of `sdpa`. Use `eager` with `AutoModelForCausalLM.from_pretrained('<path-to-checkpoint>', attn_implementation='eager')`.
#     <div>
#
#       <progress value='606' max='606' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [606/606 17:48, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.980400</td>
#       <td>0.299621</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.885500</td>
#       <td>0.282266</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.824400</td>
#       <td>0.257263</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.795600</td>
#       <td>0.238374</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.749000</td>
#       <td>0.233530</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.734400</td>
#       <td>0.233188</td>
#     </tr>
#   </tbody>
# </table><p>
# Fine-tuning finished.

# %%
print(f"Saving fine-tuned adapters to ./{new_model_name}")
trainer.model.save_pretrained(new_model_name)
tokenizer.save_pretrained(new_model_name)
print("Adapters and tokenizer saved.")

# Optional: Clean up memory
# del model
# del trainer
# torch.cuda.empty_cache()
# Out:
# Saving fine-tuned adapters to ./gemma-3-4b-it-medium-json-16bit
# Adapters and tokenizer saved.

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = f"iTzMiNOS/{new_model_name}"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-medium-clean-18k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: Tesla T4
# GPU does not support bfloat16, using torch.float16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) in torch.float16
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-medium-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/262M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches: 100%|██████████| 12/12 [00:02<00:00,  4.87it/s]
# --- ERROR during batch 1 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 2 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 3 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 4 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 5 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 6 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 7 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 8 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 9 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 10 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 11 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# --- ERROR during batch 12 --- Error: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.0000
# ✅ Exact Match Accuracy: 0.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                 transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     items predicted_items  similarity
# 0    I want a Cream of Mushroom soup with truffle oil, some spring rolls with vegetarian and chicken, a portion of chicken wings with BBQ, Buffalo, and spicy sauces, a grilled chicken breast with BBQ, and a selection of soft drinks including Fanta, Coke, and Sprite. Also, add some craft beer â€” a mix of lager, pale ale, and IPA, and I'll need extra sauces like pesto and BBQ sauce.                                                     [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]            None         0.0
# 1                                                                                                                  Ordering some mozzarella sticks with marinara and ranch, a grilled chicken breast with BBQ and garlic butter, fresh juices with carrot, apple, and orange, an apple pie, and both vanilla and chocolate. Also, I'd like extra toppings of nuts, berries, and chocolate chips.                                                                                             [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]            None         0.0
# 2                                                                                                                        I'll have the Cream of Mushroom with chopped parsley and truffle oil, a lemonade, fresh juices mixed with carrot and orange, a craft beer with lager and pale ale, and a side of extra dipping sauce with ranch. Also, throw in the strawberry and extra whipped cream.                                                                                                                   [{'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]            None         0.0
# 3                                                                                                                           One vegan burger with vegan mayo, a mix of Sprite and Fanta for soft drinks, both sweetened and unsweetened iced tea, a scoop of mint chocolate chip ice cream, and an extra side with veggies, fries, and rice. Also, please add BBQ sauce and extra whipped cream.                                                                                                        [{'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Veggies', 'Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]            None         0.0
# 4                                                                                                                                                                                 Ordering a Chicken Soup with fresh parsley and a lemon wedge, a Lemonade, a Mojito cocktail, Mint Chocolate Chip ice cream, a Berry Parfait, and an extra side with rice, fries, mashed potatoes, and veggies.                                                                                                                                                                        [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Rice', 'Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}]            None         0.0
# 5                                                                                                                                       Miso Soup with toasted sesame seeds and chili oil, grilled chicken breast with BBQ sauce, vegetable stir-fry with teriyaki and peanut sauce, a lemonade, fresh juices with apple, orange, and carrot, and extra dipping sauces of blue cheese and ranch.                                                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]            None         0.0
# 6                                                                                                                                               I'm ordering a Shrimp Cocktail with spicy cocktail and lemon herb, Fish and Chips with onion rings extra crispy, a Vegetable Stir-fry with teriyaki, a lemonade, a selection of craft beer including IPA, pale ale, and lager, and an extra bun.                                                                                                                                 [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]            None         0.0
# 7                                                                                                                                                                                                                 Ordering a Shrimp Cocktail with spicy cocktail sauce, sweetened iced tea, a mix of red and rose wine, an extra side of mashed potatoes, and oat milk for the milk alternative.                                                                                                                                                                                                                                             [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]            None         0.0
# 8                                                                                                                                                             Ordering a Caesar Salad with grilled shrimp, a mild and spicy coleslaw, a grilled chicken breast with BBQ sauce, a chocolate cake, extra pesto sauce, an extra scoop of ice cream, and milk alternatives with almond and oat milk.                                                                                                                 [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]            None         0.0
# 9                                                                                                                                                                              Order a Cream of Mushroom with truffle oil and chopped parsley, a side of onion rings with ranch and BBQ sauce, an iced tea that's sweetened, a refreshing lemonade, and some fresh juices with orange and apple.                                                                                                                                                                                                                                    [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}]            None         0.0
# 10                                                                                                                                                                                I'll have a tomato soup with croutons, a miso soup with chili oil and toasted sesame seeds, a mojito cocktail, an extra topping of chocolate chips, and an extra shot of alcohol with rum, whiskey, and vodka.                                                                                                                                                                                                        [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]            None         0.0
# 11                                                                                                                                                                          Ordering some onion rings with BBQ and ranch, a grilled chicken breast with BBQ, a grilled salmon with garlic butter and lemon dill, a lemonade, a couple of cocktailsâ€”margarita and mojitoâ€”and a berry parfait.                                                                                                                                                                                [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}]            None         0.0
# 12                                                                                                                 Ordering a Greek Salad with grilled chicken, a side of grilled tofu with peanut sauce, chili lime, and soy ginger, some chocolate, strawberry, and apple crumble desserts, and an extra bun or bread roll on the side. Also, please add extra whipped cream for the desserts.                                                                                                         [{'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]            None         0.0
# 13                                                                                                                                                            Caesar Salad with grilled shrimp and grilled chicken, Greek Salad with grilled chicken, Vegetable Stir-fry with peanut sauce, garlic soy, and teriyaki, Lemon Meringue Pie, Fruit Salad, and an extra side of ranch dipping sauce.                                                                                                                        [{'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}]            None         0.0
# 14                                                                                                                                                                                       I'll have a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a side of mild and spicy coleslaw, a sweetened iced tea, extra cheese, extra whipped cream, and an extra shot of vodka.                                                                                                                                                        [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]            None         0.0
# 15                                                                                                                                                                                             I'm ordering a Cream of Mushroom with truffle oil and chopped parsley, two soft drinks â€” one Fanta and one Coke, a Pale Ale craft beer, a cheesecake, a lemon meringue pie, and some chocolate.                                                                                                                                                                                              [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}]            None         0.0
# 16                                                                                                                                                                                                                                                Grilled chicken breast with BBQ sauce, sweetened iced tea, a lemonade, a cheesecake, and extra toppings of nuts, chocolate chips, and berries.                                                                                                                                                                                                                                                     [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]            None         0.0
# 17                                                                                                                       Going for some Chicken Soup with fresh parsley and a lemon wedge, a bowl of cream of mushroom topped with truffle oil and chopped parsley, a side of shrimp cocktail with lemon herb, a fruit salad, and I'll add extra toppings of nuts, chocolate chips, and berries.                                                                                                                                                                                    [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]            None         0.0
# 18                                                                               I'll have the chicken soup with a lemon wedge, grilled salmon topped with garlic butter and lemon dill. For dessert, I'd like a slice of cheesecake, and also, please include the chocolate and strawberry. Additionally, a side of fruit salad and extra sauces of gravy, pesto, and BBQ sauce would be great.                                                                                                                                          [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]            None         0.0
# 19                                                                                                                                                                                           I'll have the Cream of Mushroom with truffle oil and chopped parsley, a fresh juice blend of carrot, orange, and apple, a glass of red wine, vanilla, strawberry, fruit salad, and a berry parfait.                                                                                                                                                    [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Berry Parfait'}]            None         0.0
# 20                                                                                                                 Can I get a cream of mushroom soup with truffle oil and chopped parsley, a garden salad with vinaigrette, ranch, and balsamic dressings, mozzarella sticks with marinara, a couple of craft beers - one IPA and one pale ale, a slice of chocolate cake, and a berry parfait?                                                                                                                                                  [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vinaigrette', 'Ranch', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}]            None         0.0
# 21                                                                                                                                                                I'll have a Chicken Soup with fresh parsley, a Caesar Salad with grilled chicken, BBQ chicken wings, grilled salmon with lemon dill and garlic butter, a spicy shrimp cocktail, and soft drinks including a Sprite and a Coke.                                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]            None         0.0
# 22                                                                                                                                                                                             Caesar Salad with no protein, spicy and mild coleslaw, onion rings with BBQ sauce, iced tea half unsweetened and half sweetened, a chocolate cake, a cheesecake, and an extra scoop of ice cream.                                                                                                                                                [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]            None         0.0
# 23                                                                                                                                                                                                                                                            I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                                                                                                                [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]            None         0.0
# 24                                                                                                                             I'll have a miso soup with chili oil and toasted sesame seeds, a garden salad with balsamic and ranch, a sweetened iced tea, a lager craft beer, cocktails including an old fashioned and a mojito, a cheesecake, and extra toppings of nuts and chocolate chips.                                                                                             [{'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]            None         0.0
# 25                                                                                                                                                                 I want an order of mozzarella sticks with ranch, chicken wings with buffalo, BBQ, and spicy sauce, fish and chips extra crispy with onion rings, some chocolate, extra blue cheese for dipping, and an extra shot of whiskey.                                                                                                                                        [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]            None         0.0
# 26                                                                                                                                                                                                                                       Can I get a spicy coleslaw and a shrimp cocktail with lemon herb? Also, a lemonade, a mojito, a glass of rosÃ© wine, and some extra cheese on the side.                                                                                                                                                                                                                                 [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]            None         0.0
# 27                                                                                                                                                                                           Ordering Chicken Soup with a lemon wedge and fresh parsley, a Greek Salad without protein, a Margarita cocktail, a side of strawberries, extra ranch dipping sauce, and an extra bun or bread roll.                                                                                                                                                                                  [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]            None         0.0
# 28                                                                                                                                                                                                                                                   Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                                                                                                                   [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]            None         0.0
# 29                                I want to order some vegetarian and chicken spring rolls, along with Fanta and Coke for drinks. For cocktails, please add a mojito and an old fashioned. I'll take a mix of white, rose, and red wine. For dessert, just some chocolate, and I'd like extra toppings of chocolate chips and berries. Also, let's have some vanilla flavored syrup on the side.                                                                                           [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]            None         0.0
# 30                                                                                                                                                                                                            Cream of Mushroom with truffle oil and chopped parsley, spicy coleslaw, grilled chicken breast with BBQ sauce, grilled salmon with garlic butter and lemon dill, and a cheesecake.                                                                                                                                                                                                              [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}]            None         0.0
# 31                                                                                                                                                                Coleslaw with mild and spicy, shrimp cocktail with lemon herb and spicy cocktail, a lemonade, lemon meringue pie, mint chocolate chip ice cream, extra topping with nuts and chocolate chips, and flavored syrup with vanilla.                                                                                                               [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]            None         0.0
# 32                                                                                                                                                                                                            I'll have a Greek Salad with falafel, Spring Rolls with chicken, a side of chocolate, extra ranch dipping sauce, an extra scoop of ice cream, and oat milk as my milk alternative.                                                                                                                                                                                                      [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]            None         0.0
# 33                                                                                                                                                                                                                                                             I'll have the Shrimp Cocktail with Lemon Herb and Spicy Cocktail, a Sprite to drink, Chocolate Cake, Apple Pie, and some Vanilla.                                                                                                                                                                                                                                                                        [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]            None         0.0
# 34                                                                                                                                                                Ordering some onion rings with BBQ and ranch, chicken wings with BBQ, grilled tofu with soy ginger and chili lime, an unsweetened iced tea, a craft beer with IPA and lager, a chocolate, and extra whipped cream on the side.                                                                                                                                    [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]            None         0.0
# 35                                                                                                                                                                                                                              Coleslaw with mild spice, a Fanta for the drink, cocktails including Margarita, Mojito, and Old Fashioned, apple pie, chocolate, and an extra bun or bread roll.                                                                                                                                                                                                          [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]            None         0.0
# 36                                                                                                                                               Ordering vegetarian and chicken spring rolls, grilled chicken breast with garlic butter and BBQ sauce, a vegan burger without cheese, a cheesecake, a lemon meringue pie, a berry parfait, and milk alternatives with both almond and oat milk.                                                                                                     [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['No Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]            None         0.0
# 37                                                                                                                                                                            I'm ordering chicken spring rolls, grilled salmon with lemon dill and garlic butter, a sweetened iced tea, an Old Fashioned cocktail, cheesecake, mint chocolate chip, and flavored syrups in vanilla and caramel.                                                                                                                   [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]            None         0.0
# 38                                                                                                                 I'm ordering a Garden Salad with balsamic and ranch dressing, Spring Rolls with a mix of vegetarian and chicken, some spicy Chicken Wings with BBQ and buffalo sauce, Grilled Salmon with lemon dill, Fish and Chips that are crispy with fries, and to finish, an Apple Pie.                                                                                                                                                        [{'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}]            None         0.0
# 39                                                                                                                                                                                                                                                                        Can I get an order of Onion Rings with BBQ and Ranch, an Apple Pie, some Chocolate, a Berry Parfait, and Extra Cheese?                                                                                                                                                                                                                                                                                                  [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]            None         0.0
# 40                                                                                                                                                                                                                                         A Greek salad with falafel, mozzarella sticks with ranch, a fruit salad, extra dipping sauces of ranch and blue cheese, and some extra whipped cream.                                                                                                                                                                                                                                                   [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]            None         0.0
# 41                                        Ordering tomato soup with cheddar cheese, cream of mushroom with truffle oil and chopped parsley, spicy coleslaw, a vegan burger with vegan mayo, ketchup, no cheese, mustard, and vegan cheese, plus soft drinks including Sprite, Coke, and Fanta, craft beer options of pale ale, lager, and IPA, and an extra side of mashed potatoes and veggies.  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Mustard', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}]            None         0.0
# 42                                                                                                                                                                                             Miso soup with toasted sesame seeds and chili oil, mild coleslaw, vegetable stir-fry with peanut sauce, teriyaki, and garlic soy, a chocolate cake, a cheesecake, and flavored syrups in vanilla.                                                                                                                                                              [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Peanut Sauce', 'Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]            None         0.0
# ...
# 164                                                                                                                                                         Ordering Fish and Chips with onion rings, crispy fries, and extra crispy. Also getting a lemonade, vanilla ice cream, mint chocolate chip ice cream, an extra scoop of ice cream, and I'll go with oat milk for my milk alternative.                                                                                                                                                                                  [{'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]            None         0.0
# 165                                                                                                                                                              Ordering a bowl of Cream of Mushroom with truffle oil, Grilled Tofu drizzled with peanut sauce and chili lime, a slice of Apple Pie, a slice of Lemon Meringue Pie, some vanilla, and flavored syrups with caramel and vanilla.                                                                                                                                                                                       [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]            None         0.0
# 166                                                                                                                                                                                                                                      Spicy coleslaw, mozzarella sticks with marinara, grilled chicken breast with garlic butter, chocolate, apple crumble, and extra chocolate chips on top.                                                                                                                                                                                               [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]            None         0.0
# 167                                                                                             I want a Greek Salad with grilled chicken and falafel, a mild and spicy coleslaw, chicken and vegetarian spring rolls, a shrimp cocktail with lemon herb and spicy cocktail sauce, a slice of lemon meringue pie, an apple crumble, and some extra sauces including gravy, BBQ sauce, and pesto.                                                           [{'customizations': ['No Protein', 'Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Gravy', 'BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}]            None         0.0
# 168                                                                                                                                                                                                                 Ordering a tomato soup with croutons and basil pesto, a Greek salad topped with grilled chicken and falafel, a strawberry, a berry parfait, and an extra scoop of ice cream.                                                                                                                                                                                                                                               [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]            None         0.0
# 169                                                                                                                                  Spring Rolls with vegetarian filling, Grilled Salmon with garlic butter and lemon dill, Shrimp Cocktail with lemon herb, Fish and Chips with fries and onion rings, extra crispy and crispy, a slice of Lemon Meringue Pie, a Strawberry, and extra cheese.                                                                                          [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Fries', 'Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Cheese'}]            None         0.0
# 170                                                           I'll have a Tomato Soup with croutons, cheddar cheese, and basil pesto, a Chicken Soup with fresh parsley, a Grilled Salmon with garlic butter and lemon dill, Fish and Chips extra crispy with fries, crispy onion rings, and some soft drinks including Coke, Sprite, and Fanta. Also add almond milk for the milk alternatives.                                                                      [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]            None         0.0
# 171                                                                                                                                                                                                                         I'll have coleslaw with mild sauce, grilled tofu with soy ginger, peanut sauce, and chili lime, a glass of white wine, chocolate, and mint chocolate chip ice cream.                                                                                                                                                                                                                                                           [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]            None         0.0
# 172                                                                                                                                       Miso Soup with toasted sesame seeds, Greek Salad with falafel and grilled chicken, Grilled Salmon with lemon dill, Vegan Burger without cheese, Grilled Tofu with chili lime and peanut sauce, and a Craft Beer selection of Pale Ale, Lager, and IPA.                                                                                                                 [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Falafel', 'Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}]            None         0.0
# 173                                                                                                                                                                                                    I'll have the Chicken Soup with fresh parsley and a lemon wedge, a mild coleslaw, chicken wings with buffalo, spicy, and BBQ sauces, a shrimp cocktail with lemon herb, and a cheesecake.                                                                                                                                                                                                                                   [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]            None         0.0
# 174                                                                                                                                                                                                   Grilled Chicken Breast with BBQ sauce, a Fresh Carrot Juice, Craft Beer featuring both IPA and Lager, a slice of Chocolate Cake, a Berry Parfait, and Almond Milk for my milk alternative.                                                                                                                                                                                                  [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]            None         0.0
# 175                                                                                                                                                                                       I want a Chicken Soup with fresh parsley and a lemon wedge, a side of spicy buffalo chicken wings, a carrot fresh juice, a pale ale craft beer, a chocolate cake, vanilla, and an extra shot of vodka.                                                                                                                            [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]            None         0.0
# 176                                                                                                                             Can I get a Garden Salad with balsamic dressing, a side of onion rings with BBQ sauce, grilled salmon topped with garlic butter, grilled tofu with soy ginger, an iced tea that's sweetened, a scoop of mint chocolate chip ice cream, and an extra bun, please?                                                                                                                       [{'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]            None         0.0
# 177                                                                                                                                                                                                                                                       I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]            None         0.0
# 178                                                                                                                                                                                                                                                 Caesar Salad with grilled chicken but no protein, Fish and chips extra crispy with crispy fries, Apple pie, Berry parfait, and extra cheese.                                                                                                                                                                                                                                          [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]            None         0.0
# 179                                                                                                                                                                        I'll have some Sprite and Fanta for the soft drinks. For craft beer, please add Pale Ale, IPA, and Lager. Also, getting an apple pie and an apple crumble. And don't forget the extra cheese and extra whipped cream.                                                                                                                                                                                                             [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]            None         0.0

# %%
df.head(5)
# Out:
#                                     transcribed_text   speaker  \
# 0  Ordering a Shrimp Cocktail with Lemon Herb, Ve...  af_bella
# 1  Ordering Fish and Chips with Onion Rings, an A...  af_bella
# 2  Order a Chocolate Cake, an Extra Ice Cream Sco...  af_bella
# 3  Can I get an apple crumble and a lemonade? Als...  af_bella
# 4  Coleslaw with a spicy kick, cream of mushroom ...  af_bella
#
#                                                items  \
# 0  [{'customizations': ['Lemon Herb'], 'name': 'S...
# 1  [{'customizations': ['Onion Rings'], 'name': '...
# 2  [{'customizations': [], 'name': 'Chocolate Cak...
# 3  [{'customizations': [], 'name': 'Apple Crumble...
# 4  [{'customizations': ['Spicy', 'Mild'], 'name':...
#
#                                      predicted_items  similarity  exact_match
# 0  [{'customizations': ['Lemon Herb'], 'name': 'S...    1.000000         True
# 1  [{'customizations': ['Onion Rings'], 'name': '...    0.760246        False
# 2  [{'customizations': [], 'name': 'Chocolate Cak...    1.000000         True
# 3  [{'customizations': [], 'name': 'Apple Crumble...    0.932673        False
# 4  [{'customizations': ['Spicy', 'Mild'], 'name':...    1.000000         True

# %%
df['predicted_items'].isnull().sum()
# Out:
# np.int64(0)

# %%
pipe(prefix + , max_new_tokens=200, return_full_text=False, pad_token_id=tokenizer.eos_token_id)
