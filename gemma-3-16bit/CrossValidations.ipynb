# %%
# !pip install -q -U transformers datasets accelerate peft trl bitsandbytes scipy

# %%
import torch
import os
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel, get_peft_model, prepare_model_for_kbit_training
from trl import SFTTrainer

from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# # **Load Small Dataset**

# %%
model_id = "google/gemma-3-1b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
eos_token = tokenizer.eos_token

print(f"EOS Token: {eos_token}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# EOS Token: <eos>

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1200, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-small-clean-12k' (split: 'train')...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1200
# })
# Splitting dataset into train and validation sets...
# Train set size: 1080
# Validation set size: 120
# WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-small-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-1b-it...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) in torch.bfloat16
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-small-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/104M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [00:18<00:00,  4.70s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9866
# ✅ Exact Match Accuracy: 86.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                          transcribed_text                                                                                                                                                                                                                                                                                                       items                                                                                                                                                                                                                                                                                                            predicted_items  similarity
# 9   Hey, can I get some mozzarella sticks with marinara and ranch, fish and chips with extra crispy fries, an extra topping of chocolate chips and berries, and a drink with almond milk?  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Extra Crispy', 'Crispy', 'On the Side'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.517483
# 21                                               Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.                          [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                            [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.770161
# 28                                                              Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                                      [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                       [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.794366

# %% [markdown]
# ### **Medium 1b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-medium-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) in torch.bfloat16
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-medium-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/104M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [00:40<00:00, 10.18s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.7439
# ✅ Exact Match Accuracy: 15.83%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                       transcribed_text                                                                                                                                                                                                                                                                                            items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         predicted_items  similarity
# 1                                                                                                                                    Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                 [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                             [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.700000
# 3                                                                                                                                  Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                 [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.663342
# 4                                                                                                             I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                          [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                   [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.677966
# 5                                                                                                     Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                  [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                  [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['White', 'Red'], 'name': 'Wine'}]    0.659259
# 8                                                                                                                                          Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                    [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                          [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Mashed Potatoes', 'Veggies', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.530337
# 10                                                                               Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                         [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                   [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.750469
# 11                                                                                                                                         I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                           [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                 [{'customizations': ['White', 'Mint Chocolate Chip'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.551020
# 12                                                                                                                                                    Could I get a pale ale and an extra bun, please?                                                                                                                                                              [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                      [{'customizations': ['Pale Ale', 'Extra Bun'], 'name': 'I'll have some soft drinks with Sprite, Coke, and Fanta.'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chocolate Chips', 'Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.448980
# 16                                                                                                                    Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                 [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                 [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.552632
# 18                                                                                                 Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                             [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                   [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.601942
# 21                                                            Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.               [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                           [{'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.691552
# 22                                                                                                                        Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                               [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                [{'customizations': [], 'name': 'Apple Juice'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.757493
# 23                                                                                                                                             Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.783673
# 24                                                                                                                               Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                           [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                         [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.627063
# 25                                                                                                                                                  Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                         [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                               [{'customizations': ['Ranch', 'Chocolate'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Fries', 'Mashed Potatoes', 'Veggies', 'Rice'], 'name': 'Extra Side'}]    0.477612
# 26                                                                                           Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                     [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.515306
# 27                                                                                                    I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                               [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.653422
# 28                                                                           Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                           [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                  [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.655814
# 30                                                                            Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                     [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                     [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.707775
# 31                                                                                      Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                   [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                    [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.720648
# 33                                                                     Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                               [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                    [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}]    0.649606
# 34                                                                                        Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                                     [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                      [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Iced Tea'}, {'customizations': ['Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.633094
# 37                                                      I'll have a Garden Salad with ranch, balsamic, and vinaigrette, some vegetarian Spring Rolls, and a Grilled Chicken Breast with garlic butter.                                                                          [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                  [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.675630
# 38                                                            Can I get a Miso Soup with toasted sesame seeds and chili oil, some Mozzarella Sticks with ranch on the side, and a slice of cheesecake?                                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                           [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}]    0.720497
# 39                                                                        Can I get an order of Mozzarella Sticks with Ranch and Marinara, a Vegetable Stir-fry with Peanut Sauce, and some Chocolate?                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                            [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.763797
# 40                                                                                         Can I get some spicy coleslaw, buffalo chicken wings with a spicy kick, and an extra shot of vodka, please?                                                                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                      [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.652591
# 41                                                                                                                           Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                            [{'customizations': [], 'name': 'Pizza'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.649007
# 42   I'm ordering a miso soup with toasted sesame seeds, a garden salad with vinaigrette, a grilled chicken breast with BBQ and garlic butter, and a grilled salmon with garlic butter and lemon dill.  [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}]                                                                                      [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.797037
# 43                                                                                                 Can I get a miso soup with toasted sesame seeds and chili oil, and a chocolate on the side, please?                                                                                                                                                                    [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.524664
# 44                                                                                    Can I get a Chicken Soup with a lemon wedge and a Cream of Mushroom topped with chopped parsley and truffle oil?                                                                                                                                               [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}]                                                                                                                                                                                                                                                                                              [{'customizations': ['Lemon Wedge', 'Chopped Parsley', 'Truffle Oil'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}]    0.588235
# 47                                                                                                                                                      Can I get a vanilla and a fruit salad? Thanks!                                                                                                                                                                                                       [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.517134
# 48                                                                                                  Grilled Chicken Breast with BBQ sauce, Fanta and Sprite to drink, and a side of vanilla ice cream.                                                                                                                       [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                            [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]    0.656965
# 51                                                                                                                     Can I get some mozzarella sticks with marinara sauce and a glass of white wine?                                                                                                                                                                                   [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                            [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.485437
# 52                                                                                    Can I get a couple of soft drinks, please? One Sprite and one Fanta. Also, I'll take an apple pie and a vanilla.                                                                                                                                         [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                      [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch'], 'name': 'Gravy'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}]    0.663507
# 53                                                                            Getting a mix of craft beer including IPA, pale ale, and lager along with some wine options, specifically rosÃ© and red.                                                                                                                                                                    [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}]                                                                                              [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Vanilla'}]    0.452756
# 58                                                                                                                                  Can I get a bottle of white wine and a slice of apple pie, please?                                                                                                                                                                                      [{'customizations': ['Rose', 'Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                           [{'customizations': ['White', 'Apple'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.516556
# 59                                                                         Can I get an Old Fashioned cocktail, a slice of chocolate cake, a slice of lemon meringue pie, and a berry parfait, please?                                                                            [{'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                     [{'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.730627
# 61                                                                                                                        Caesar Salad with no protein, extra cheese, and an extra scoop of ice cream.                                                                                                                            [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]  [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Sauce with Pesto, Gravy, and BBQ Sauce'}, {'customizations': [], 'name': 'Extra Topping with Berries, Chocolate Chips, and Nuts'}, {'customizations': [], 'name': 'Extra Shot of Alcohol with Vodka'}]    0.480499
# 62                                                                                                    Grilled Salmon with Lemon Dill and Garlic Butter, plus an extra shot of Vodka, Whiskey, and Rum.                                                                                                                                [{'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Vodka', 'Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                             [{'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Vodka', 'Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Mashed Potatoes', 'Fries', 'Rice'], 'name': 'Extra Side'}]    0.637131
# 66                                                                                                                                            Can I get a chocolate with extra chocolate chips on top?                                                                                                                                                                                  [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                             [{'customizations': ['Chocolate'], 'name': 'Extra Chocolate Chips'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.388889
# 69                                                                                                                                            Ordering some BBQ chicken wings and a vanilla ice cream.                                                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Vanilla'}]                                                                   [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.352941
# 71                                                                                                     Grilled chicken breast with BBQ and garlic butter, and a side of mint chocolate chip ice cream.                                                                                                                                                          [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                      [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fries', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.521561
# 72                                                                                                             Can I get some spicy coleslaw and extra sauce with BBQ sauce, gravy, and pesto, please?                                                                                                                                                          [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.626316
# 73                                   For my order, please add grilled chicken and falafel to the Greek salad, and for the vegetable stir-fry, I'd like it with peanut sauce, teriyaki, and garlic soy.                                                                                                                        [{'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                [{'customizations': ['No Protein', 'Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]    0.663883
# 77                                                            Can I get some mild coleslaw, shrimp cocktail with lemon herb and spicy cocktail sauce, and a mix of Fanta, Coke, and Sprite for drinks?                                                                                      [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}]                                                                                                                         [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.675000
# ...
# 103                                                                                                                           One chocolate cake, one apple pie, and some extra whipped cream, please.                                                                                                                                           [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                               [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.646512
# 104                                                                                                                    I'm ordering a fruit salad and an extra sauce with pesto, BBQ sauce, and gravy.                                                                                                                                                                      [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.742671
# 105                                                                                           Order a Greek Salad with grilled chicken but no additional protein, and a mint chocolate chip ice cream.                                                                                                                                                            [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                            [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.620499
# 106                                                                                                  Can I get a fresh orange juice, an extra side of mashed potatoes and fries, and some almond milk?                                                                                               [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                          [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.715128
# 107                                                                                                                                                            I'd like a cheesecake and an apple pie.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.521739
# 108                                                                                  Ordering a Vegetable Stir-fry with peanut sauce and garlic soy, a chocolate cake, and an extra gravy on the side.                                                                                                       [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                             [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}]    0.768212
# 110            Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                                       [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                   [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.762684
# 111           Can I get some coleslaw, make it mild and spicy? Also, I'd like the fish and chips with onion rings, extra crispy, and some fries on the side. For dessert, please add an apple crumble.                                                                                             [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                     [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Crispy', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.657040
# 112                                               Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                           [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                       [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.639456
# 113                                                                                                      I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                       [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                       [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.672304
# 115                                                                                                                            Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                            [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                      [{'customizations': ['Vinaigrette', 'Spicy'], 'name': 'Garden Salad'}, {'customizations': ['Ketchup', 'Vegan Mayo', 'No Cheese', 'Mustard', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}]    0.440171
# 116                                                                                Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                    [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                              [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.668041
# 117                                                           Can I get some vegetarian spring rolls, a cheesecake, a fruit salad, and for the extra topping, please include nuts and chocolate chips?                                                              [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                 [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.750000
# 118                                                                                  I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                         [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Rose', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.508411
# 119                                                                                              Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                               [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.757576

# %% [markdown]
# ### **Large 1b Model, Small Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-large-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) in torch.bfloat16
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-large-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/104M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:17<00:00, 19.38s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.4812
# ✅ Exact Match Accuracy: 0.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                                                       items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              predicted_items  similarity
# 0                                                                                                                I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': ['Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.540816
# 1                                                                                                                                                           Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                            [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Honey', 'Agave Nectar'], 'name': 'Flavored Syrups'}]    0.441860
# 2                                                                                                         Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                                   [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Lemonade'}]    0.556548
# 3                                                                                                                                                         Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                            [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Balsamic', 'Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.433225
# 4                                                                                                                                    I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                                     [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                            [{'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}]    0.381992
# 5                                                                                                                            Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Extra Whipped Cream'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Lemonade'}]    0.604414
# 6                             Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['No Cheese'], 'name': 'Pizza'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.600884
# 7                       Can I get a Garden Salad with Ranch, a dozen Spicy Buffalo BBQ Chicken Wings, Fish and Chips with crispy batter and onion rings on the side, and a Craft Beer with a mix of Lager, IPA, and Pale Ale?                          [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.782071
# 8                                                                                                                                                                 Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                               [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['No Protein', 'Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Cheesecake'}]    0.374603
# 9                                       Hey, can I get some mozzarella sticks with marinara and ranch, fish and chips with extra crispy fries, an extra topping of chocolate chips and berries, and a drink with almond milk?  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.669154
# 10                                                                                                      Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                                    [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]  [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Ranch', 'Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}]    0.394477
# 11                                                                                                                                                                I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                                      [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                               [{'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}]    0.289634
# 12                                                                                                                                                                           Could I get a pale ale and an extra bun, please?                                                                                                                                                                         [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                   [{'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}]    0.347826
# 13                                                                                                 Can I get a Garden Salad with vinaigrette and ranch, a spicy order of chicken wings, a chocolate cake, and some chocolate?                                                                               [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                 [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}]    0.485714
# 14                                                                                                    Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                               [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.544489
# 15                                                    Ordering a Tomato Soup with Cheddar Cheese, a Caesar Salad topped with Grilled Shrimp and Grilled Chicken, a slice of Chocolate Cake, and a scoop of Vanilla ice cream.                                                             [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                            [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]    0.491187
# 16                                                                                                                                           Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}]    0.403071
# 17                                                                                              Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                                                     [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}]    0.591195
# 18                                                                                                                        Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                  [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Chili Lime', 'Peanut Sauce', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Vegan Mayo', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.346786
# 19                                                    Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                                              [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Chips'}]    0.595065
# 20                                                                                                    I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                                  [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                          [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Veggies', 'No Protein', 'Grilled Chicken'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}]    0.450952
# 21                                                                                   Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.                          [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.506829
# 22                                                                                                                                               Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                                          [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Peanut Sauce'], 'name': 'Grilled Tofu'}]    0.549091
# 23                                                                                                                                                                    Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                                     [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                               [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]    0.320000
# 24                                                                                                                                                      Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}]    0.424107
# 25                                                                                                                                                                         Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}]    0.423581
# 26                                                                                                                  Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                             [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.290230
# 27                                                                                                                           I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                             [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}]    0.498316
# 28                                                                                                  Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                                      [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}]    0.537143
# 29                                                                                                                             Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                                     [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemonade'}]    0.476923
# 30                                                                                                   Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Vegan Cheese', 'Mustard', 'No Cheese', 'Ketchup', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.472272
# 31                                                                                                             Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                              [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}]    0.576985
# ...
# 109                                                   Can I get some chicken spring rolls, grilled salmon with garlic butter and lemon dill, a spicy shrimp cocktail, and extra sauces including BBQ sauce, pesto, and gravy?                     [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}]    0.753623
# 110                                   Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                                                  [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Strawberry'}]    0.726989
# 111                                  Can I get some coleslaw, make it mild and spicy? Also, I'd like the fish and chips with onion rings, extra crispy, and some fries on the side. For dessert, please add an apple crumble.                                                                                                        [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                     [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.496552
# 112                                                                      Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                                      [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                                                                                            [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Rose', 'White'], 'name': 'Wine'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}]    0.416544
# 113                                                                                                                             I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                                  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                       [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce', 'Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.435616
# 114                                                                       I want an order of Chicken Wings with BBQ and Spicy sauce, a slice of Cheesecake, a Chocolate treat, and some Extra Dipping Sauce with Blue Cheese.                                                                              [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.654952
# 115                                                                                                                                                   Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                      [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.314735
# 116                                                                                                       Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Rice', 'Mashed Potatoes', 'Fries', 'Veggies'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Vanilla'}]    0.555746
# 117                                                                                  Can I get some vegetarian spring rolls, a cheesecake, a fruit salad, and for the extra topping, please include nuts and chocolate chips?                                                                         [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Red', 'Rose', 'White'], 'name': 'Wine'}, {'customizations': ['Fries', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}]    0.115274
# 118                                                                                                         I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                           [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}]    0.484848
# 119                                                                                                                     Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                           [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}]    0.518135

# %% [markdown]
# ### **Medium 4b Model, Small Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-medium-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-medium-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/262M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:04<00:00, 16.10s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.7324
# ✅ Exact Match Accuracy: 13.33%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                             transcribed_text                                                                                                                                                                                                                                                                               items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         predicted_items  similarity
# 0                                                                               I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                               [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.788104
# 1                                                                                                                          Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                    [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.597753
# 2                                                                        Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                           [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                 [{'customizations': [], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.663121
# 3                                                                                                                        Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                    [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.709333
# 4                                                                                                   I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                             [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.643678
# 11                                                                                                                               I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                              [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                 [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.443925
# 12                                                                                                                                          Could I get a pale ale and an extra bun, please?                                                                                                                                                 [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.627907
# 16                                                                                                          Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                    [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                    [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.464602
# 17                                                             Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                             [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]                                             [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vodka', 'Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.491503
# 18                                                                                       Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                              [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Mashed Potatoes', 'Veggies', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.464419
# 19                   Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                      [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Vegan Cheese', 'No Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]    0.277056
# 20                                                                   I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                          [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.694323
# 21                                                  Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.  [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.695652
# 22                                                                                                              Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                  [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.641189
# 23                                                                                                                                   Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                             [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]    0.583587
# 24                                                                                                                     Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                              [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Almond Milk'}, {'customizations': [], 'name': 'Oat Milk'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.451306
# 25                                                                                                                                        Order onion rings with ranch and a chocolate cake.                                                                                                                                                                            [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.506527
# 26                                                                                 Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.664260
# 27                                                                                          I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                     [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.663677
# 28                                                                 Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                              [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.593684
# 29                                                                                            Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                             [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.761671
# 30                                                                  Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                        [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.656716
# 31                                                                            Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                      [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]    0.747899
# 33                                                           Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                  [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.697674
# 34                                                                              Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.568966
# 35                                                             Can I get a spicy and mild coleslaw, grilled salmon with garlic butter, crispy fish and chips, and extra BBQ and pesto sauce?                           [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                               [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.791096
# 37                                            I'll have a Garden Salad with ranch, balsamic, and vinaigrette, some vegetarian Spring Rolls, and a Grilled Chicken Breast with garlic butter.                                                             [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                                                                                                          [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Vanilla'}]    0.667774
# 38                                                  Can I get a Miso Soup with toasted sesame seeds and chili oil, some Mozzarella Sticks with ranch on the side, and a slice of cheesecake?                                                                                          [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.700201
# 41                                                                                                                 Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                           [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': [], 'name': 'Ice Cream'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.506329
# 43                                                                                       Can I get a miso soup with toasted sesame seeds and chili oil, and a chocolate on the side, please?                                                                                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}]    0.582090
# 44                                                                          Can I get a Chicken Soup with a lemon wedge and a Cream of Mushroom topped with chopped parsley and truffle oil?                                                                                                                                  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}]  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.367021
# 45                                                                                  Ordering some spicy buffalo chicken wings, a lemonade, and I'll take almond milk as my milk alternative.                                                                                                   [{'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                [{'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chocolate', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.591337
# 46          I want a Greek Salad with grilled chicken and falafel, a side of onion rings with BBQ sauce, a shrimp cocktail with lemon herb and spicy cocktail sauce, and no dessert for now.        [{'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.791519
# 51                                                                                                           Can I get some mozzarella sticks with marinara sauce and a glass of white wine?                                                                                                                                                                      [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                    [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.444924
# 52                                                                          Can I get a couple of soft drinks, please? One Sprite and one Fanta. Also, I'll take an apple pie and a vanilla.                                                                                                                            [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.681265
# 53                                                                  Getting a mix of craft beer including IPA, pale ale, and lager along with some wine options, specifically rosÃ© and red.                                                                                                                                                       [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.605263
# 54                                                                Can I get a couple of craft beers, one IPA and one lager? Also, I'll take a fruit salad and some extra cheese on the side.                                                                                                                         [{'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.783562
# 58                                                                                                                        Can I get a bottle of white wine and a slice of apple pie, please?                                                                                                                                                                         [{'customizations': ['Rose', 'Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.592334
# 61                                                                                                              Caesar Salad with no protein, extra cheese, and an extra scoop of ice cream.                                                                                                               [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['No Protein', 'Extra Cheese'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.677130
# 62                                                                                          Grilled Salmon with Lemon Dill and Garlic Butter, plus an extra shot of Vodka, Whiskey, and Rum.                                                                                                                   [{'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Vodka', 'Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Vodka', 'Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.792651
# ...
# 95                                                                                          Can I get the grilled tofu with chili lime, a chocolate cake, a chocolate, and an apple crumble?                                                                        [{'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.768293
# 97                                                                                                                                          Grilled Salmon with Lemon Dill and Extra Cheese.                                                                                                                                                                      [{'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                               [{'customizations': ['Lemon Dill', 'Extra Cheese'], 'name': 'Grilled Salmon'}, {'customizations': ['Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Mashed Potatoes', 'Fries', 'Veggies', 'Rice'], 'name': 'Extra Side'}]    0.412826
# 98                                                              Can I get some chicken wings with buffalo, BBQ, and spicy sauces? Also, I'll have a cheesecake and a strawberry on the side.                                                                                                              [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Strawberry'}]                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.642857
# 101                                                                                 Can I get a miso soup with chili oil, a grilled chicken breast with BBQ sauce, and a sweetened iced tea?                                                                                                      [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}]                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}]    0.690678
# 104                                                                                                          I'm ordering a fruit salad and an extra sauce with pesto, BBQ sauce, and gravy.                                                                                                                                                         [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.574307
# 105                                                                                 Order a Greek Salad with grilled chicken but no additional protein, and a mint chocolate chip ice cream.                                                                                                                                               [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.497778
# 106                                                                                        Can I get a fresh orange juice, an extra side of mashed potatoes and fries, and some almond milk?                                                                                  [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.725100
# 107                                                                                                                                                  I'd like a cheesecake and an apple pie.                                                                                                                                                                                         [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                           [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Rice', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}]    0.412776
# 110  Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                          [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                      [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}]    0.766447
# 112                                     Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                              [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                   [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.514599
# 115                                                                                                                  Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                               [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Fanta', 'Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}]    0.536585
# 116                                                                      Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                       [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.720000
# 118                                                                        I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Chocolate Chips'}, {'customizations': [], 'name': 'Berries'}, {'customizations': [], 'name': 'Nuts'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.582441
# 119                                                                                    Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                   [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Old Fashioned', 'Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}]    0.675676

# %% [markdown]
# ### **Large 4b Model, Small Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-large-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-large-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/262M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:30<00:00, 22.72s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.5000
# ✅ Exact Match Accuracy: 0.83%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                                                       items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        predicted_items  similarity
# 0                                                                                                                I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                               [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}]    0.546256
# 1                                                                                                                                                           Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                            [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['White', 'Red'], 'name': 'Wine'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}]    0.608696
# 2                                                                                                         Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                                   [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                          [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.490814
# 3                                                                                                                                                         Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                            [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Vanilla'}]    0.535211
# 4                                                                                                                                    I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                                     [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                          [{'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.471380
# 5                                                                                                                            Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                                                                                                  [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.506401
# 6                             Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                            [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]    0.552846
# 7                       Can I get a Garden Salad with Ranch, a dozen Spicy Buffalo BBQ Chicken Wings, Fish and Chips with crispy batter and onion rings on the side, and a Craft Beer with a mix of Lager, IPA, and Pale Ale?                          [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Cheesecake'}]    0.687500
# 8                                                                                                                                                                 Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                               [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}]    0.434622
# 9                                       Hey, can I get some mozzarella sticks with marinara and ranch, fish and chips with extra crispy fries, an extra topping of chocolate chips and berries, and a drink with almond milk?  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.743094
# 10                                                                                                      Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                                    [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                    [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}]    0.501253
# 11                                                                                                                                                                I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                                      [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                         [{'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Crispy', 'Onion Rings', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.317726
# 12                                                                                                                                                                           Could I get a pale ale and an extra bun, please?                                                                                                                                                                         [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                    [{'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}]    0.309333
# 13                                                                                                 Can I get a Garden Salad with vinaigrette and ranch, a spicy order of chicken wings, a chocolate cake, and some chocolate?                                                                               [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.667758
# 14                                                                                                    Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                  [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Crispy', 'Fries', 'Onion Rings'], 'name': 'Fish and Chips'}]    0.529032
# 15                                                    Ordering a Tomato Soup with Cheddar Cheese, a Caesar Salad topped with Grilled Shrimp and Grilled Chicken, a slice of Chocolate Cake, and a scoop of Vanilla ice cream.                                                             [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                     [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.540804
# 16                                                                                                                                           Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                              [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['No Protein', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.290055
# 17                                                                                              Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                                                     [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]        [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Grilled Chicken Breast'], 'name': 'Grilled Chicken'}, {'customizations': [], 'name': 'Apple'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}]    0.397380
# 18                                                                                                                        Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                            [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Lemonade'}]    0.427586
# 19                                                    Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                                              [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                       [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Rice', 'Mashed Potatoes', 'Veggies', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.521628
# 20                                                                                                    I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                                  [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                 [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Extra Crispy', 'Onion Rings', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Rose', 'Red', 'White'], 'name': 'Wine'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.454286
# 21                                                                                   Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.                          [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                        [{'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.380521
# 22                                                                                                                                               Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                                          [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                             [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}]    0.416552
# 23                                                                                                                                                                    Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                                     [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                                                                                            [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['No Cheese', 'Vegan Mayo', 'Ketchup', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.377953
# 24                                                                                                                                                      Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Red', 'Rose', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.332750
# 25                                                                                                                                                                         Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemonade'}]    0.433036
# 26                                                                                                                  Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.419087
# 27                                                                                                                           I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                             [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                               [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['No Protein', 'Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Veggies', 'Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}]    0.437870
# 28                                                                                                  Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                                      [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                                            [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]    0.470785
# 29                                                                                                                             Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                                     [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Vegan Cheese', 'No Cheese', 'Ketchup', 'Vegan Mayo', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Strawberry'}]    0.545775
# 30                                                                                                   Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                               [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Cheesecake'}]    0.375000
# 31                                                                                                             Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                              [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                      [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['White'], 'name': 'Wine'}]    0.469038
# 32                                                                                                      Can I get an extra ranch dipping sauce, an extra side of veggies, and flavored syrups in vanilla and caramel, please?                                                                                                                [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito', 'Old Fashioned', 'Margarita'], 'name': 'Cocktails'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.619718
# 33                                                                                            Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                                          [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                                                 [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}]    0.510046
# ...
# 108                                                                                                         Ordering a Vegetable Stir-fry with peanut sauce and garlic soy, a chocolate cake, and an extra gravy on the side.                                                                                                                  [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Extra Crispy', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}]    0.541213
# 109                                                   Can I get some chicken spring rolls, grilled salmon with garlic butter and lemon dill, a spicy shrimp cocktail, and extra sauces including BBQ sauce, pesto, and gravy?                     [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]  [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['White', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}]    0.523139
# 110                                   Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                                                  [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                    [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.602067
# 111                                  Can I get some coleslaw, make it mild and spicy? Also, I'd like the fish and chips with onion rings, extra crispy, and some fries on the side. For dessert, please add an apple crumble.                                                                                                        [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                               [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Crispy', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}]    0.547368
# 112                                                                      Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                                      [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                                                                                           [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}]    0.459283
# 113                                                                                                                             I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                                  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Teriyaki', 'Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Fries', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Balsamic', 'Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}]    0.527363
# 114                                                                       I want an order of Chicken Wings with BBQ and Spicy sauce, a slice of Cheesecake, a Chocolate treat, and some Extra Dipping Sauce with Blue Cheese.                                                                              [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                 [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}]    0.610119
# 115                                                                                                                                                   Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                                                          [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}]    0.358891
# 116                                                                                                       Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                              [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.469565
# 117                                                                                  Can I get some vegetarian spring rolls, a cheesecake, a fruit salad, and for the extra topping, please include nuts and chocolate chips?                                                                         [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                        [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.523039
# 118                                                                                                         I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                           [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                             [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Extra Crispy Fries'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Nuts'], 'name': 'Extra Salad Topping'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.407796
# 119                                                                                                                     Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                           [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                          [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mashed Potatoes', 'Cheese'], 'name': 'Extra Side'}, {'customizations': ['Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['White', 'Red'], 'name': 'Wine'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.374065

# %% [markdown]
# ### **Medium 12b Model, Small Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-medium-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-medium-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:22<00:00, 20.74s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.7303
# ✅ Exact Match Accuracy: 20.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                           transcribed_text                                                                                                                                                                                                                                                                                            items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              predicted_items  similarity
# 2                                                                                      Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                        [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                               [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chocolate Chips', 'Berries', 'Nuts'], 'name': 'Extra Topping'}]    0.639316
# 3                                                                                                                                      Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                 [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.636364
# 5                                                                                                         Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                  [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.660482
# 7    Can I get a Garden Salad with Ranch, a dozen Spicy Buffalo BBQ Chicken Wings, Fish and Chips with crispy batter and onion rings on the side, and a Craft Beer with a mix of Lager, IPA, and Pale Ale?               [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                          [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.744548
# 8                                                                                                                                              Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                    [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                   [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}]    0.574209
# 10                                                                                   Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                         [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                   [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Veggies', 'Rice', 'Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.654664
# 11                                                                                                                                             I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                           [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                            [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.465686
# 12                                                                                                                                                        Could I get a pale ale and an extra bun, please?                                                                                                                                                              [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                  [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Mashed Potatoes', 'Fries', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.484305
# 13                                                                              Can I get a Garden Salad with vinaigrette and ranch, a spicy order of chicken wings, a chocolate cake, and some chocolate?                                                                    [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                           [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.786127
# 14                                                                                 Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                                   [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.770677
# 16                                                                                                                        Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                 [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                  [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Fruit Salad'], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.404624
# 17                                                                           Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                                          [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]                                                [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.581144
# 18                                                                                                     Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                             [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                             [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]    0.654354
# 20                                                                                 I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                       [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                              [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['White', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.554974
# 21                                                                Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.               [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                            [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.695652
# 22                                                                                                                            Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                               [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                 [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Oat Milk'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.616327
# 23                                                                                                                                                 Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                           [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]    0.484848
# 24                                                                                                                                   Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                           [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                             [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.421286
# 25                                                                                                                                                      Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                         [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                            [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}]    0.579104
# 26                                                                                               Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                     [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                               [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.403509
# 27                                                                                                        I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.669683
# 28                                                                               Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                           [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                        [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.657343
# 29                                                                                                          Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                          [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                               [{'customizations': ['Falafel', 'Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.738095
# 30                                                                                Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                     [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                     [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Rice', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.645477
# 31                                                                                          Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                   [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                        [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.696673
# 33                                                                         Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                               [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                                                                                                                  [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.702128
# 34                                                                                            Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                                     [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]    0.675192
# 37                                                          I'll have a Garden Salad with ranch, balsamic, and vinaigrette, some vegetarian Spring Rolls, and a Grilled Chicken Breast with garlic butter.                                                                          [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                                                               [{'customizations': ['Ranch', 'Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.758491
# 38                                                                Can I get a Miso Soup with toasted sesame seeds and chili oil, some Mozzarella Sticks with ranch on the side, and a slice of cheesecake?                                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                           [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.732632
# 39                                                                            Can I get an order of Mozzarella Sticks with Ranch and Marinara, a Vegetable Stir-fry with Peanut Sauce, and some Chocolate?                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                     [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Chocolate Chips'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.681102
# 40                                                                                             Can I get some spicy coleslaw, buffalo chicken wings with a spicy kick, and an extra shot of vodka, please?                                                                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                 [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.660194
# 41                                                                                                                               Can I get a pizza with extra cheese and an ice cream with an extra scoop?                                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                        [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': [], 'name': 'Ice Cream'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Fries', 'Rice', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.468599
# 42       I'm ordering a miso soup with toasted sesame seeds, a garden salad with vinaigrette, a grilled chicken breast with BBQ and garlic butter, and a grilled salmon with garlic butter and lemon dill.  [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}]                                                                                               [{'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.783115
# 43                                                                                                     Can I get a miso soup with toasted sesame seeds and chili oil, and a chocolate on the side, please?                                                                                                                                                                    [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                         [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.505400
# 44                                                                                        Can I get a Chicken Soup with a lemon wedge and a Cream of Mushroom topped with chopped parsley and truffle oil?                                                                                                                                               [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}]                                                                                                                                                                                                                  [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}]    0.618834
# 46                        I want a Greek Salad with grilled chicken and falafel, a side of onion rings with BBQ sauce, a shrimp cocktail with lemon herb and spicy cocktail sauce, and no dessert for now.                     [{'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                  [{'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'No Extra Topping'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.786070
# 47                                                                                                                                                          Can I get a vanilla and a fruit salad? Thanks!                                                                                                                                                                                                       [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.590747
# 51                                                                                                                         Can I get some mozzarella sticks with marinara sauce and a glass of white wine?                                                                                                                                                                                   [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                                                          [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.597101
# 53                                                                                Getting a mix of craft beer including IPA, pale ale, and lager along with some wine options, specifically rosÃ© and red.                                                                                                                                                                    [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}]                                                                                                                                                                                                    [{'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}]    0.531178
# 54                                                                              Can I get a couple of craft beers, one IPA and one lager? Also, I'll take a fruit salad and some extra cheese on the side.                                                                                                                                      [{'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                  [{'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.657471
# 57                                                                                   I'll go with mozzarella sticks with ranch, an apple pie, and some extra sauces including gravy, pesto, and BBQ sauce.                                                                                                            [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                          [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Mashed Potatoes', 'Veggies', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.717949
# 58                                                                                                                                      Can I get a bottle of white wine and a slice of apple pie, please?                                                                                                                                                                                      [{'customizations': ['Rose', 'Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                  [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fries', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.516717
# 59                                                                             Can I get an Old Fashioned cocktail, a slice of chocolate cake, a slice of lemon meringue pie, and a berry parfait, please?                                                                            [{'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                             [{'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.754286
# ...
# 93                                                                                      I'll go for a Vegetable Stir-fry with Garlic Soy, Peanut Sauce, and Teriyaki, and add an extra scoop of ice cream.                                                                                                                                          [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                        [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.795518
# 94                                                                                                            Can I get a Grilled Tofu with Soy Ginger and Peanut Sauce, a Lemonade, and an Apple Crumble?                                                                                                                        [{'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                    [{'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]    0.658281
# 97                                                                                                                                                        Grilled Salmon with Lemon Dill and Extra Cheese.                                                                                                                                                                                   [{'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                    [{'customizations': ['Lemon Dill', 'Extra Cheese'], 'name': 'Grilled Salmon'}, {'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}]    0.523810
# 98                                                                            Can I get some chicken wings with buffalo, BBQ, and spicy sauces? Also, I'll have a cheesecake and a strawberry on the side.                                                                                                                           [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Strawberry'}]                                                                                                                                                                                            [{'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.638831
# 100                                                                            Order two cocktails, one Margarita and one Old Fashioned, and an extra side with fries, rice, veggies, and mashed potatoes.                                                                                                                             [{'customizations': ['Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Fries', 'Rice', 'Veggies', 'Mashed Potatoes'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                 [{'customizations': ['Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Fries', 'Rice', 'Veggies', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.761194
# 101                                                                                               Can I get a miso soup with chili oil, a grilled chicken breast with BBQ sauce, and a sweetened iced tea?                                                                                                                   [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}]                                                                                                              [{'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.579041
# 102                                         I'll have a Vegetable Stir-fry with Garlic Soy, Peanut Sauce, and Teriyaki, a Vegan Burger with Mustard, no cheese, vegan cheese, and Ketchup, and a Lemonade.                                                      [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}]                                                                                                                                                                [{'customizations': ['Garlic Soy', 'Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes'], 'name': 'Extra Side'}]    0.759582
# 103                                                                                                                               One chocolate cake, one apple pie, and some extra whipped cream, please.                                                                                                                                           [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                         [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.703797
# 104                                                                                                                        I'm ordering a fruit salad and an extra sauce with pesto, BBQ sauce, and gravy.                                                                                                                                                                      [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.660870
# 105                                                                                               Order a Greek Salad with grilled chicken but no additional protein, and a mint chocolate chip ice cream.                                                                                                                                                            [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                    [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.577320
# 106                                                                                                      Can I get a fresh orange juice, an extra side of mashed potatoes and fries, and some almond milk?                                                                                               [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                             [{'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.712329
# 107                                                                                                                                                                I'd like a cheesecake and an apple pie.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                 [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Rice', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.429668
# 112                                                   Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                           [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                                                                  [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]    0.628062
# 115                                                                                                                                Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                            [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                              [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}]    0.523810
# 118                                                                                      I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.608501

# %% [markdown]
# ### **Large 12b Model, Small Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-large-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-large-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [02:16<00:00, 34.01s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.4823
# ✅ Exact Match Accuracy: 0.00%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                              transcribed_text                                                                                                                                                                                                                                                                                                       items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    predicted_items  similarity
# 0                                                                                                                I'll have some chicken and vegetarian spring rolls, buffalo chicken wings, extra cheese, and a side of rice.                                                                       [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Rose', 'Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Rice'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.647986
# 1                                                                                                                                                           Please order a chocolate cake, an apple pie, and a berry parfait.                                                                                                                                                            [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                      [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Berry', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vodka', 'Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.359459
# 2                                                                                                         Please add extra ranch dipping sauce, extra cheese, and an extra side of fries, veggies, mashed potatoes, and rice.                                                                                                   [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}]                                                                                                                                                                                               [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Fries', 'Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.527504
# 3                                                                                                                                                         Can I get a lemonade, a chocolate, and extra whipped cream, please?                                                                                                                                                            [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                              [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Apple Pie'}]    0.433225
# 4                                                                                                                                    I'll have a bottle of red wine, a slice of cheesecake, and some caramel flavored syrups.                                                                                                                                                     [{'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                           [{'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Garlic Butter', 'Lemon Dill', 'No Sauce'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Veggies', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}]    0.343558
# 5                                                                                                                            Garden Salad with vinaigrette, spicy and mild coleslaw, and chicken and vegetarian spring rolls.                                                                                                             [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]                                                                                                                                                                                                                                                                                                                [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chili Lime', 'Peanut Sauce', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Vegetarian', 'Chicken', 'Lemon Wedge'], 'name': 'Soup'}, {'customizations': [], 'name': 'Lemonade'}]    0.597315
# 6                             Can I get the Cream of Mushroom with some truffle oil and chopped parsley? Also, add a side of onion rings with ranch, and for the extra side, please include mashed potatoes, rice, and fries.                                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                         [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.566667
# 7                       Can I get a Garden Salad with Ranch, a dozen Spicy Buffalo BBQ Chicken Wings, Fish and Chips with crispy batter and onion rings on the side, and a Craft Beer with a mix of Lager, IPA, and Pale Ale?                          [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                                                                                                                                                                                           [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}]    0.700831
# 8                                                                                                                                                                 Cream of Mushroom with Truffle Oil and an extra bun please.                                                                                                                                                                               [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                    [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Vanilla', 'Chocolate'], 'name': 'Extra Ice Cream Flavor'}]    0.407599
# 9                                       Hey, can I get some mozzarella sticks with marinara and ranch, fish and chips with extra crispy fries, an extra topping of chocolate chips and berries, and a drink with almond milk?  [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                             [{'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ketchup', 'No Cheese'], 'name': 'Vegan Burger'}]    0.642775
# 10                                                                                                      Can I get an order of mozzarella sticks with marinara, some crispy fish and chips, a strawberry, and a berry parfait?                                                                                    [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                          [{'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemonade'}]    0.585652
# 11                                                                                                                                                                I'll have a white wine and a mint chocolate chip ice cream.                                                                                                                                                                                                      [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                   [{'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vinaigrette'], 'name': 'Salad'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.333919
# 12                                                                                                                                                                           Could I get a pale ale and an extra bun, please?                                                                                                                                                                         [{'customizations': ['Pale Ale', 'Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Veggies', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]    0.431138
# 13                                                                                                 Can I get a Garden Salad with vinaigrette and ranch, a spicy order of chicken wings, a chocolate cake, and some chocolate?                                                                               [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                  [{'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Mashed Potatoes', 'Veggies', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}]    0.510000
# 14                                                                                                    Ordering a mild coleslaw, grilled salmon with garlic butter, red and rose wine, and some extra gravy sauce on the side.                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                    [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}]    0.629800
# 15                                                    Ordering a Tomato Soup with Cheddar Cheese, a Caesar Salad topped with Grilled Shrimp and Grilled Chicken, a slice of Chocolate Cake, and a scoop of Vanilla ice cream.                                                             [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                            [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.655835
# 16                                                                                                                                           Can I get an order of chicken spring rolls and some extra whipped cream, please?                                                                                                                                                                                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                    [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Apple', 'Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Ketchup', 'No Cheese', 'Vegan Mayo', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}]    0.266836
# 17                                                                                              Let's get a Caesar salad with grilled chicken, a grilled chicken breast with BBQ and garlic butter, and a fresh apple juice.                                                                                                     [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}]  [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.422947
# 18                                                                                                                        Can I get an order of mozzarella sticks with ranch and marinara, plus some vanilla flavored syrups?                                                                                                                                                                        [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                               [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.431304
# 19                                                    Can I get a vegan burger with vegan cheese, mustard, ketchup, vegan mayo, and no cheese? Also, I'll have a margarita and a mojito. For dessert, let's add an apple pie.                                                                              [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                        [{'customizations': ['Vegan Cheese', 'Mustard', 'Ketchup', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}]    0.514429
# 20                                                                                                    I'll have a Greek salad with grilled chicken, a garden salad with balsamic dressing, and some extra cheese on the side.                                                                                                                                  [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                        [{'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Strawberry'], 'name': 'Extra Topping'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Fanta', 'Sprite', 'Coke'], 'name': 'Soft Drinks'}]    0.433834
# 21                                                                                   Ordering a Caesar Salad with grilled shrimp, a Greek Salad with grilled chicken, an apple pie, and some extra blue cheese dipping sauce.                          [{'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                       [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Rose'], 'name': 'Wine'}]    0.415423
# 22                                                                                                                                               Can I get a fresh apple juice, extra cheese, and an extra bun or bread roll?                                                                                                                                          [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                          [{'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Vegan Mayo', 'No Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.444118
# 23                                                                                                                                                                    Please order a Lemon Meringue Pie and an Apple Crumble.                                                                                                                                                                                                     [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                           [{'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Mojito', 'Old Fashioned'], 'name': 'Cocktails'}]    0.287425
# 24                                                                                                                                                      Please get me a chocolate ice cream with an extra scoop of ice cream.                                                                                                                                                                                                      [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.336879
# 25                                                                                                                                                                         Order onion rings with ranch and a chocolate cake.                                                                                                                                                                                                    [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}]    0.397541
# 26                                                                                                                  Can I get a pizza with extra cheese and some flavored syrups on the side, please? Caramel would be great.                                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                                                                                             [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}]    0.399209
# 27                                                                                                                           I want a Garden Salad with ranch dressing, some chicken spring rolls, and a glass of white wine.                                                                                                                                             [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}]                                                                                                                                                                                                                                                  [{'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vegetarian', 'Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Vegetarian', 'Lemon Wedge', 'Fresh Parsley'], 'name': 'Vegetarian'}, {'customizations': [], 'name': 'Cheesecake'}]    0.473600
# 28                                                                                                  Can I get a tomato soup with cheddar cheese, basil pesto, and croutons? Also, I'd like an Old Fashioned cocktail, please.                                                                                                                                                      [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}]                                                                                                                                                                                                                                                 [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.455574
# 29                                                                                                                             Can I get a Greek Salad with falafel and grilled chicken, a vanilla item, and a berry parfait?                                                                                                                                     [{'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                [{'customizations': ['No Protein', 'Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.553571
# 30                                                                                                   Can I get a grilled chicken breast with BBQ sauce and some extra dipping sauces, please? I'd like blue cheese and ranch.                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                                                                                         [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemonade'}]    0.472272
# 31                                                                                                             Can I get a grilled chicken breast with BBQ and garlic butter, a margarita cocktail, and a lemon meringue pie?                                                                                                              [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                   [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Cheesecake'}]    0.532934
# 32                                                                                                      Can I get an extra ranch dipping sauce, an extra side of veggies, and flavored syrups in vanilla and caramel, please?                                                                                                                [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]        [{'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]    0.404598
# 33                                                                                            Please get some spicy coleslaw, onion rings with ranch and BBQ sauce, and a couple of cocktailsâ€”one margarita and one mojito.                                                                                                                          [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}]                                                                                                                     [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Chocolate Chips', 'Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}]    0.434783
# 34                                                                                                               Can I get an order of mozzarella sticks with ranch and marinara, and a vegetable stir-fry with peanut sauce?                                                                                                                                                                [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                     [{'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Rice', 'Mashed Potatoes', 'Veggies', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}]    0.396992
# ...
# 108                                                                                                         Ordering a Vegetable Stir-fry with peanut sauce and garlic soy, a chocolate cake, and an extra gravy on the side.                                                                                                                  [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]    0.632727
# 109                                                   Can I get some chicken spring rolls, grilled salmon with garlic butter and lemon dill, a spicy shrimp cocktail, and extra sauces including BBQ sauce, pesto, and gravy?                     [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}]                            [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['BBQ Sauce', 'Pesto', 'Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.553191
# 110                                   Let's go with a Cream of Mushroom soup topped with chopped parsley, some onion rings with BBQ sauce, grilled salmon with garlic butter, and a couple of craft beersâ€”IPA and Pale Ale.                                                  [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}]                                                                                [{'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Fries', 'Crispy', 'Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}]    0.541231
# 111                                  Can I get some coleslaw, make it mild and spicy? Also, I'd like the fish and chips with onion rings, extra crispy, and some fries on the side. For dessert, please add an apple crumble.                                                                                                        [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                     [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Onion Rings', 'Crispy', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]    0.581470
# 112                                                                      Can I get an order of vegetarian spring rolls and chicken spring rolls? Also, I'd like the grilled salmon with lemon dill and garlic butter, please.                                                                                                                                                      [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]                                                                                                                                                                         [{'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}]    0.411679
# 113                                                                                                                             I'll have a tomato soup with cheddar cheese, a fruit salad, and some caramel flavored syrups.                                                                                                                                  [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                 [{'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Balsamic', 'Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}]    0.499215
# 114                                                                       I want an order of Chicken Wings with BBQ and Spicy sauce, a slice of Cheesecake, a Chocolate treat, and some Extra Dipping Sauce with Blue Cheese.                                                                              [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                       [{'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.591631
# 115                                                                                                                                                   Can I get a garden salad with vinaigrette and some spicy chicken wings?                                                                                                                                                                                       [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}]                                                                                                                                                                                                                               [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Ketchup', 'No Cheese', 'Mustard', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.364238
# 116                                                                                                       Can I please get a Chicken Soup with fresh parsley, a Grilled Salmon with lemon dill, and extra cheese on the side?                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                         [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}]    0.538206
# 117                                                                                  Can I get some vegetarian spring rolls, a cheesecake, a fruit salad, and for the extra topping, please include nuts and chocolate chips?                                                                         [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                     [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}]    0.626866
# 118                                                                                                         I'll have the chicken soup with fresh parsley and an extra shot of alcohol that includes whiskey, vodka, and rum.                                                                                                                                                           [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                        [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}]    0.400000
# 119                                                                                                                     Ordering a Shrimp Cocktail with Lemon Herb, a refreshing Lemonade, and a slice of Lemon Meringue Pie.                                                                                                                                           [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                     [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.437956

# %% [markdown]
# # **Load Medium Dataset**

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-medium-clean-18k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1800, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-medium-clean-18k' (split: 'train')...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/28 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/24 [00:00<?, ?it/s]
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1800
# })
# Splitting dataset into train and validation sets...
# Train set size: 1620
# Validation set size: 180
# WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.

# %% [markdown]
# ### **Small 1b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-small-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) in torch.bfloat16
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-small-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 6/6 [00:47<00:00,  7.95s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9310
# ✅ Exact Match Accuracy: 52.78%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                 transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  predicted_items  similarity
# 0    I want a Cream of Mushroom soup with truffle oil, some spring rolls with vegetarian and chicken, a portion of chicken wings with BBQ, Buffalo, and spicy sauces, a grilled chicken breast with BBQ, and a selection of soft drinks including Fanta, Coke, and Sprite. Also, add some craft beer â€” a mix of lager, pale ale, and IPA, and I'll need extra sauces like pesto and BBQ sauce.  [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                             [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Pesto', 'BBQ Sauce'], 'name': 'Craft Beer'}]    0.792699
# 7                                                                                                                                                                                                                 Ordering a Shrimp Cocktail with spicy cocktail sauce, sweetened iced tea, a mix of red and rose wine, an extra side of mashed potatoes, and oat milk for the milk alternative.                                                                                                                                                                                          [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                     [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.760417
# 14                                                                                                                                                                                       I'll have a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a side of mild and spicy coleslaw, a sweetened iced tea, extra cheese, extra whipped cream, and an extra shot of vodka.                                                                                                     [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                       [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Extra Cheese', 'Extra Whipped Cream', 'Extra Shot of Vodka'], 'name': 'Iced Tea'}]    0.723684
# 18                                                                               I'll have the chicken soup with a lemon wedge, grilled salmon topped with garlic butter and lemon dill. For dessert, I'd like a slice of cheesecake, and also, please include the chocolate and strawberry. Additionally, a side of fruit salad and extra sauces of gravy, pesto, and BBQ sauce would be great.                                                                                       [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                           [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.794788
# 21                                                                                                                                                                I'll have a Chicken Soup with fresh parsley, a Caesar Salad with grilled chicken, BBQ chicken wings, grilled salmon with lemon dill and garlic butter, a spicy shrimp cocktail, and soft drinks including a Sprite and a Coke.                                                                                                [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                 [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Grilled Chicken', 'BBQ Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}]    0.643678
# 22                                                                                                                                                                                             Caesar Salad with no protein, spicy and mild coleslaw, onion rings with BBQ sauce, iced tea half unsweetened and half sweetened, a chocolate cake, a cheesecake, and an extra scoop of ice cream.                                                                                             [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                          [{'customizations': ['No Protein', 'Spicy', 'Mild'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Spicy Coleslaw'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.347709
# 25                                                                                                                                                                 I want an order of mozzarella sticks with ranch, chicken wings with buffalo, BBQ, and spicy sauce, fish and chips extra crispy with onion rings, some chocolate, extra blue cheese for dipping, and an extra shot of whiskey.                                                                                     [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                     [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Extra Crispy', 'Onion Rings', 'Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.461133
# 26                                                                                                                                                                                                                                       Can I get a spicy coleslaw and a shrimp cocktail with lemon herb? Also, a lemonade, a mojito, a glass of rosÃ© wine, and some extra cheese on the side.                                                                                                                                                                              [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito', 'Cocktails'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Rose Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.695507
# 28                                                                                                                                                                                                                                                   Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                                                                [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                         [{'customizations': ['Basil Pesto', 'Spicy', 'Buffalo'], 'name': 'Tomato Soup'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.468354
# 43                                                                                             Can I get a Garden Salad with vinaigrette, a Grilled Salmon topped with lemon dill and garlic butter, a Shrimp Cocktail with spicy cocktail sauce, Fish and Chips with onion rings and extra crispy, Grilled Tofu with chili lime, a slice of Lemon Meringue Pie, and an extra bun or bread roll?                            [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]         [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.686230
# 56                                                                                                                                                                    I'll have the chicken soup with fresh parsley and a lemon wedge, spring rolls with chicken, fish and chips with fries and crispy onion rings, a lemonade, a chocolate cake, a chocolate, and flavored syrups with vanilla.                                                                       [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                                       [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Crispy', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.417414
# 62                                               I want a Greek Salad with no protein, add falafel and grilled chicken. Also, get a Vegetable Stir-fry with peanut sauce and teriyaki. For dessert, include a chocolate cake and some mint chocolate chip ice cream. Don't forget extra dipping sauces with blue cheese and ranch, and add extra toppings of berries, chocolate chips, and nuts.                                                   [{'customizations': ['No Protein', 'Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                               [{'customizations': ['No Protein', 'Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.769231
# 76                                                                                                                                                                                   I'll have a Tomato Soup with Cheddar Cheese and Croutons, Spicy Buffalo Chicken Wings, Vegetable Stir-fry with Peanut Sauce, Grilled Tofu with Chili Lime and Soy Ginger, an Apple Pie, and some Chocolate.                                                                                                                 [{'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                     [{'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Peanut Sauce', 'Grilled Tofu'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}]    0.672897
# 84                                                                                                                                                                   Grilled Chicken Breast with BBQ and Garlic Butter, unsweetened iced tea, lemonade, fresh juices with carrot, apple, and orange, a lager craft beer, and strawberries on the side. Also, an extra bun or bread roll, please.                                                                         [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                             [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.512668
# 126                                                                                                                 I'll have the Chicken Soup with a lemon wedge, a Greek Salad without any protein, Fish and Chips with crispy onion rings and extra crispy fries, Grilled Tofu with chili lime, an Apple Pie, a Berry Parfait, and some milk alternatives including oat milk and almond milk.                                     [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]                                               [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy', 'Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.412888
# 154                                                                                                                                                                    I would like to order Miso Soup with toasted sesame seeds and chili oil, vegetarian spring rolls, extra crispy fish and chips with fries, apple pie, vanilla ice cream, chocolate ice cream, and extra gravy on the side.                                                                                       [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]                                                                                                                   [{'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Crispy', 'Extra Crispy', 'Fries', 'On the Side'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}]    0.727273
# 166                                                                                                                                                                                                                                      Spicy coleslaw, mozzarella sticks with marinara, grilled chicken breast with garlic butter, chocolate, apple crumble, and extra chocolate chips on top.                                                                                                                                            [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                              [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.097710
# 170                                                           I'll have a Tomato Soup with croutons, cheddar cheese, and basil pesto, a Chicken Soup with fresh parsley, a Grilled Salmon with garlic butter and lemon dill, Fish and Chips extra crispy with fries, crispy onion rings, and some soft drinks including Coke, Sprite, and Fanta. Also add almond milk for the milk alternatives.                   [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]  [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Extra Crispy', 'Fries', 'Onion Rings', 'Crispy', 'Apple Crumble'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.625139
# 178                                                                                                                                                                                                                                                 Caesar Salad with grilled chicken but no protein, Fish and chips extra crispy with crispy fries, Apple pie, Berry parfait, and extra cheese.                                                                                                                                                                                       [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                       [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Crispy', 'Extra Crispy', 'Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.387435

# %% [markdown]
# ### **Large 1b Model, Medium Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-large-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) in torch.bfloat16
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-large-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 6/6 [01:31<00:00, 15.21s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8234
# ✅ Exact Match Accuracy: 21.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                     transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                   items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 predicted_items  similarity
# 7                                                                                                                                                                     Ordering a Shrimp Cocktail with spicy cocktail sauce, sweetened iced tea, a mix of red and rose wine, an extra side of mashed potatoes, and oat milk for the milk alternative.                                                                                                                                                           [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                        [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Rose', 'White'], 'name': 'Wine'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}]    0.454640
# 9                                                                                                                                  Order a Cream of Mushroom with truffle oil and chopped parsley, a side of onion rings with ranch and BBQ sauce, an iced tea that's sweetened, a refreshing lemonade, and some fresh juices with orange and apple.                                                                                                                                                  [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Buffalo', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.713043
# 10                                                                                                                                    I'll have a tomato soup with croutons, a miso soup with chili oil and toasted sesame seeds, a mojito cocktail, an extra topping of chocolate chips, and an extra shot of alcohol with rum, whiskey, and vodka.                                                                                                                      [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                        [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.624381
# 11                                                                                                                              Ordering some onion rings with BBQ and ranch, a grilled chicken breast with BBQ, a grilled salmon with garlic butter and lemon dill, a lemonade, a couple of cocktailsâ€”margarita and mojitoâ€”and a berry parfait.                                                                                              [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                       [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Chocolate'}]    0.737885
# 15                                                                                                                                                 I'm ordering a Cream of Mushroom with truffle oil and chopped parsley, two soft drinks â€” one Fanta and one Coke, a Pale Ale craft beer, a cheesecake, a lemon meringue pie, and some chocolate.                                                                                                            [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                             [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}]    0.688770
# 16                                                                                                                                                                                                    Grilled chicken breast with BBQ sauce, sweetened iced tea, a lemonade, a cheesecake, and extra toppings of nuts, chocolate chips, and berries.                                                                                                                                                                   [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.684343
# 17                                                                           Going for some Chicken Soup with fresh parsley and a lemon wedge, a bowl of cream of mushroom topped with truffle oil and chopped parsley, a side of shrimp cocktail with lemon herb, a fruit salad, and I'll add extra toppings of nuts, chocolate chips, and berries.                                                                                                  [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.647668
# 19                                                                                                                                               I'll have the Cream of Mushroom with truffle oil and chopped parsley, a fresh juice blend of carrot, orange, and apple, a glass of red wine, vanilla, strawberry, fruit salad, and a berry parfait.                                                                  [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Mojito', 'Old Fashioned', 'Margarita'], 'name': 'Cocktails'}]    0.786418
# 23                                                                                                                                                                                                                I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                              [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]    0.688915
# 25                                                                                                                     I want an order of mozzarella sticks with ranch, chicken wings with buffalo, BBQ, and spicy sauce, fish and chips extra crispy with onion rings, some chocolate, extra blue cheese for dipping, and an extra shot of whiskey.                                                      [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}]    0.796074
# 27                                                                                                                                               Ordering Chicken Soup with a lemon wedge and fresh parsley, a Greek Salad without protein, a Margarita cocktail, a side of strawberries, extra ranch dipping sauce, and an extra bun or bread roll.                                                                                                [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Fanta', 'Sprite', 'Coke'], 'name': 'Soft Drinks'}]    0.785463
# 28                                                                                                                                                                                                       Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                                 [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Lemon Herb'], 'name': 'Chicken Spring Rolls'}]    0.770149
# 30                                                                                                                                                                Cream of Mushroom with truffle oil and chopped parsley, spicy coleslaw, grilled chicken breast with BBQ sauce, grilled salmon with garlic butter and lemon dill, and a cheesecake.                                                                                                                            [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Veggies'], 'name': 'Extra Side'}]    0.695853
# 32                                                                                                                                                                I'll have a Greek Salad with falafel, Spring Rolls with chicken, a side of chocolate, extra ranch dipping sauce, an extra scoop of ice cream, and oat milk as my milk alternative.                                                                                                                    [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch'], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.756886
# 33                                                                                                                                                                                                                 I'll have the Shrimp Cocktail with Lemon Herb and Spicy Cocktail, a Sprite to drink, Chocolate Cake, Apple Pie, and some Vanilla.                                                                                                                                                                                      [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                      [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Crispy', 'Fries', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Mashed Potatoes', 'Veggies', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}]    0.580941
# 37                                                                                                                                I'm ordering chicken spring rolls, grilled salmon with lemon dill and garlic butter, a sweetened iced tea, an Old Fashioned cocktail, cheesecake, mint chocolate chip, and flavored syrups in vanilla and caramel.                                 [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                       [{'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}]    0.742210
# 38                                                                     I'm ordering a Garden Salad with balsamic and ranch dressing, Spring Rolls with a mix of vegetarian and chicken, some spicy Chicken Wings with BBQ and buffalo sauce, Grilled Salmon with lemon dill, Fish and Chips that are crispy with fries, and to finish, an Apple Pie.                                                                      [{'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Spicy', 'BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Balsamic'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.791574
# 39                                                                                                                                                                                                                            Can I get an order of Onion Rings with BBQ and Ranch, an Apple Pie, some Chocolate, a Berry Parfait, and Extra Cheese?                                                                                                                                                                                                                [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}]    0.635854
# 40                                                                                                                                                                                             A Greek salad with falafel, mozzarella sticks with ranch, a fruit salad, extra dipping sauces of ranch and blue cheese, and some extra whipped cream.                                                                                                                                                                 [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                        [{'customizations': ['Falafel', 'No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ketchup', 'Vegan Mayo', 'Mustard', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.148064
# 45                                                                                                                                                                                                   Can I get a sweetened iced tea, some extra cheese, an extra bun, flavored syrups with caramel and vanilla, and oat milk as my milk alternative?                                                                                                                                                                [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Fries', 'Crispy', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.742240
# 46                                                                                              I'll have the Cream of Mushroom with truffle oil and chopped parsley, a Miso Soup with chili oil and toasted sesame seeds, an Iced Tea both unsweetened and sweetened, a Margarita for cocktails, and some chocolate along with mint chocolate chip.                                                                 [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Teriyaki', 'Peanut Sauce', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['BBQ', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.584723
# 49                                                                                   Ordering a vegan burger with mustard, vegan mayo, and ketchup. Also getting a mix of soft drinks with Sprite and Coke, plus both sweetened and unsweetened iced tea. Don't forget a side of chocolate and some milk alternatives with almond milk and oat milk.                                                                                                                      [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Dipping Sauce (Ranch, Blue Cheese)'}]    0.656954
# 50                                                                                                                                           Shrimp cocktail with spicy cocktail and lemon herb, grilled tofu with chili lime and soy ginger, a lemonade, margarita cocktails, a selection of white, rose, and red wine, and an extra side of fries.                                                                                      [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.772881
# 51                                                                                                                                                     Ordering some onion rings with ranch and BBQ, a grilled chicken breast with garlic butter, shrimp cocktail with lemon herb, an extra whipped cream on the side, and an extra shot of whiskey.                                                                                                                                          [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                               [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['BBQ', 'Spicy'], 'name': 'Fish and Chips'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}]    0.614271
# 52                                                                                                                      Please bring me some Chicken Soup with fresh parsley, a Shrimp Cocktail with spicy cocktail sauce, a Vegan Burger with vegan mayo, a slice of Lemon Meringue Pie, and an extra shot of alcohol with vodka, rum, and whiskey.                                                                                                                                  [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.794771
# 53                                                                                                                                                                    Ordering a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a Vegan Burger with vegan cheese and ketchup, an Apple Pie, extra cheese, and an extra bun or bread roll.                                                                                                                                                      [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Rose', 'White', 'Red'], 'name': 'Wine'}]    0.753316
# ...
# 162                                                                                                                 I'll have the chicken soup with a lemon wedge and fresh parsley, fish and chips with onion rings, fresh juices with orange and carrot, a slice of chocolate cake, extra topping of nuts, and an extra shot of vodka and whiskey.                                                                     [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}]    0.780911
# 163                                                                                                                                                                                 I'll have chicken and vegetarian spring rolls, fish and chips with onion rings, a cheesecake, some chocolate, a fruit salad, apple crumble, and a berry parfait.                                                                                      [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}]    0.786621
# 168                                                                                                                                                                     Ordering a tomato soup with croutons and basil pesto, a Greek salad topped with grilled chicken and falafel, a strawberry, a berry parfait, and an extra scoop of ice cream.                                                                                                                                                             [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                   [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.636782
# 171                                                                                                                                                                             I'll have coleslaw with mild sauce, grilled tofu with soy ginger, peanut sauce, and chili lime, a glass of white wine, chocolate, and mint chocolate chip ice cream.                                                                                                                                                                         [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                             [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Mustard', 'No Cheese', 'Vegan Cheese', 'Vegan Mayo'], 'name': 'Vegan Burger'}]    0.613426
# 173                                                                                                                                                        I'll have the Chicken Soup with fresh parsley and a lemon wedge, a mild coleslaw, chicken wings with buffalo, spicy, and BBQ sauces, a shrimp cocktail with lemon herb, and a cheesecake.                                                                                                                                                 [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}]    0.783673
# 174                                                                                                                                                       Grilled Chicken Breast with BBQ sauce, a Fresh Carrot Juice, Craft Beer featuring both IPA and Lager, a slice of Chocolate Cake, a Berry Parfait, and Almond Milk for my milk alternative.                                                                                                                [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                          [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Red', 'Rose', 'White'], 'name': 'Wine'}]    0.671579
# 177                                                                                                                                                                                                           I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                                  [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Old Fashioned', 'Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}]    0.715190
# 178                                                                                                                                                                                                     Caesar Salad with grilled chicken but no protein, Fish and chips extra crispy with crispy fries, Apple pie, Berry parfait, and extra cheese.                                                                                                                                                        [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                        [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Sprite', 'Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Whiskey', 'Rum'], 'name': 'Extra Shot of Alcohol'}]    0.695545
# 179                                                                                                                            I'll have some Sprite and Fanta for the soft drinks. For craft beer, please add Pale Ale, IPA, and Lager. Also, getting an apple pie and an apple crumble. And don't forget the extra cheese and extra whipped cream.                                                                                                                           [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.694665

# %% [markdown]
# ### **Small 4b Model, Medium Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-small-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-small-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/854 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/262M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 6/6 [00:59<00:00,  9.93s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9639
# ✅ Exact Match Accuracy: 70.56%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                       transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                        items                                                                                                                                                                                                                                                                                                                                                                                                                                                                              predicted_items  similarity
# 43   Can I get a Garden Salad with vinaigrette, a Grilled Salmon topped with lemon dill and garlic butter, a Shrimp Cocktail with spicy cocktail sauce, Fish and Chips with onion rings and extra crispy, Grilled Tofu with chili lime, a slice of Lemon Meringue Pie, and an extra bun or bread roll?  [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]        [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.701956
# 56                                                                          I'll have the chicken soup with fresh parsley and a lemon wedge, spring rolls with chicken, fish and chips with fries and crispy onion rings, a lemonade, a chocolate cake, a chocolate, and flavored syrups with vanilla.                                             [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]                                                     [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Chicken', 'Fish'], 'name': 'Spring Rolls'}, {'customizations': ['Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.284981
# 72                                                                                                        Coleslaw with mild dressing, fish and chips extra crispy with onion rings and fries, fresh juices including apple and orange, a margarita cocktail, and blue cheese for extra dipping sauce.                                                                                                                                      [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Extra Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                            [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}]    0.274637
# 112                                                             I want an iced tea sweetened, a fresh juice mix with apple, orange, and carrot, a craft beer IPA, a fruit salad, extra ranch dipping sauce, flavored syrups in vanilla and caramel, and some almond and oat milk as milk alternatives.       [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]  [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.377752
# 126                       I'll have the Chicken Soup with a lemon wedge, a Greek Salad without any protein, Fish and Chips with crispy onion rings and extra crispy fries, Grilled Tofu with chili lime, an Apple Pie, a Berry Parfait, and some milk alternatives including oat milk and almond milk.           [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]                           [{'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy', 'Onion Rings', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}]    0.415274
# 131                                                                                                                                                I'll have a grilled chicken breast with garlic butter and BBQ, a lemonade, fresh carrot juice, extra cheese, almond milk, and an extra shot of rum.                                                                                                         [{'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]                                                                                                            [{'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemonade'], 'name': 'Soft Drinks'}, {'customizations': ['Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.322009
# 134                                                                                   Caesar Salad with no protein, Grilled Chicken, and Grilled Shrimp; Grilled Chicken Breast with BBQ and Garlic Butter; Chocolate Cake; Apple Crumble; Extra Cheese; Extra Sauce with Gravy, Pesto, and BBQ Sauce.                                                             [{'customizations': ['No Protein', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]                                    [{'customizations': ['No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Chicken'], 'name': 'Grilled Chicken'}, {'customizations': ['Chicken Breast', 'BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.795396
# 166                                                                                                                                            Spicy coleslaw, mozzarella sticks with marinara, grilled chicken breast with garlic butter, chocolate, apple crumble, and extra chocolate chips on top.                                                                                                                  [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                          [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.097710

# %% [markdown]
# ### **Large 4b Model, Medium Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-large-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-large-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 6/6 [02:00<00:00, 20.05s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8296
# ✅ Exact Match Accuracy: 26.67%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                            transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        predicted_items  similarity
# 2                                                                   I'll have the Cream of Mushroom with chopped parsley and truffle oil, a lemonade, fresh juices mixed with carrot and orange, a craft beer with lager and pale ale, and a side of extra dipping sauce with ranch. Also, throw in the strawberry and extra whipped cream.                                                                       [{'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                   [{'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.696559
# 4                                                                                                                            Ordering a Chicken Soup with fresh parsley and a lemon wedge, a Lemonade, a Mojito cocktail, Mint Chocolate Chip ice cream, a Berry Parfait, and an extra side with rice, fries, mashed potatoes, and veggies.                                                                                                                            [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Rice', 'Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                       [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Rice', 'Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}]    0.729211
# 7                                                                                                                                                            Ordering a Shrimp Cocktail with spicy cocktail sauce, sweetened iced tea, a mix of red and rose wine, an extra side of mashed potatoes, and oat milk for the milk alternative.                                                                                                                                                                                                 [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}]    0.755735
# 9                                                                                                                         Order a Cream of Mushroom with truffle oil and chopped parsley, a side of onion rings with ranch and BBQ sauce, an iced tea that's sweetened, a refreshing lemonade, and some fresh juices with orange and apple.                                                                                                                                                                                        [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]    0.771505
# 10                                                                                                                           I'll have a tomato soup with croutons, a miso soup with chili oil and toasted sesame seeds, a mojito cocktail, an extra topping of chocolate chips, and an extra shot of alcohol with rum, whiskey, and vodka.                                                                                                                                                            [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Fries'], 'name': 'Fish and Chips'}]    0.791457
# 14                                                                                                                                  I'll have a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a side of mild and spicy coleslaw, a sweetened iced tea, extra cheese, extra whipped cream, and an extra shot of vodka.                                                                                                            [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                     [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Rose', 'Red', 'White'], 'name': 'Wine'}, {'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.744589
# 16                                                                                                                                                                                           Grilled chicken breast with BBQ sauce, sweetened iced tea, a lemonade, a cheesecake, and extra toppings of nuts, chocolate chips, and berries.                                                                                                                                                                                                         [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Veggies', 'Fries'], 'name': 'Extra Side'}]    0.723632
# 23                                                                                                                                                                                                       I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                                                                    [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                             [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Pesto', 'Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Veggies', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Berry Parfait'}]    0.545094
# 27                                                                                                                                      Ordering Chicken Soup with a lemon wedge and fresh parsley, a Greek Salad without protein, a Margarita cocktail, a side of strawberries, extra ranch dipping sauce, and an extra bun or bread roll.                                                                                                                                      [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}]    0.796671
# 28                                                                                                                                                                                              Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                                                                       [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]    0.735294
# 33                                                                                                                                                                                                        I'll have the Shrimp Cocktail with Lemon Herb and Spicy Cocktail, a Sprite to drink, Chocolate Cake, Apple Pie, and some Vanilla.                                                                                                                                                                                                                            [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}]    0.656291
# 35                                                                                                                                                                         Coleslaw with mild spice, a Fanta for the drink, cocktails including Margarita, Mojito, and Old Fashioned, apple pie, chocolate, and an extra bun or bread roll.                                                                                                                                                              [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                             [{'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}]    0.701357
# 39                                                                                                                                                                                                                   Can I get an order of Onion Rings with BBQ and Ranch, an Apple Pie, some Chocolate, a Berry Parfait, and Extra Cheese?                                                                                                                                                                                                                                                      [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                          [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Whipped Cream'], 'name': 'Extra Topping'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.563975
# 40                                                                                                                                                                                    A Greek salad with falafel, mozzarella sticks with ranch, a fruit salad, extra dipping sauces of ranch and blue cheese, and some extra whipped cream.                                                                                                                                                                                                       [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                          [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Lemonade'}]    0.653159
# 44                                                            Getting a spicy coleslaw, crispy fries with the fish and chips, a vegetable stir-fry with peanut sauce, a vegan burger with ketchup, mustard, vegan mayo, no cheese, and vegan cheese, grilled tofu with peanut sauce, chili lime, and soy ginger, plus a lemon meringue pie.                                                     [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Mayo', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Peanut Sauce', 'Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Mayo', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Peanut Sauce', 'Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.707143
# 45                                                                                                                                                                                          Can I get a sweetened iced tea, some extra cheese, an extra bun, flavored syrups with caramel and vanilla, and oat milk as my milk alternative?                                                                                                                                                                                                      [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Chili Lime', 'Peanut Sauce', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}]    0.682382
# 51                                                                                                                                            Ordering some onion rings with ranch and BBQ, a grilled chicken breast with garlic butter, shrimp cocktail with lemon herb, an extra whipped cream on the side, and an extra shot of whiskey.                                                                                                                                                                                [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                              [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Pesto', 'Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.608607
# 52                                                                                                             Please bring me some Chicken Soup with fresh parsley, a Shrimp Cocktail with spicy cocktail sauce, a Vegan Burger with vegan mayo, a slice of Lemon Meringue Pie, and an extra shot of alcohol with vodka, rum, and whiskey.                                                                                                                                                                        [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                               [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Peanut Sauce', 'Soy Ginger'], 'name': 'Grilled Tofu'}]    0.715294
# 53                                                                                                                                                           Ordering a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a Vegan Burger with vegan cheese and ketchup, an Apple Pie, extra cheese, and an extra bun or bread roll.                                                                                                                                                                                            [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}]    0.758344
# 54                                                                                                                                                             Order some BBQ and spicy chicken wings, grilled tofu with soy ginger and peanut sauce, a Coke, lemonade, a slice of lemon meringue pie, and extra whipped cream on the side.                                                                                                                                                     [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.797500
# 55   I'll take a Caesar Salad with grilled chicken, a Greek Salad with falafel, some BBQ spicy Buffalo chicken wings, a Shrimp Cocktail with lemon herb and spicy cocktail sauce, three cocktails: an Old Fashioned, a Mojito, and a Margarita. For dessert, I'll go with a slice of chocolate cake and some mint chocolate chip ice cream.  [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Old Fashioned', 'Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                            [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ', 'Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Old Fashioned', 'Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}]    0.297426
# 60                                                                                                                       Can I get a spicy coleslaw and some onion rings with BBQ and ranch sauce? Also, please include a mix of Sprite and Coke. For dessert, I'll take some strawberries and I need almond milk for my milk alternatives.                                                                                                                                                                                                       [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.777143
# 63                                                                                                                                                                                                                          Ordering a vegan burger with mustard, cheesecake, apple pie, lemon meringue pie, strawberry, and apple crumble.                                                                                                                                                                                                     [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}]                                                                                                                                                                                                                                                                                      [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['No Protein', 'Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Berry'], 'name': 'Parfait'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}]    0.652330
# 64                                                                                                                                                                 Grilled Chicken Breast with BBQ and Garlic Butter, Chocolate Cake, Cheesecake, Fruit Salad, Apple Crumble, and an Extra Topping with Nuts, Chocolate Chips, and Berries.                                                                                                                                         [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                                                               [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}]    0.755149
# 65                                                                                                          Going for some spicy chicken wings and a grilled chicken breast with BBQ sauce. I'll take a glass of red wine with that. Also, I'd like some extra nuts on top and I'll need almond milk and oat milk for my milk alternatives.                                                                                                                                                                                                     [{'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                              [{'customizations': ['Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Strawberry'}]    0.559838
# 67                                                                                                                                                                                                   Ordering a Fresh Juice with Orange, Apple, and Carrot, a Craft Beer IPA, an Apple Pie, a Lemon Meringue Pie, and some Extra BBQ Sauce.                                                                                                                                                                                                                   [{'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['Orange', 'Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}]    0.714090
# ...
# 158                                                                                                                                                                                                      I want a shrimp cocktail with spicy cocktail sauce, an extra crispy fish and chips, a lemonade, some chocolate, and a fruit salad.                                                                                                                                                                                                                                   [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}]  [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Strawberry'], 'name': 'Flavored Syrups'}, {'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.461682
# 160                                                I'll have some chicken wings with BBQ, spicy, and buffalo sauce, a grilled salmon with lemon dill, a vegetable stir-fry with teriyaki sauce, and a berry parfait. Also, please add extra cheese, extra BBQ sauce, and pesto for sauces, and a bit of extra whipped cream on the parfait.                                                          [{'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                            [{'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.793456
# 163                                                                                                                                                                        I'll have chicken and vegetarian spring rolls, fish and chips with onion rings, a cheesecake, some chocolate, a fruit salad, apple crumble, and a berry parfait.                                                                                                                            [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Crispy', 'Fries'], 'name': 'Extra Crispy Fish and Chips'}, {'customizations': [], 'name': 'Vanilla'}]    0.791183
# 164                                                                                                    Ordering Fish and Chips with onion rings, crispy fries, and extra crispy. Also getting a lemonade, vanilla ice cream, mint chocolate chip ice cream, an extra scoop of ice cream, and I'll go with oat milk for my milk alternative.                                                                                                                                      [{'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Onion Rings', 'Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.162465
# 168                                                                                                                                                            Ordering a tomato soup with croutons and basil pesto, a Greek salad topped with grilled chicken and falafel, a strawberry, a berry parfait, and an extra scoop of ice cream.                                                                                                                                                                                                   [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}]    0.757866
# 171                                                                                                                                                                    I'll have coleslaw with mild sauce, grilled tofu with soy ginger, peanut sauce, and chili lime, a glass of white wine, chocolate, and mint chocolate chip ice cream.                                                                                                                                                                                                               [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mashed Potatoes', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Caramel'], 'name': 'Flavored Syrups'}]    0.657568
# 173                                                                                                                                               I'll have the Chicken Soup with fresh parsley and a lemon wedge, a mild coleslaw, chicken wings with buffalo, spicy, and BBQ sauces, a shrimp cocktail with lemon herb, and a cheesecake.                                                                                                                                                                                       [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}]    0.729114
# 177                                                                                                                                                                                                  I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}]    0.660819
# 178                                                                                                                                                                                            Caesar Salad with grilled chicken but no protein, Fish and chips extra crispy with crispy fries, Apple pie, Berry parfait, and extra cheese.                                                                                                                                                                                              [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.763533

# %% [markdown]
# ### **Small 12b Model, Medium Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-small-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-small-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 6/6 [01:34<00:00, 15.80s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9637
# ✅ Exact Match Accuracy: 78.89%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                        transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 items                                                                                                                                                                                                                                                                                                                                                                                                                                                                              predicted_items  similarity
# 25                                                                                                        I want an order of mozzarella sticks with ranch, chicken wings with buffalo, BBQ, and spicy sauce, fish and chips extra crispy with onion rings, some chocolate, extra blue cheese for dipping, and an extra shot of whiskey.                                                                    [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                           [{'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Extra Crispy', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]    0.434667
# 79                                                                                                           Caesar Salad with grilled chicken and grilled shrimp, vegetarian and chicken spring rolls, unsweetened and sweetened iced tea, mint chocolate chip ice cream, an extra bun or bread roll, and an extra scoop of ice cream.                                                                           [{'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                    [{'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.162450
# 112                                                                                              I want an iced tea sweetened, a fresh juice mix with apple, orange, and carrot, a craft beer IPA, a fruit salad, extra ranch dipping sauce, flavored syrups in vanilla and caramel, and some almond and oat milk as milk alternatives.                [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]  [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.377752
# 136                                                                                                                                Can I get a Caesar Salad with grilled chicken and grilled shrimp, a Greek Salad with grilled chicken and falafel, a glass of white wine, a cheesecake, and some caramel and vanilla flavored syrups?                                                                                                                        [{'customizations': ['No Protein', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                [{'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['White', 'Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]    0.222556
# 164                                                                                                Ordering Fish and Chips with onion rings, crispy fries, and extra crispy. Also getting a lemonade, vanilla ice cream, mint chocolate chip ice cream, an extra scoop of ice cream, and I'll go with oat milk for my milk alternative.                                                                                                              [{'customizations': ['Onion Rings', 'Crispy', 'Fries', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                     [{'customizations': ['Onion Rings', 'Fries', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.173653
# 166                                                                                                                                                                             Spicy coleslaw, mozzarella sticks with marinara, grilled chicken breast with garlic butter, chocolate, apple crumble, and extra chocolate chips on top.                                                                                                                           [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                          [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]    0.097710
# 170  I'll have a Tomato Soup with croutons, cheddar cheese, and basil pesto, a Chicken Soup with fresh parsley, a Grilled Salmon with garlic butter and lemon dill, Fish and Chips extra crispy with fries, crispy onion rings, and some soft drinks including Coke, Sprite, and Fanta. Also add almond milk for the milk alternatives.  [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]         [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Crispy', 'Extra Crispy', 'Fries', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.643021
# 178                                                                                                                                                                                        Caesar Salad with grilled chicken but no protein, Fish and chips extra crispy with crispy fries, Apple pie, Berry parfait, and extra cheese.                                                                                                                                                                      [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                             [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Crispy', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.393617

# %% [markdown]
# ### **Large 12b Model, Medium Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-large-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-large-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 180 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 6/6 [03:04<00:00, 30.80s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8233
# ✅ Exact Match Accuracy: 19.44%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                     transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          predicted_items  similarity
# 4                                                                                                                                     Ordering a Chicken Soup with fresh parsley and a lemon wedge, a Lemonade, a Mojito cocktail, Mint Chocolate Chip ice cream, a Berry Parfait, and an extra side with rice, fries, mashed potatoes, and veggies.                                                                                                                            [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Rice', 'Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                   [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Rice', 'Fries', 'Mashed Potatoes', 'Veggies'], 'name': 'Extra Side'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Ranch', 'Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Vanilla'}]    0.751648
# 6                                                                                                   I'm ordering a Shrimp Cocktail with spicy cocktail and lemon herb, Fish and Chips with onion rings extra crispy, a Vegetable Stir-fry with teriyaki, a lemonade, a selection of craft beer including IPA, pale ale, and lager, and an extra bun.                                                                                     [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                  [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['IPA', 'Pale Ale', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.784314
# 7                                                                                                                                                                     Ordering a Shrimp Cocktail with spicy cocktail sauce, sweetened iced tea, a mix of red and rose wine, an extra side of mashed potatoes, and oat milk for the milk alternative.                                                                                                                                                                                                 [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                          [{'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Cheddar Cheese', 'Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}]    0.661939
# 9                                                                                                                                  Order a Cream of Mushroom with truffle oil and chopped parsley, a side of onion rings with ranch and BBQ sauce, an iced tea that's sweetened, a refreshing lemonade, and some fresh juices with orange and apple.                                                                                                                                                                                        [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}]                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Red', 'Rose', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.774629
# 10                                                                                                                                    I'll have a tomato soup with croutons, a miso soup with chili oil and toasted sesame seeds, a mojito cocktail, an extra topping of chocolate chips, and an extra shot of alcohol with rum, whiskey, and vodka.                                                                                                                                                            [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                                               [{'customizations': ['Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Rum', 'Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}]    0.770171
# 11                                                                                                                              Ordering some onion rings with BBQ and ranch, a grilled chicken breast with BBQ, a grilled salmon with garlic butter and lemon dill, a lemonade, a couple of cocktailsâ€”margarita and mojitoâ€”and a berry parfait.                                                                                                                                    [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                                                                                                                               [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Gravy', 'Pesto', 'BBQ Sauce'], 'name': 'Extra Sauce'}]    0.691434
# 13                                                                                                                Caesar Salad with grilled shrimp and grilled chicken, Greek Salad with grilled chicken, Vegetable Stir-fry with peanut sauce, garlic soy, and teriyaki, Lemon Meringue Pie, Fruit Salad, and an extra side of ranch dipping sauce.                                                                            [{'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}]                                                                                                                                                                                                                                            [{'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Chicken', 'Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Peanut Sauce', 'Garlic Soy', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}]    0.770681
# 14                                                                                                                                           I'll have a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a side of mild and spicy coleslaw, a sweetened iced tea, extra cheese, extra whipped cream, and an extra shot of vodka.                                                                                                            [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}]                                                                                                    [{'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Chocolate Chips', 'Nuts', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Ketchup', 'Vegan Cheese', 'No Cheese', 'Mustard', 'Vegan Mayo', 'Vegan Patty'], 'name': 'Vegan Burger'}]    0.657116
# 15                                                                                                                                                 I'm ordering a Cream of Mushroom with truffle oil and chopped parsley, two soft drinks â€” one Fanta and one Coke, a Pale Ale craft beer, a cheesecake, a lemon meringue pie, and some chocolate.                                                                                                                                                  [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                  [{'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.771257
# 16                                                                                                                                                                                                    Grilled chicken breast with BBQ sauce, sweetened iced tea, a lemonade, a cheesecake, and extra toppings of nuts, chocolate chips, and berries.                                                                                                                                                                                                         [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                                               [{'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Nuts', 'Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Fanta', 'Sprite', 'Coke'], 'name': 'Soft Drinks'}]    0.675810
# 23                                                                                                                                                                                                                I want a sweetened iced tea, a lemonade, a cheesecake, a lemon meringue pie, and a vanilla. Also, add an extra scoop of ice cream.                                                                                                                                                                                    [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lager', 'Pale Ale'], 'name': 'Craft Beer'}]    0.733503
# 26                                                                                                                                                                                           Can I get a spicy coleslaw and a shrimp cocktail with lemon herb? Also, a lemonade, a mojito, a glass of rosÃ© wine, and some extra cheese on the side.                                                                                                                                                                                     [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                             [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Mojito'], 'name': 'Cocktails'}, {'customizations': ['Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Peanut Sauce', 'Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}]    0.712294
# 28                                                                                                                                                                                                       Ordering a tomato soup with basil pesto, spicy buffalo chicken wings, an apple pie, a lemon meringue pie, and some extra fries on the side.                                                                                                                                                                                                                       [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.704918
# 33                                                                                                                                                                                                                 I'll have the Shrimp Cocktail with Lemon Herb and Spicy Cocktail, a Sprite to drink, Chocolate Cake, Apple Pie, and some Vanilla.                                                                                                                                                                                                                            [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}]                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Onion Rings', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}]    0.782071
# 39                                                                                                                                                                                                                            Can I get an order of Onion Rings with BBQ and Ranch, an Apple Pie, some Chocolate, a Berry Parfait, and Extra Cheese?                                                                                                                                                                                                                                                      [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.718354
# 40                                                                                                                                                                                             A Greek salad with falafel, mozzarella sticks with ranch, a fruit salad, extra dipping sauces of ranch and blue cheese, and some extra whipped cream.                                                                                                                                                                                                       [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                                               [{'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}]    0.708010
# 43                                                 Can I get a Garden Salad with vinaigrette, a Grilled Salmon topped with lemon dill and garlic butter, a Shrimp Cocktail with spicy cocktail sauce, Fish and Chips with onion rings and extra crispy, Grilled Tofu with chili lime, a slice of Lemon Meringue Pie, and an extra bun or bread roll?                                   [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Onion Rings', 'Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.605293
# 44                                                                     Getting a spicy coleslaw, crispy fries with the fish and chips, a vegetable stir-fry with peanut sauce, a vegan burger with ketchup, mustard, vegan mayo, no cheese, and vegan cheese, grilled tofu with peanut sauce, chili lime, and soy ginger, plus a lemon meringue pie.                                                     [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Mayo', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Peanut Sauce', 'Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]                                                                                                                                                                                                                                                                                              [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Crispy', 'Extra Crispy'], 'name': 'Fries'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Ketchup', 'Mustard', 'Vegan Mayo', 'No Cheese', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Chocolate'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Peanut Sauce', 'Chili Lime', 'Soy Ginger'], 'name': 'Grilled Tofu'}]    0.608414
# 45                                                                                                                                                                                                   Can I get a sweetened iced tea, some extra cheese, an extra bun, flavored syrups with caramel and vanilla, and oat milk as my milk alternative?                                                                                                                                                                                                      [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.780142
# 49                                                                                   Ordering a vegan burger with mustard, vegan mayo, and ketchup. Also getting a mix of soft drinks with Sprite and Coke, plus both sweetened and unsweetened iced tea. Don't forget a side of chocolate and some milk alternatives with almond milk and oat milk.                                                                                                                                                            [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                     [{'customizations': ['Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['Sprite', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}]    0.768850
# 51                                                                                                                                                     Ordering some onion rings with ranch and BBQ, a grilled chicken breast with garlic butter, shrimp cocktail with lemon herb, an extra whipped cream on the side, and an extra shot of whiskey.                                                                                                                                                                                [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                [{'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Vanilla', 'Caramel'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Margarita', 'Old Fashioned'], 'name': 'Cocktails'}]    0.680412
# 52                                                                                                                      Please bring me some Chicken Soup with fresh parsley, a Shrimp Cocktail with spicy cocktail sauce, a Vegan Burger with vegan mayo, a slice of Lemon Meringue Pie, and an extra shot of alcohol with vodka, rum, and whiskey.                                                                                                                                                                        [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}]                                                                                                                                                                                                                                                                                             [{'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Vodka', 'Rum', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]    0.737864
# 53                                                                                                                                                                    Ordering a Shrimp Cocktail with spicy cocktail sauce and lemon herb, a Vegan Burger with vegan cheese and ketchup, an Apple Pie, extra cheese, and an extra bun or bread roll.                                                                                                                                                                                            [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                       [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Vegan Cheese', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Mojito', 'Old Fashioned', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.690158
# 54                                                                                                                                                                      Order some BBQ and spicy chicken wings, grilled tofu with soy ginger and peanut sauce, a Coke, lemonade, a slice of lemon meringue pie, and extra whipped cream on the side.                                                                                                                                                     [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                                                                              [{'customizations': ['BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Soy Ginger', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.764072
# 55            I'll take a Caesar Salad with grilled chicken, a Greek Salad with falafel, some BBQ spicy Buffalo chicken wings, a Shrimp Cocktail with lemon herb and spicy cocktail sauce, three cocktails: an Old Fashioned, a Mojito, and a Margarita. For dessert, I'll go with a slice of chocolate cake and some mint chocolate chip ice cream.  [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Old Fashioned', 'Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                             [{'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['BBQ', 'Spicy', 'Buffalo'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Old Fashioned', 'Mojito', 'Margarita'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['White', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Mashed Potatoes', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Strawberry'}]    0.721943
# 57                                                                                                          I'm ordering a Tomato Soup with Cheddar Cheese and Croutons, a Chocolate Cake, a Lemon Meringue Pie, Extra Whipped Cream, an Extra Topping with Berries, Chocolate Chips, and Nuts, and Milk Alternatives with Almond Milk and Oat Milk.                                                                                                 [{'customizations': ['Cheddar Cheese', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                  [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Berries', 'Chocolate Chips', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vegan Cheese', 'Mustard', 'Vegan Mayo', 'No Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Apple Crumble'}]    0.129870
# ...
# 165                                                                                                                  Ordering a bowl of Cream of Mushroom with truffle oil, Grilled Tofu drizzled with peanut sauce and chili lime, a slice of Apple Pie, a slice of Lemon Meringue Pie, some vanilla, and flavored syrups with caramel and vanilla.                                                                                                                                           [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}]                                                                                                                                                                                                                                                               [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Vegan Cheese', 'Ketchup', 'Mustard', 'No Cheese', 'Vegan Mayo'], 'name': 'Vegan Burger'}]    0.752000
# 166                                                                                                                                                                                          Spicy coleslaw, mozzarella sticks with marinara, grilled chicken breast with garlic butter, chocolate, apple crumble, and extra chocolate chips on top.                                                                                                                                                   [{'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}]                                                                                                                                                                                                                                                        [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Ranch', 'Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Greek Salad'}]    0.073059
# 168                                                                                                                                                                     Ordering a tomato soup with croutons and basil pesto, a Greek salad topped with grilled chicken and falafel, a strawberry, a berry parfait, and an extra scoop of ice cream.                                                                                                                                                                                                   [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                      [{'customizations': ['Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Grilled Chicken', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Buffalo', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Lemonade'}]    0.733775
# 170               I'll have a Tomato Soup with croutons, cheddar cheese, and basil pesto, a Chicken Soup with fresh parsley, a Grilled Salmon with garlic butter and lemon dill, Fish and Chips extra crispy with fries, crispy onion rings, and some soft drinks including Coke, Sprite, and Fanta. Also add almond milk for the milk alternatives.                          [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Croutons', 'Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries', 'Onion Rings', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Coke', 'Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}]    0.650057
# 171                                                                                                                                                                             I'll have coleslaw with mild sauce, grilled tofu with soy ginger, peanut sauce, and chili lime, a glass of white wine, chocolate, and mint chocolate chip ice cream.                                                                                                                                                                                                               [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                           [{'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Soy Ginger', 'Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Strawberry'}]    0.780560
# 173                                                                                                                                                        I'll have the Chicken Soup with fresh parsley and a lemon wedge, a mild coleslaw, chicken wings with buffalo, spicy, and BBQ sauces, a shrimp cocktail with lemon herb, and a cheesecake.                                                                                                                                                                                       [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                                    [{'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Buffalo', 'Spicy', 'BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Onion Rings', 'Extra Crispy', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Sprite'], 'name': 'Soft Drinks'}]    0.659794
# 177                                                                                                                                                                                                           I'll have a lemonade, a slice of lemon meringue pie, some chocolate, extra cheese on the side, and extra whipped cream for my dessert.                                                                                                                                                                                                                                                        [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                  [{'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Orange', 'Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Rose', 'White'], 'name': 'Wine'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}]    0.537455
# 178                                                                                                                                                                                                     Caesar Salad with grilled chicken but no protein, Fish and chips extra crispy with crispy fries, Apple pie, Berry parfait, and extra cheese.                                                                                                                                                                                              [{'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Extra Crispy', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Crispy', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.347518
# 179                                                                                                                            I'll have some Sprite and Fanta for the soft drinks. For craft beer, please add Pale Ale, IPA, and Lager. Also, getting an apple pie and an apple crumble. And don't forget the extra cheese and extra whipped cream.                                                                                                                                                                 [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                                                                                                                                                        [{'customizations': ['Sprite', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Pale Ale', 'IPA', 'Lager'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}]    0.702641

# %% [markdown]
# # **Load Large Dataset**

# %%
from datasets import load_dataset
import json

dataset_id = "iTzMiNOS/voice-orders-large-clean-12k"
split_name = "train"

print(f"Loading dataset '{dataset_id}' (split: '{split_name}')...")
dataset = load_dataset(dataset_id, split=split_name)

columns_to_keep = ["transcribed_text", "items", "speaker"]
dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])

dataset = dataset.select(range(min(1200, len(dataset))))

print(f"Dataset loaded: {dataset}")

prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""

print("Splitting dataset into train and validation sets...")
train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
train_data = train_val_split['train']
validation_data = train_val_split['test']

print(f"Train set size: {len(train_data)}")
print(f"Validation set size: {len(validation_data)}")

def format_data_for_sft(example):
    text = example["transcribed_text"]
    items_data = example["items"]
    json_string = json.dumps(items_data, separators=(',', ':'))
    if 'tokenizer' not in globals():
        raise NameError("Tokenizer not found. Please run the tokenizer loading cell (Cell 5) first.")
    eos = tokenizer.eos_token
    formatted_string = f"{prefix}{text}\n{json_string}{eos}"
    return {"formatted_text": formatted_string}

if 'tokenizer' in globals():
    print("Applying formatting function to the datasets...")
    train_dataset = train_data.map(format_data_for_sft, remove_columns=train_data.column_names)
    validation_dataset = validation_data.map(format_data_for_sft, remove_columns=validation_data.column_names) # Process validation data too!
    print("Dataset formatting complete.")
    print(f"Train dataset features: {train_dataset.features}")
    print(f"Validation dataset features: {validation_dataset.features}")
else:
    print("WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.")
    train_dataset = None
    validation_dataset = None
# Out:
# Loading dataset 'iTzMiNOS/voice-orders-large-clean-12k' (split: 'train')...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Resolving data files:   0%|          | 0/24 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/24 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/22 [00:00<?, ?it/s]
# Dataset loaded: Dataset({
#     features: ['transcribed_text', 'speaker', 'items'],
#     num_rows: 1200
# })
# Splitting dataset into train and validation sets...
# Train set size: 1080
# Validation set size: 120
# WARNING: Tokenizer not loaded yet. Re-run Cell 5 and this cell's mapping part.

# %% [markdown]
# ### **Small 1b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-small-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) in torch.bfloat16
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-small-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches:  12%|█▎        | 1/8 [00:10<01:12, 10.31s/it]
# Warning: Could not parse JSON: Expecting ',' delimiter: line 1 column 267 (char 266).
# Attempted to parse (after extraction): '[{"customizations":[],"name":"Apple Crumble"},{"customizations":[],"name":"Lemonade"},{"customizations":["Ketchup","Vegan Mayo"],"name":"Vegan Burger"},{"customizations":[],"name":"Fries"},{"customizations":[],"name":"Extra Sauce (Pesto, BBQ Sauce, Gravy)","count":5"}]'
# Inference Batches:  50%|█████     | 4/8 [00:38<00:38,  9.60s/it]
# Warning: Could not parse JSON: Expecting ':' delimiter: line 1 column 336 (char 335).
# Attempted to parse (after extraction): '[{"customizations":[],"name":"Extra Bun or Bread Roll"},{"customizations":["Coke","Sprite","Fanta"],"name":"Soft Drinks"},{"customizations":[],"name":"Extra Whipped Cream"},{"customizations":["Vegetarian"],"name":"Spring Rolls"},{"customizations":[],"name":"Lemon Meringue Pie"},{"customizations":[],"name":"Extra Sauce (Pesto","Gravy"},{"customizations":[],"name":"Strawberry"},{"customizations":[],"name":"Cream of Mushroom Soup with Truffle Oil","Chopped Parsley"},{"customizations":["Vegan Cheese","Vegan Mayo"],"name":"Vegetarian Burger"},{"customizations":["Garlic Soy","Peanut Sauce"],"name":"Extra Side"}]'
# Inference Batches: 100%|██████████| 8/8 [01:15<00:00,  9.41s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.7438
# ✅ Exact Match Accuracy: 8.33%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   predicted_items  similarity
# 1                                                                                                                                                                                                                                                                                                                                         Ordering Fish and Chips with Onion Rings, an Apple Crumble, and a Berry Parfait on the side. Iâ€™ll have sweetened Iced Tea and a drink with an extra shot of Rum. Please add some Vanilla, extra toppings of Berries, and extra BBQ Sauce and Gravy.                                                                                                                                                                                                                                                                    [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Berries', 'Extra Topping'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]    0.764706
# 3                                                                                                                                                                                                                                                           Can I get an apple crumble and a lemonade? Also, I'd like a vegan burger with ketchup and vegan mayo, along with mozzarella sticks served with ranch. Please add a vegetable stir-fry with teriyaki sauce, a fruit salad, and a lemon meringue pie. Also, throw in an apple pie and some extra sauces: pesto, BBQ sauce, and gravy.                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Ketchup', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Teriyaki'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Pesto', 'BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              None    0.000000
# 4                                                                                                                                                                                                        Coleslaw with a spicy kick, cream of mushroom soup topped with truffle oil and chopped parsley, mint chocolate chip ice cream, garden salad with ranch and vinaigrette dressings, grilled salmon with lemon dill and garlic butter, chicken soup garnished with fresh parsley, a pale ale craft beer, extra whipped cream, and a mix of soft drinks including Fanta, Coke, and Sprite.                                                                                                                                                   [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                                      [{'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Ranch', 'Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Extra Whipped Cream'}]    0.796218
# 5                                                                                                                                                                                                                                                                              Can I get a Sprite, mild coleslaw, an extra shot of rum and vodka, ranch dipping sauce, vegetable stir-fry with teriyaki and garlic soy, chicken soup with a lemon wedge and fresh parsley, an extra bun or bread roll, a slice of lemon meringue pie, and milk alternatives including almond milk and oat milk?                                                                                                                                                            [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.743929
# 6                                                                                                                                                                                                                                                                                 Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                                                                                                       [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.715013
# 8                                                                                                                                                                                           I want a vegan burger with ketchup, vegan mayo, and mustard, miso soup with toasted sesame seeds, extra cheese, and an extra side of rice, fries, and mashed potatoes. Also, add a garden salad with vinaigrette and balsamic, onion rings with BBQ and ranch, cream of mushroom with chopped parsley and truffle oil, mint chocolate chip ice cream, a berry parfait, and an unsweetened iced tea.                                                                                    [{'customizations': ['Ketchup', 'Vegan Mayo', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Rice', 'Fries', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]                                                                                                                                                                                                                      [{'customizations': ['Ketchup', 'Vegan Mayo', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]    0.617978
# 9                                                                                                                                                                                                                                                                                                                                           I want a chocolate, a bottle of white wine, some vegetarian spring rolls, an extra side of rice, vegetable stir-fry with peanut sauce, blue cheese for dipping, a Caesar salad with grilled chicken, an extra scoop of ice cream, and an apple pie.                                                                                                                                                                                                                           [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Rice'], 'name': 'Extra Side'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                                                                                                                          [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Rice', 'Vegetable Stir-fry'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Apple Pie'}]    0.760456
# 10                                                                                                                                                                                        Can I get a Cream of Mushroom soup with truffle oil, two craft beers (one IPA and one pale ale), a miso soup with chili oil and toasted sesame seeds, some chocolate, a couple of cocktails (mojito and old fashioned), a slice of chocolate cake, a Caesar salad with grilled chicken, mozzarella sticks with ranch, onion rings with ranch, and some almond milk and oat milk as milk alternatives?                                                                                                              [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}]                                                                                                                              [{'customizations': ['Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': ['IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken', 'Ranch'], 'name': 'Caesar Salad'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}]    0.773050
# 14                                                                                                                                                                                                                              Grilled Chicken Breast with BBQ and Garlic Butter, Chicken Wings in Buffalo, BBQ, and Spicy, Cream of Mushroom topped with Chopped Parsley and Truffle Oil, an Extra Ice Cream Scoop, Greek Salad without protein, Apple Crumble, Extra Sauce including BBQ Sauce and Pesto, a Coke, Lemon Meringue Pie, and Miso Soup with Chili Oil and Toasted Sesame Seeds.                                                                                   [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}]                                                                   [{'customizations': ['BBQ', 'Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Buffalo', 'BBQ', 'Spicy'], 'name': 'Chicken Wings'}, {'customizations': ['Cream of Mushroom', 'Chopped Parsley', 'Truffle Oil'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Coke', 'Lemon Meringue Pie'], 'name': 'Extra Topping'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.668321
# 15                                                                                                                                                                                                                                                                                                           I'll take some extra dipping sauce with ranch and blue cheese, a fruit salad, fresh apple juice, a berry parfait, a chocolate treat, a Fanta soft drink, an extra shot of alcohol with whiskey, vodka, and rum, a Greek salad with falafel, and a shrimp cocktail with lemon herb.                                                                                                                                                                                                                     [{'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Fanta'], 'name': 'Soft Drinks'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}]                                                                                                                                                                                                                                                                                                                                                                                             [{'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Whiskey', 'Vodka', 'Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Falafel'], 'name': 'Greek Salad'}, {'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.764187
# 18                                                                                                                                                                                                                                                                                                                                                                                         Grilled Tofu with peanut sauce, chocolate cake, an extra bun, lemon meringue pie, oat milk and almond milk as milk alternatives, vegetarian and chicken spring rolls, mild coleslaw, and cheesecake.                                                                                                                                                                                                                                                                               [{'customizations': ['Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                   [{'customizations': ['Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['No Protein', 'Protein'], 'name': 'Vegetarian'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}]    0.636943
# 19                                                                                                                                                                                                                                                                                                      Can I get flavored syrups with caramel and vanilla, one cheesecake, some soft drinks including Coke and Sprite, extra dipping sauces of ranch and blue cheese, extra cheese, vegetarian spring rolls, a grilled chicken breast with BBQ, and coleslaw with both mild and spicy options?                                                                                                                                                                                                                                                              [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                                                                                                                                                              [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['BBQ'], 'name': 'Vegetarian Spring Rolls'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Extra Shot of Alcohol'}]    0.726327
# 20                                                                                                                                                                                                                                         I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                                                                                                       [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                          [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caesar', 'Grilled Chicken', 'Grilled Shrimp'], 'name': 'Extra Side'}, {'customizations': ['Miso Soup', 'Toasted Sesame Seeds'], 'name': 'Extra Topping'}]    0.740586
# 22                                                                                                                                                                                                                                                                                                                                                                                                  Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                                                                                                   [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                       [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito', 'Lemon Meringue Pie'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.376891
# 23                                                                                                   I'll have a Craft Beer IPA, a mix of Vegetarian and Chicken Spring Rolls, Coleslaw with both Mild and Spicy, Onion Rings with Ranch and BBQ sauces, Vegetable Stir-fry with Garlic Soy, Teriyaki, and Peanut Sauce, a Cream of Mushroom topped with Chopped Parsley, Extra Dipping Sauces of Ranch and Blue Cheese, a slice of Chocolate Cake, Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, and a Caesar Salad without protein, plus both Grilled Shrimp and Grilled Chicken.                              [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]                                                                 [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Caesar Salad'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Extra Dipping Sauce'}]    0.741270
# 25                                                                                                                                                                                                                        Can I get a Coke, BBQ onion rings, a slice of chocolate cake, a grilled chicken breast with garlic butter, a grilled salmon with garlic butter and lemon dill, grilled tofu with peanut sauce, soy ginger, and chili lime, a craft beer with a selection of lager, pale ale, and IPA, mozzarella sticks with ranch and marinara, spicy coleslaw, and a berry parfait?                                                                                 [{'customizations': ['Coke', 'Fanta', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Lager', 'Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Berry Parfait'}]                                                               [{'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce', 'Soy Ginger', 'Chili Lime'], 'name': 'Spicy Coleslaw'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Craft Beer'}, {'customizations': ['Ranch', 'Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Berry'], 'name': 'Extra Topping'}]    0.645215
# 28                                                                                                                                                  Iâ€™ll take a sweetened iced tea, an apple crumble, onion rings with BBQ and ranch, extra sides of veggies, fries, rice, and mashed potatoes. For the soup, I want cream of mushroom with truffle oil and chopped parsley. A berry parfait and apple pie for dessert. Iâ€™d also like the grilled salmon with garlic butter and lemon dill, a craft beer with lager, IPA, and pale ale options, and an extra bun or bread roll on the side.                                                                                 [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Veggies', 'Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                              [{'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Veggies', 'Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Garlic Butter', 'Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Lager', 'IPA', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Apple Pie'}]    0.771350
# 29                                                                                                                                                                                                                                                                                                                  Can I get an extra ice cream scoop, fresh juices with carrot, orange, and apple, a garden salad with vinaigrette, a selection of red, rose, and white wine, chicken soup with a lemon wedge, strawberry, extra whipped cream, onion rings with BBQ sauce, and a cheesecake?                                                                                                                                                                                                                                  [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Red', 'Rose', 'White'], 'name': 'Wine'}, {'customizations': ['Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                                                                       [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Carrot', 'Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette'], 'name': 'Garden Salad'}, {'customizations': ['Red', 'Rose', 'White'], 'name': 'Wine'}, {'customizations': ['BBQ'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Cheesecake'}]    0.580508
# 30                                                                                                                             Can I get an extra bun or bread roll, some chocolate, and a bowl of tomato soup with basil pesto? Also, please add a selection of veggies, rice, and fries as an extra side. For dessert, I'll have a lemon meringue pie and an apple pie. To drink, I'd like a glass of white wine. Oh, and Iâ€™ll take some mozzarella sticks with ranch and a Caesar salad that has grilled shrimp and grilled chicken but no other protein. And thatâ€™s everything, thanks!                                                                                                                     [{'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Pie'}]                                                                                                                                                                                                                                                                                             [{'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Ranch', 'Caesar Salad', 'Grilled Shrimp', 'No Protein'], 'name': 'Extra Protein'}, {'customizations': ['Lemon Meringue Pie', 'Apple Pie'], 'name': 'Extra Dessert'}, {'customizations': ['White Wine'], 'name': 'Extra Drink'}]    0.442387
# 31                                                                                                                      Can I get extra sauces with BBQ sauce, gravy, and pesto? Also, please add mozzarella sticks with marinara, and a bowl of miso soup topped with toasted sesame seeds. For dessert, I'll take vanilla and mint chocolate chip. Don't forget the onion rings with ranch and BBQ sauce, plus an extra topping of chocolate chips and berries. Lastly, I'd like tomato soup with cheddar cheese, croutons, and basil pesto, and a grilled chicken breast with garlic butter.                                                                                                                                        [{'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chocolate Chips', 'Berries'], 'name': 'Extra Topping'}, {'customizations': ['Cheddar Cheese', 'Croutons', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}]                                                                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['BBQ Sauce', 'Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Miso Soup', 'Toasted Sesame Seeds'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.500579
# 33                                                                                                                                                                                                                                                                                                                                                                                             Order a chocolate with extra side of veggies, rice, and fries, an extra bun, grilled tofu with chili lime, mild coleslaw, a Caesar salad with grilled chicken, vanilla, and extra whipped cream.                                                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]                                                                                                       [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Chili Lime'], 'name': 'Mild Coleslaw'}, {'customizations': ['No Protein', 'Grilled Chicken'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.739754
# ...
# 107                                                                                                                                                                                                                      Shrimp Cocktail with Lemon Herb, Chicken and Vegetarian Spring Rolls, extra Blue Cheese dipping sauce, Lemon Meringue Pie, extra Pesto, Gravy, and BBQ Sauce, Margaritas, Mojitos, and Old Fashioneds for cocktails, Mint Chocolate Chip, Almond Milk for milk alternatives, Fish and Chips with onion rings, crispy, and fries, and Fanta and Sprite for soft drinks.                                                           [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Pesto', 'Gravy', 'BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Margarita', 'Mojito', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Onion Rings', 'Crispy', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Fanta', 'Sprite'], 'name': 'Soft Drinks'}]    0.478649
# 111                                                                                                                                                         Can I get a Berry Parfait, a Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, a Tomato Soup with Cheddar Cheese and Basil Pesto, a Garden Salad with Vinaigrette, Balsamic, and Ranch dressing, a Lemon Meringue Pie, an extra side of Veggies, Fries, Mashed Potatoes, and Rice, a Vegan Burger with Vegan Mayo, Ketchup, no Cheese, Vegan Cheese, and Mustard, a Chocolate Cake, and a Greek Salad with Grilled Chicken?                                                                                 [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': ['Vegan Mayo', 'Ketchup', 'No Cheese', 'Vegan Cheese', 'Mustard'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}]                                                                                                                                                            [{'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Cheddar Cheese', 'Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Veggies', 'Fries', 'Mashed Potatoes', 'Rice'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Grilled Chicken'], 'name': 'Vegan Burger'}]    0.760213
# 113                                                                                                     I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                                                                                            [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                                                                                    [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.545455
# 114                                                                                                                                                                                                                                                                  I'll have a cheesecake, two cocktails (Old Fashioned and Mojito), a lemonade, an apple crumble, soft drinks with Fanta, Coke, and Sprite, an extra shot of rum, fish and chips extra crispy with onion rings and fries, a Caesar salad with grilled shrimp and grilled chicken, and a garden salad with balsamic dressing.                                                                                                                                                [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Crispy', 'Extra Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Balsamic', 'Vinaigrette'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                                                                                       [{'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Fanta', 'Coke', 'Sprite'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Crispy', 'Onion Rings', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}]    0.760801
# 115                                                                                                                                                                                                                                                                                                             Ordering a Caesar salad with grilled shrimp, vegetable stir-fry with teriyaki, garlic soy, and peanut sauce, apple crumble, cheesecake, grilled salmon with lemon dill and garlic butter, strawberry, onion rings with BBQ and ranch, and soft drinks including Fanta and Coke.                                                                                                                                                                                                               [{'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Teriyaki', 'Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                                                         [{'customizations': ['Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Teriyaki', 'Garlic Soy', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Lemon Dill', 'Garlic Butter'], 'name': 'Grilled Salmon'}, {'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]    0.750285
# 118                                                                                                                                                                          Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.                                                                               [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                               [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.387396
# 119                                                                                                                                   Ordering vegetarian spring rolls and miso soup with toasted sesame seeds. I'll also need extra dipping sauces of ranch and blue cheese, along with onion rings and ranch on the side. A vegan burger comes with no cheese, ketchup, mustard, vegan mayo, and vegan cheese. Add cream of mushroom soup with chopped parsley and truffle oil, followed by a slice of chocolate cake. Lastly, include extra pesto sauce. Two chocolate bars for dessert too.                                                                                                                                          [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}]                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}]    0.623529

# %% [markdown]
# ### **Medium 1b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-1b-it"
adapter_model_id = "iTzMiNOS/gemma-3-1b-it-medium-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 16

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-1b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-1b-it) in torch.bfloat16
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-1b-it-medium-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 16)...
# Inference Batches:  88%|████████▊ | 7/8 [01:19<00:11, 11.73s/it]
# Warning: Could not parse JSON: Expecting ',' delimiter: line 1 column 383 (char 382).
# Attempted to parse (after extraction): '[{"customizations":["Lemon Dill"],"name":"Grilled Salmon"},{"customizations":[],"name":"Extra Ice Cream Scoop"},{"customizations":[],"name":"Strawberry"},{"customizations":["BBQ"],"name":"Grilled Chicken Breast"},{"customizations":["Chili Oil","Toasted Sesame Seeds"],"name":"Miso Soup"},{"customizations":[],"name":"Mint Chocolate Chip"},{"customizations":[],"name":"Extra Topping":["Berries","Nuts"],"name":"Extra Ice Cream Scoop"},{"customizations":[],"name":"Lemon Meringue Pie"},{"customizations":[],"name":"Vanilla"},{"customizations":["Vegetarian","Chicken"],"name":"Spring Rolls"}]'
# Inference Batches: 100%|██████████| 8/8 [01:30<00:00, 11.33s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.8831
# ✅ Exact Match Accuracy: 32.50%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     predicted_items  similarity
# 1                                                                                                                                                                                                                                                                                                                                         Ordering Fish and Chips with Onion Rings, an Apple Crumble, and a Berry Parfait on the side. Iâ€™ll have sweetened Iced Tea and a drink with an extra shot of Rum. Please add some Vanilla, extra toppings of Berries, and extra BBQ Sauce and Gravy.                                                                                                                                                                                                                                         [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum', 'Vodka', 'Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Berries'], 'name': 'Extra Topping'}, {'customizations': ['BBQ Sauce', 'Gravy'], 'name': 'Extra Sauce'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Rum'], 'name': 'Extra Shot of Alcohol'}]    0.612766
# 20                                                                                                                                                                                                                                         I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                                                                            [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                              [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Caesar', 'Grilled Chicken', 'No Protein', 'Grilled Shrimp'], 'name': 'Extra Protein'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Extra Topping'}]    0.700210
# 22                                                                                                                                                                                                                                                                                                                                                                                                  Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                                                                        [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                         [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 23                                                                                                   I'll have a Craft Beer IPA, a mix of Vegetarian and Chicken Spring Rolls, Coleslaw with both Mild and Spicy, Onion Rings with Ranch and BBQ sauces, Vegetable Stir-fry with Garlic Soy, Teriyaki, and Peanut Sauce, a Cream of Mushroom topped with Chopped Parsley, Extra Dipping Sauces of Ranch and Blue Cheese, a slice of Chocolate Cake, Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, and a Caesar Salad without protein, plus both Grilled Shrimp and Grilled Chicken.   [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]  [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Cream of Mushroom'}, {'customizations': ['Chopped Parsley'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Extra Protein'}]    0.607407
# 30                                                                                                                             Can I get an extra bun or bread roll, some chocolate, and a bowl of tomato soup with basil pesto? Also, please add a selection of veggies, rice, and fries as an extra side. For dessert, I'll have a lemon meringue pie and an apple pie. To drink, I'd like a glass of white wine. Oh, and Iâ€™ll take some mozzarella sticks with ranch and a Caesar salad that has grilled shrimp and grilled chicken but no other protein. And thatâ€™s everything, thanks!                                                                                          [{'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Basil Pesto'], 'name': 'Tomato Soup'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': ['Truffle Oil', 'Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': [], 'name': 'Apple Pie'}]                                                              [{'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Basil Pesto'}, {'customizations': ['Veggies', 'Rice', 'Fries'], 'name': 'Extra Side'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['White'], 'name': 'Wine'}, {'customizations': ['Ranch', 'No Cheese'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Extra Protein'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': [], 'name': 'Extra Topping with Nuts or Chocolate Chips'}]    0.682645
# 34   Let's go with some onion rings with BBQ and ranch, a grilled tofu dish topped with peanut sauce and chili lime, an old fashioned cocktail, and a side of extra whipped cream. I'll also add flavored syrups for my drinks with caramel and vanilla. For the main, I want a vegan burger with vegan cheese, mustard, and vegan mayo. A side of strawberries would be great, along with fish and chips that are crispy with onion rings, extra crispy, and fries. Lastly, a grilled chicken breast with garlic butter and BBQ sauce, plus a vegetable stir-fry with teriyaki and garlic soy.  [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Cheese', 'Mustard', 'Vegan Mayo'], 'name': 'Vegan Burger'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Crispy', 'Onion Rings', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Teriyaki', 'Garlic Soy'], 'name': 'Vegetable Stir-fry'}]                                                                                                                                                                                                                                                            [{'customizations': ['BBQ', 'Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Peanut Sauce', 'Chili Lime'], 'name': 'Grilled Tofu'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Onion Rings', 'Crispy', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Garlic Butter', 'BBQ'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Teriyaki', 'Garlic Soy'], 'name': 'Extra Sauce'}]    0.601611
# 36                                                                                                                                                                                                                                                                               Can I get an extra ice cream scoop, extra toppings with nuts and chocolate chips, a lemonade, extra gravy, miso soup with toasted sesame seeds and chili oil, cream of mushroom with chopped parsley and truffle oil, an apple pie, grilled tofu with soy ginger, and both unsweetened and sweetened iced tea?                                                                                                                                                 [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}]                                                                                                                      [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Gravy'], 'name': 'Extra Sauce'}, {'customizations': ['Toasted Sesame Seeds', 'Chili Oil'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Cream of Mushroom'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}]    0.759243
# 39                                                                                                                                                                                                                                                                                                                                          I'll have a vanilla and cheesecake, a fruit salad with nuts as an extra topping, chicken soup with fresh parsley and a lemon wedge, apple crumble, mozzarella sticks with marinara and ranch, unsweetened iced tea, and an extra bun or bread roll.                                                                                                                                                                                                                [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                           [{'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Nuts'], 'name': 'Extra Topping'}, {'customizations': ['Chicken Soup', 'Fresh Parsley', 'Lemon Wedge'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Marinara', 'Ranch'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.508403
# 43                                                                                                                                                                                                                 Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                                                                  [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                            [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.068433
# 44                                                                                                                                                                                                                                              I'll have a pale ale, a lemonade, an apple pie with extra toppings of berries, nuts, and chocolate chips, a shrimp cocktail with spicy cocktail sauce, extra dipping sauces of blue cheese and ranch, tomato soup with basil pesto and croutons, milk alternatives of almond milk and oat milk, an extra scoop of ice cream, and a fruit salad.                                                                                      [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]                                                                                                              [{'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Basil Pesto', 'Croutons'], 'name': 'Extra Topping'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Fruit Salad'}]    0.697436
# 46                                                                                                                                                                                                                                                                                  Extra shot of whiskey, Caesar salad with grilled shrimp and grilled chicken, miso soup with chili oil, chicken soup with fresh parsley, vanilla flavored syrups, extra dipping sauces of ranch and blue cheese, extra whipped cream, fruit salad, shrimp cocktail with spicy cocktail sauce and lemon herb.                                                                                                                [{'customizations': ['Whiskey'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}]                                                                                                                                 [{'customizations': ['Extra Shot of Whiskey', 'Rum'], 'name': 'Cocktails'}, {'customizations': ['Grilled Shrimp', 'No Protein', 'Grilled Chicken'], 'name': 'Caesar Salad'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': ['Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}]    0.082892
# 49                                                                                                                I'll have some oat milk, shrimp cocktail with lemon herb and spicy cocktail sauce, a margarita and a mojito. For craft beer, Iâ€™ll go with a lager and an IPA. A side of strawberries, spicy coleslaw, and fish and chips that are extra crispy with onion rings sounds great. Iâ€™ll also take a Caesar salad with no protein and grilled shrimp, plus an extra side of fries, rice, and mashed potatoes. And letâ€™s add some fresh juices, specifically carrot and apple.                                             [{'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}]                                                                                                                                                                                                                [{'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Lager', 'Mojito'], 'name': 'Craft Beer'}, {'customizations': ['Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}]    0.496416
# 81                                                                                                Want to order some Spring Rolls with chicken and vegetarian options, a couple of Craft Beers in lager and IPA, and some Extra Sauce with gravy and pesto. Don't forget the Fresh Juices, we'll go with apple and carrot, and a Garden Salad with vinaigrette and balsamic dressing. For drinks, letâ€™s have Iced Tea, half sweetened and half unsweetened. For dessert, Iâ€™ll take a Cheesecake and a Lemon Meringue Pie. Also, throw in an Extra Bun or Bread Roll and some Extra Cheese.                                                                                                          [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                           [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Extra Salad Dressing'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.542254
# 83                                                                                                        I'll have oat milk and almond milk for the milk alternatives, a selection of IPA, lager, and pale ale for the craft beer, and I'll need BBQ sauce and pesto for the extra sauce. For my iced tea, I want it sweetened. Add fish and chips with fries to the order. I'll also have mojito, margarita, and old fashioned cocktails. For dessert, a berry parfait sounds good. I want some cream of mushroom with chopped parsley and chicken soup with fresh parsley and a lemon wedge.                               [{'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}]            [{'customizations': ['Oat Milk', 'Almond Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['IPA', 'Lager', 'Pale Ale'], 'name': 'Craft Beer'}, {'customizations': ['BBQ Sauce', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Fish and Chips', 'Fries'], 'name': 'Extra Side'}, {'customizations': ['Mojito', 'Margarita', 'Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.466819
# 92                                                                                                                                                                                   Ordering tomato soup with cheddar cheese, basil pesto, and croutons. I want extra toppings with nuts, berries, and chocolate chips. Also including apple crumble and an extra shot of vodka. For the side, I'll have fruit salad and Greek salad with grilled chicken and no protein. And let's add milk alternatives with almond milk and oat milk. Finally, a side of coleslaw with both mild and spicy.                                                                                                                         [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                            [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Fruit Salad'], 'name': 'Extra Side'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Coleslaw', 'Mild', 'Spicy'], 'name': 'Extra Sauce'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Shot of Alcohol'}]    0.669959
# 109                                                                                                                      Ordering a Chicken Soup with a lemon wedge and fresh parsley, onion rings with ranch and BBQ sauce, an extra dipping sauce of blue cheese and ranch, fresh juices with carrot, apple, and orange, a Greek salad topped with falafel and grilled chicken, a slice of chocolate cake, an extra scoop of ice cream, craft beer with both lager and IPA, fish and chips crispy with onion rings and fries, and a shrimp cocktail with lemon herb and spicy cocktail sauce.                  [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}]                                          [{'customizations': ['Lemon Wedge', 'Fresh Parsley'], 'name': 'Chicken Soup'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Blue Cheese', 'Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Carrot', 'Apple', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Falafel', 'Grilled Chicken'], 'name': 'Extra Protein'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Crispy', 'Onion Rings', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}]    0.530864
# 110                                                                                                                                                                                                                                                   Grilled Salmon with Lemon Dill, an extra scoop of ice cream, strawberry flavor, Grilled Chicken Breast with BBQ, Miso Soup with chili oil and toasted sesame seeds, Mint Chocolate Chip, extra toppings of berries and nuts, a slice of Lemon Meringue Pie, vanilla ice cream, and spring rolls with both vegetarian and chicken options.                                                                                                                     [{'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['BBQ'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Chili Oil', 'Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Berries', 'Nuts'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                None    0.000000
# 113                                                                                                     I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                                                                 [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                                  [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.488235
# 118                                                                                                                                                                          Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.                                                    [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                        [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.352840

# %% [markdown]
# ### **Small 4b Model, Large Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-small-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-small-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [00:57<00:00, 14.44s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9248
# ✅ Exact Match Accuracy: 40.83%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          predicted_items  similarity
# 6                                                                                                                                                                              Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                          [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                       [{'customizations': ['Extra Whipped Cream'], 'name': 'Extra Topping'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.133874
# 12                                                                                                                                           One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                     [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]                                                                                        [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.703959
# 20                                                                                                                                      I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                          [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                         [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.660674
# 22                                                                                                                                                                                                                                                                                               Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                      [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 43                                                                                                              Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.067265
# 75                                                                                                                                                   Ordering an extra scoop of ice cream, with extra dipping sauces of ranch and blue cheese. I'll have the fish and chips crispy, vanilla ice cream, and chicken soup with fresh parsley and a lemon wedge. A berry parfait on the side, along with a lemonade. For drinks, I'll take red and rose wine, and finish off with a cheesecake.                                                                     [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': [], 'name': 'Cheesecake'}]                                                                                                                                                            [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Fresh Parsley', 'Lemon Wedge'], 'name': 'Chicken Soup'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Red Wine'}, {'customizations': [], 'name': 'Rose Wine'}, {'customizations': [], 'name': 'Cheesecake'}]    0.774500
# 92                                                                                Ordering tomato soup with cheddar cheese, basil pesto, and croutons. I want extra toppings with nuts, berries, and chocolate chips. Also including apple crumble and an extra shot of vodka. For the side, I'll have fruit salad and Greek salad with grilled chicken and no protein. And let's add milk alternatives with almond milk and oat milk. Finally, a side of coleslaw with both mild and spicy.                                                                       [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                                                                                                                                                                                                             [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Vodka'], 'name': 'Extra Shot'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]    0.719524
# 113  I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                               [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                            [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red', 'Pale Ale', 'IPA'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.505584
# 118                                                                       Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.  [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                           [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Orange', 'Lager'], 'name': 'Craft Beer'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.249548
# 119                                Ordering vegetarian spring rolls and miso soup with toasted sesame seeds. I'll also need extra dipping sauces of ranch and blue cheese, along with onion rings and ranch on the side. A vegan burger comes with no cheese, ketchup, mustard, vegan mayo, and vegan cheese. Add cream of mushroom soup with chopped parsley and truffle oil, followed by a slice of chocolate cake. Lastly, include extra pesto sauce. Two chocolate bars for dessert too.                                                             [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Chopped Parsley', 'Truffle Oil'], 'name': 'Cream of Mushroom'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}]  [{'customizations': ['Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Miso Soup', 'Toasted Sesame Seeds'], 'name': 'Soup'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Onion Rings', 'Ranch'], 'name': 'Extra Sauce'}, {'customizations': ['No Cheese', 'Ketchup', 'Mustard', 'Vegan Mayo', 'Vegan Cheese'], 'name': 'Vegan Burger'}, {'customizations': ['Cream of Mushroom', 'Chopped Parsley', 'Truffle Oil'], 'name': 'Extra Soup'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Pesto'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Chocolate'}, {'customizations': [], 'name': 'Extra Chocolate Bar'}]    0.628619

# %% [markdown]
# ### **Medium 4b Model, Large Dataset**

# %%
# ISSUE - RESOLVED

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-4b-it"
adapter_model_id = "iTzMiNOS/gemma-3-4b-it-medium-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-4b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-4b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-4b-it-medium-json-16bit) onto the base model...
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:04<00:00, 16.06s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9212
# ✅ Exact Match Accuracy: 45.83%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            predicted_items  similarity
# 6                                                                                                                                                                                    Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                                                                           [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                                                                                                                                                                                                                                                                                 [{'customizations': ['Extra Whipped Cream'], 'name': 'Drink'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.104294
# 12                                                                                                                                                 One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                                                                      [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]                                                                                                                                                                                                                                          [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.703959
# 20                                                                                                                                            I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                                                                           [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                                                                                                                                                                                                                                                            [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.722401
# 22                                                                                                                                                                                                                                                                                                     Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                                                                       [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 23      I'll have a Craft Beer IPA, a mix of Vegetarian and Chicken Spring Rolls, Coleslaw with both Mild and Spicy, Onion Rings with Ranch and BBQ sauces, Vegetable Stir-fry with Garlic Soy, Teriyaki, and Peanut Sauce, a Cream of Mushroom topped with Chopped Parsley, Extra Dipping Sauces of Ranch and Blue Cheese, a slice of Chocolate Cake, Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, and a Caesar Salad without protein, plus both Grilled Shrimp and Grilled Chicken.  [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]                                                      [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Cream of Mushroom'}, {'customizations': ['Chopped Parsley'], 'name': 'Extra Topping'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': [], 'name': 'Caesar Salad'}, {'customizations': ['Grilled Shrimp', 'Grilled Chicken'], 'name': 'Protein'}]    0.586972
# 32                                                                                                                                                I'll have a pizza with extra cheese, some cocktails with an Old Fashioned, a scoop of vanilla, a plate of vegetarian and chicken spring rolls, a bowl of tomato soup with basil pesto, croutons, and cheddar cheese, a cup of miso soup with chili oil, a slice of apple pie, and a garden salad with vinaigrette, balsamic, and ranch dressing.                                                                                                                                                                                                                          [{'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                                                                                                                              [{'customizations': ['Extra Cheese'], 'name': 'Pizza'}, {'customizations': ['Old Fashioned', 'Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Basil Pesto', 'Croutons', 'Cheddar Cheese'], 'name': 'Tomato Soup'}, {'customizations': ['Chili Oil'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]    0.162791
# 43                                                                                                                    Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                                                                 [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                                                                                                                   [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.068433
# 49                   I'll have some oat milk, shrimp cocktail with lemon herb and spicy cocktail sauce, a margarita and a mojito. For craft beer, Iâ€™ll go with a lager and an IPA. A side of strawberries, spicy coleslaw, and fish and chips that are extra crispy with onion rings sounds great. Iâ€™ll also take a Caesar salad with no protein and grilled shrimp, plus an extra side of fries, rice, and mashed potatoes. And letâ€™s add some fresh juices, specifically carrot and apple.                                            [{'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Extra Crispy', 'Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}]  [{'customizations': ['Oat Milk'], 'name': 'Milk'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Margarita', 'Mojito'], 'name': 'Cocktails'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Crispy', 'Onion Rings', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['No Protein', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Fries', 'Rice', 'Mashed Potatoes'], 'name': 'Extra Side'}, {'customizations': ['Carrot', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Berries', 'Nuts', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': ['Whiskey', 'Rum', 'Vodka'], 'name': 'Extra Shot of Alcohol'}]    0.452211
# 81   Want to order some Spring Rolls with chicken and vegetarian options, a couple of Craft Beers in lager and IPA, and some Extra Sauce with gravy and pesto. Don't forget the Fresh Juices, we'll go with apple and carrot, and a Garden Salad with vinaigrette and balsamic dressing. For drinks, letâ€™s have Iced Tea, half sweetened and half unsweetened. For dessert, Iâ€™ll take a Cheesecake and a Lemon Meringue Pie. Also, throw in an Extra Bun or Bread Roll and some Extra Cheese.                                                                                                         [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Unsweetened', 'Sweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Cheese'}]                                                                                                                                                                                                                                          [{'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Gravy', 'Pesto'], 'name': 'Extra Sauce'}, {'customizations': ['Vinaigrette', 'Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': [], 'name': 'Cheesecake'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Extra Cheese'}]    0.778369
# 89                                                                                                                                                                                                                  I'll have chicken wings with BBQ sauce, sweetened iced tea, apple and carrot fresh juice, a lemonade, a strawberry, and a vanilla. For the food, I want a fruit salad, a Greek salad with falafel and no protein, crispy fish and chips, and an extra side of mashed potatoes.                                                                                                                                                                        [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Sweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]                                                                                                                                                                                                                                                                                                                          [{'customizations': ['BBQ'], 'name': 'Chicken Wings'}, {'customizations': ['Sweetened', 'Unsweetened'], 'name': 'Iced Tea'}, {'customizations': ['Apple', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Strawberry'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Falafel', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Crispy', 'Extra Crispy'], 'name': 'Fish and Chips'}, {'customizations': ['Mashed Potatoes'], 'name': 'Extra Side'}]    0.768612
# 113        I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                                                                [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                                                                                                  [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.485380
# 118                                                                             Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.                                                   [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                                                                                                                                                      [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'Rose'], 'name': 'Wine'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.347386

# %% [markdown]
# ### **Small 12b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-small-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-small-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:30<00:00, 22.51s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9314
# ✅ Exact Match Accuracy: 49.17%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    predicted_items  similarity
# 6                                                                                                                                                                              Can I get a drink with extra whipped cream, a grilled tofu dish with soy ginger, chili lime, and peanut sauce, a Coke, and an extra scoop of ice cream? Also, I'll have miso soup with toasted sesame seeds, a grilled chicken breast with garlic butter, a berry parfait, and mint chocolate chip ice cream.                                                                                                                          [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]                                                                                           [{'customizations': ['Extra Whipped Cream'], 'name': 'Extra Whipped Cream'}, {'customizations': ['Soy Ginger', 'Chili Lime', 'Peanut Sauce'], 'name': 'Grilled Tofu'}, {'customizations': ['Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': [], 'name': 'Berry Parfait'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}]    0.135081
# 11                                                                                                                                                                                                       I'll have a chocolate cake, mint chocolate chip ice cream, chicken and vegetarian spring rolls, an extra bun, apple crumble, a Greek salad with grilled chicken, fish and chips with onion rings, grilled tofu with soy ginger, spicy shrimp cocktail, and an unsweetened iced tea.                                                       [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': ['Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]    [{'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Chicken', 'Vegetarian'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Grilled Chicken', 'Fish', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': ['Onion Rings'], 'name': 'Fish and Chips'}, {'customizations': ['Soy Ginger'], 'name': 'Grilled Tofu'}, {'customizations': [], 'name': 'Spicy Shrimp Cocktail'}, {'customizations': ['Unsweetened'], 'name': 'Iced Tea'}]    0.667255
# 12                                                                                                                                           One chocolate with caramel and vanilla flavored syrups, almond milk and oat milk for the milk alternatives, extra cheese, vegetarian and chicken spring rolls, an apple pie, a Greek salad with grilled chicken, no protein, and falafel, extra whipped cream, vanilla, and a vegan burger with vegan mayo, vegan cheese, mustard, and ketchup.                     [{'customizations': [], 'name': 'Chocolate'}, {'customizations': ['Caramel', 'Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]  [{'customizations': ['Caramel', 'Vanilla'], 'name': 'Chocolate'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': ['Grilled Chicken', 'No Protein', 'Falafel'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Vegan Mayo', 'Vegan Cheese', 'Mustard', 'Ketchup'], 'name': 'Vegan Burger'}]    0.703959
# 20                                                                                                                                      I want a vegan burger with no cheese, vegan cheese, mustard, vegan mayo, and ketchup. Also, add an extra side of BBQ sauce. I'd like a fruit salad, a wine selection of red and white, and a scoop of vanilla ice cream. For salads, include a Caesar with grilled chicken and grilled shrimp. Lastly, add some miso soup with toasted sesame seeds.                                                                                                                          [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['White', 'Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp', 'No Protein'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}]                                                                                                                                                    [{'customizations': ['No Cheese', 'Vegan Cheese', 'Mustard', 'Vegan Mayo', 'Ketchup'], 'name': 'Vegan Burger'}, {'customizations': ['BBQ Sauce'], 'name': 'Extra Sauce'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Red', 'White'], 'name': 'Wine'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Grilled Chicken', 'Grilled Shrimp'], 'name': 'Caesar Salad'}, {'customizations': ['Toasted Sesame Seeds'], 'name': 'Miso Soup'}]    0.722401
# 22                                                                                                                                                                                                                                                                                               Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                      [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                        [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 43                                                                                                              Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                           [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.068433
# 53                                                                                                                                                                                                  Can I get an extra ice cream scoop, some oat milk for the milk alternatives, a Greek salad with grilled chicken, fish and chips extra crispy with fries, extra cheese on the side, a serving of mozzarella sticks with marinara, an extra ranch dipping sauce, and a fresh orange juice?                                                                                                                                                                        [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken'], 'name': 'Greek Salad'}, {'customizations': ['Extra Crispy', 'Fries', 'Crispy'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]                                                                                                           [{'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'Fish'], 'name': 'Greek Salad'}, {'customizations': ['Crispy', 'Extra Crispy', 'Fries'], 'name': 'Fish and Chips'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Marinara'], 'name': 'Mozzarella Sticks'}, {'customizations': ['Ranch'], 'name': 'Extra Dipping Sauce'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}]    0.362272
# 92                                                                                Ordering tomato soup with cheddar cheese, basil pesto, and croutons. I want extra toppings with nuts, berries, and chocolate chips. Also including apple crumble and an extra shot of vodka. For the side, I'll have fruit salad and Greek salad with grilled chicken and no protein. And let's add milk alternatives with almond milk and oat milk. Finally, a side of coleslaw with both mild and spicy.                                                                       [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': [], 'name': 'Fruit Salad'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Grilled Chicken', 'No Protein'], 'name': 'Greek Salad'}, {'customizations': [], 'name': 'Vanilla'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]                                                                             [{'customizations': ['Cheddar Cheese', 'Basil Pesto', 'Croutons'], 'name': 'Tomato Soup'}, {'customizations': ['Nuts', 'Berries', 'Chocolate Chips'], 'name': 'Extra Topping'}, {'customizations': [], 'name': 'Apple Crumble'}, {'customizations': ['Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Fruit Salad', 'Greek Salad with Grilled Chicken', 'No Protein'], 'name': 'Extra Side'}, {'customizations': ['Almond Milk', 'Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}]    0.582857
# 113  I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                               [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                          [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.485380
# 118                                                                       Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.  [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                          [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red Wine', 'Orange Juice', 'Craft Lager'], 'name': 'Beverages'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}]    0.222023

# %% [markdown]
# ### **Medium 12b Model, Large Dataset**

# %%
# Cell: Inference and Evaluation (Batched & GPU Ensured & Fence Cleaning)

import json
import pandas as pd
from datasets import Dataset
from transformers import (
    pipeline,
    AutoModelForCausalLM,
    AutoTokenizer,
    logging
)
from peft import PeftModel
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from difflib import SequenceMatcher
import torch
import gc
import os
import math
import numpy as np
import re # Import regex for cleaning fences

# --- Configuration ---
base_model_id = "google/gemma-3-12b-it"
adapter_model_id = "iTzMiNOS/gemma-3-12b-it-medium-json-16bit"
prefix = """Convert the following food order into JSON format using this structure:
[
  { "customizations": ["Customization 1", "Customization 2"], "name": "Item Name" },
  { "customizations": [], "name": "Another Item" }
]:
"""
inference_batch_size = 32

if not torch.cuda.is_available():
     raise SystemError("CUDA is not available. This script requires a GPU.")
else:
     device_name = torch.cuda.get_device_name(0)
     print(f"CUDA is available. Using GPU: {device_name}")
     if torch.cuda.get_device_capability(0)[0] >= 8:
         print("GPU supports bfloat16, using torch.bfloat16 for inference.")
         model_dtype_inference = torch.bfloat16
     else:
         print("GPU does not support bfloat16, using torch.float16 for inference.")
         model_dtype_inference = torch.float16
     device = 0

# --- Memory Cleanup ---
print("Cleaning up memory before loading...")
gc.collect()
torch.cuda.empty_cache()
print("CUDA cache cleared.")

# --- Load Tokenizer ---
print(f"Loading tokenizer from {base_model_id}...")
tokenizer = AutoTokenizer.from_pretrained(base_model_id, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
eos_token = tokenizer.eos_token
assert tokenizer.pad_token_id is not None, "Tokenizer pad_token_id is not set!"
print("Tokenizer loaded.")

# --- Load Base Model ---
print(f"Loading base model ({base_model_id}) in {model_dtype_inference}")
model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    torch_dtype=model_dtype_inference,
    device_map="auto",
    trust_remote_code=True,
)
print(f"Base model loaded. Device map: {model.hf_device_map}")

# --- Load LoRA Adapter ---
print(f"Loading LoRA adapter ({adapter_model_id}) onto the base model...")
try:
    model = PeftModel.from_pretrained(model, adapter_model_id)
    print("LoRA adapter loaded successfully.")
    print("Attempting to merge LoRA adapter...")
    try:
        model = model.merge_and_unload()
        print("LoRA adapter merged successfully.")
    except Exception as e:
        print(f"⚠️ Could not merge LoRA adapter: {e}. Proceeding with PEFT model.")
except Exception as e:
     print(f"❌ Failed to load LoRA adapter: {e}")
     raise e

# --- Build the Inference Pipeline ---
logging.set_verbosity(logging.CRITICAL)
print("Building text-generation pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
if hasattr(pipe, 'device'): print(f"Pipeline device: {pipe.device}")
else: print("Pipeline device managed by model's device_map.")

# --- Load Validation Data ---
if 'validation_data' not in globals():
     print("validation_data not found, attempting reload...")
     from datasets import load_dataset
     dataset_id = "iTzMiNOS/voice-orders-small-clean-12k"
     split_name = "train"
     dataset = load_dataset(dataset_id, split=split_name)
     columns_to_keep = ["transcribed_text", "items", "speaker"]
     dataset = dataset.remove_columns([col for col in dataset.column_names if col not in columns_to_keep])
     dataset = dataset.select(range(min(1200, len(dataset))))
     train_val_split = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)
     validation_data = train_val_split['test']
     print("Reloaded and split dataset.")

df = validation_data.to_pandas()
print(f"Loaded validation data with {len(df)} rows.")

# --- Convert Numpy arrays in 'items' column ---
def deep_convert(obj):
    if isinstance(obj, dict):
        return {k: deep_convert(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [deep_convert(v) for v in obj]
    elif isinstance(obj, np.ndarray):
        return deep_convert(obj.tolist())
    else:
        return obj

df['items'] = df['items'].apply(deep_convert)
print("Conversion complete.")


# --- ***** UPDATED: Function for Robust JSON Parsing (Handles Fences) ***** ---
def parse_json_robustly(generated_text):
    """Attempts to extract and parse JSON, handling optional markdown fences."""
    json_str = None
    try:
        # Find the start of the first list or object
        first_bracket = generated_text.find('[')
        first_brace = generated_text.find('{')

        start_index = -1
        if first_bracket != -1 and (first_brace == -1 or first_bracket < first_brace):
            start_index = first_bracket
            start_char = '['
            end_char = ']'
        elif first_brace != -1:
            start_index = first_brace
            start_char = '{'
            end_char = '}'
        else:
             # Neither bracket nor brace found - maybe it's ONLY fences?
             # Try finding fences directly if no brace/bracket
             fence_match = re.search(r"`{3}(json)?\s*([\[\{])", generated_text)
             if fence_match:
                 start_index = fence_match.end() -1 # Start at the brace/bracket
                 start_char = fence_match.group(2)
                 end_char = ']' if start_char == '[' else '}'
             else:
                # Give up if no structure found
                # print(f"Debug: No JSON start ('[' or '{{') found. Output: {generated_text}")
                return None

        # Find the corresponding closing character using balancing
        open_count = 0
        end_index = -1
        # Check if start_index is valid before proceeding
        if start_index >= 0 and start_index < len(generated_text):
            for i in range(start_index, len(generated_text)):
                if generated_text[i] == start_char:
                    open_count += 1
                elif generated_text[i] == end_char:
                    open_count -= 1
                if open_count == 0:
                    end_index = i
                    break
        else:
             # Handle invalid start_index if fence logic above failed unusually
             print(f"Debug: Invalid start_index {start_index}. Output: {generated_text}")
             return None


        if end_index == -1:
            # print(f"Debug: No matching closing bracket/brace. Output: {generated_text}")
            return None

        # Extract the potential JSON substring
        json_str = generated_text[start_index : end_index + 1]

        # Clean leading/trailing whitespace that might remain
        json_str = json_str.strip()

        # --- Attempt to parse the extracted & cleaned string ---
        json_data = json.loads(json_str)
        return json_data

    except json.JSONDecodeError as e:
        # Add logging for parse failures, include the string attempted
        print(f"Warning: Could not parse JSON: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
    except Exception as e:
        # Catch any other unexpected errors during parsing
        print(f"Warning: Unexpected error during JSON parsing: {e}.")
        print(f"Attempted to parse (after extraction): '{json_str}'")
        # print(f"Original Generated Text: {generated_text}") # Uncomment for deeper debugging
        return None
# --- End Updated Function ---


# --- Apply Inference with Batching (Unchanged) ---
print(f"Running batched inference (batch size: {inference_batch_size})...")
all_prompts = [f"{prefix}{text}" for text in df['transcribed_text']]
all_results = []
num_batches = math.ceil(len(all_prompts) / inference_batch_size)
for i in tqdm(range(0, len(all_prompts), inference_batch_size), desc="Inference Batches", total=num_batches):
    batch_prompts = all_prompts[i:i+inference_batch_size]
    try:
        batch_outputs = pipe(batch_prompts, max_new_tokens=500, return_full_text=False, pad_token_id=tokenizer.eos_token_id, batch_size=len(batch_prompts))
        for output_list in batch_outputs:
            if output_list and isinstance(output_list, list):
                 generated_text = output_list[0]["generated_text"].strip()
                 parsed_json = parse_json_robustly(generated_text) # Use updated parser
                 all_results.append(parsed_json)
            else: print(f"Warning: Unexpected output format: {output_list}"); all_results.append(None)
    except Exception as e:
        print(f"\n--- ERROR during batch {i // inference_batch_size + 1} --- Error: {e}")
        all_results.extend([None] * len(batch_prompts))
if len(all_results) != len(all_prompts):
     print(f"Warning: Result count mismatch! Padding with None.")
     all_results.extend([None] * (len(all_prompts) - len(all_results)))
df['predicted_items'] = all_results
print("Inference complete.")

def to_lower(obj):
    if isinstance(obj, str):
        return obj.lower()  # Convert strings to lowercase
    elif isinstance(obj, dict):
        return {k: to_lower(v) for k, v in obj.items()}  # Apply recursively for dictionaries
    elif isinstance(obj, list):
        return [to_lower(v) for v in obj]  # Apply recursively for lists
    else:
        return obj

# --- Comparison Metric (Unchanged) ---
def similarity_score(pred, target):
    if pred is None or target is None:
        return 0.0
    try:
        # Convert both the prediction and target to lowercase
        pred = to_lower(pred)
        target = to_lower(target)

        # Convert the structures into strings
        pred_str = json.dumps(pred, sort_keys=True, separators=(',', ':'))
        target_str = json.dumps(target, sort_keys=True, separators=(',', ':'))

        return SequenceMatcher(None, pred_str, target_str).ratio()
    except Exception as e:
        print(f"Error calculating similarity: Pred={pred}, Target={target}, Error={e}")
        return 0.0
# --- Calculate Metrics (Unchanged) ---
print("Calculating metrics...")
df['similarity'] = df.apply(lambda row: similarity_score(row['predicted_items'], row['items']), axis=1)
df['exact_match'] = df.apply(lambda row:
                             row['predicted_items'] is not None and
                             row['items'] is not None and
                             to_lower(row['predicted_items']) == to_lower(row['items']),
                             axis=1)

average_similarity = df['similarity'].mean()
exact_match_accuracy = df['exact_match'].mean()

print("\n--- Evaluation Results ---")
print(f"🔍 Average Similarity Score: {average_similarity:.4f}")
print(f"✅ Exact Match Accuracy: {exact_match_accuracy:.2%}")

# --- Display Mismatches (Unchanged) ---
print("\n--- Low Similarity Examples (< 0.8) ---")
low_sim_df = df[df['similarity'] < 0.8][['transcribed_text', 'items', 'predicted_items', 'similarity']]
print(low_sim_df.to_string())
# Out:
# CUDA is available. Using GPU: NVIDIA A100-SXM4-40GB
# GPU supports bfloat16, using torch.bfloat16 for inference.
# Cleaning up memory before loading...
# CUDA cache cleared.
# Loading tokenizer from google/gemma-3-12b-it...
# Tokenizer loaded.
# Loading base model (google/gemma-3-12b-it) in torch.bfloat16
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Base model loaded. Device map: {'': 0}
# Loading LoRA adapter (iTzMiNOS/gemma-3-12b-it-medium-json-16bit) onto the base model...
# adapter_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# LoRA adapter loaded successfully.
# Attempting to merge LoRA adapter...
# LoRA adapter merged successfully.
# Building text-generation pipeline...
# Pipeline device: cuda:0
# Loaded validation data with 120 rows.
# Conversion complete.
# Running batched inference (batch size: 32)...
# Inference Batches: 100%|██████████| 4/4 [01:33<00:00, 23.41s/it]
# Inference complete.
# Calculating metrics...
#
# --- Evaluation Results ---
# 🔍 Average Similarity Score: 0.9455
# ✅ Exact Match Accuracy: 53.33%
#
# --- Low Similarity Examples (< 0.8) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                transcribed_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           predicted_items  similarity
# 22                                                                                                                                                                                                                                                                                                  Could I get a Sprite, an Old Fashioned cocktail, a Mojito, and a Lemon Meringue Pie? Also, please include an extra ice cream scoop, extra cheese, and some oat milk as a milk alternative.                                                                                                                                                                                                                                                       [{'customizations': ['Sprite', 'Coke', 'Fanta'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Lemonade'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]                                                                                                                                                                                                                                                                                                                                                                                                                               [{'customizations': ['Sprite'], 'name': 'Soft Drinks'}, {'customizations': ['Old Fashioned', 'Mojito'], 'name': 'Cocktails'}, {'customizations': [], 'name': 'Lemon Meringue Pie'}, {'customizations': [], 'name': 'Extra Ice Cream Scoop'}, {'customizations': [], 'name': 'Extra Cheese'}, {'customizations': ['Oat Milk'], 'name': 'Milk Alternatives'}]    0.494709
# 23   I'll have a Craft Beer IPA, a mix of Vegetarian and Chicken Spring Rolls, Coleslaw with both Mild and Spicy, Onion Rings with Ranch and BBQ sauces, Vegetable Stir-fry with Garlic Soy, Teriyaki, and Peanut Sauce, a Cream of Mushroom topped with Chopped Parsley, Extra Dipping Sauces of Ranch and Blue Cheese, a slice of Chocolate Cake, Shrimp Cocktail with Lemon Herb and Spicy Cocktail sauce, and a Caesar Salad without protein, plus both Grilled Shrimp and Grilled Chicken.  [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]  [{'customizations': ['IPA'], 'name': 'Craft Beer'}, {'customizations': ['Vegetarian', 'Chicken'], 'name': 'Spring Rolls'}, {'customizations': ['Mild', 'Spicy'], 'name': 'Coleslaw'}, {'customizations': ['Ranch', 'BBQ'], 'name': 'Onion Rings'}, {'customizations': ['Garlic Soy', 'Teriyaki', 'Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': [], 'name': 'Cream of Mushroom'}, {'customizations': ['Chopped Parsley'], 'name': 'Extra Topping'}, {'customizations': ['Ranch', 'Blue Cheese'], 'name': 'Extra Dipping Sauce'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': ['Lemon Herb', 'Spicy Cocktail'], 'name': 'Shrimp Cocktail'}, {'customizations': ['No Protein', 'Grilled Shrimp', 'Grilled Chicken'], 'name': 'Caesar Salad'}]    0.564551
# 43                                                                                                                 Can I get a vegan burger with mustard, a side of onion rings with ranch, and some coleslaw that's mild? Also, add an extra shot of whiskey and vodka, a couple of old fashioned cocktails, and fresh juices with apple, orange, and carrot. Lastly, Iâ€™ll take some soft drinks, specifically Fanta and Coke, and definitely donâ€™t forget the extra whipped cream on top.                                                                                                                                                                                                                                 [{'customizations': [], 'name': 'Extra Whipped Cream'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}]                                                                                                                                                                                                                                                                                  [{'customizations': ['Mustard'], 'name': 'Vegan Burger'}, {'customizations': ['Ranch'], 'name': 'Onion Rings'}, {'customizations': ['Mild'], 'name': 'Coleslaw'}, {'customizations': ['Whiskey', 'Vodka'], 'name': 'Extra Shot of Alcohol'}, {'customizations': ['Old Fashioned'], 'name': 'Cocktails'}, {'customizations': ['Apple', 'Orange', 'Carrot'], 'name': 'Fresh Juices'}, {'customizations': ['Fanta', 'Coke'], 'name': 'Soft Drinks'}, {'customizations': [], 'name': 'Extra Whipped Cream'}]    0.068433
# 113     I'll have a Mint Chocolate Chip and for the main course, please bring me a Grilled Salmon with Lemon Dill. I also want a Vegetable Stir-fry with Peanut Sauce, and let's add a Garden Salad with Vinaigrette, Balsamic, and Ranch on the side. To drink, I'd like a mix of Rose and Red wine, a Pale Ale, and an IPA craft beer. For dessert, I'll take an Apple Pie, and throw in an extra bun or bread roll as well. Finally, a mix of Carrot and Orange fresh juices would be great.                                                                                                                                                                [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}]                                                                                                                                                                                                                 [{'customizations': [], 'name': 'Mint Chocolate Chip'}, {'customizations': ['Lemon Dill'], 'name': 'Grilled Salmon'}, {'customizations': ['Peanut Sauce'], 'name': 'Vegetable Stir-fry'}, {'customizations': ['Vinaigrette', 'Balsamic', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Rose', 'Red'], 'name': 'Wine'}, {'customizations': ['Pale Ale', 'IPA'], 'name': 'Craft Beer'}, {'customizations': [], 'name': 'Apple Pie'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}, {'customizations': ['Carrot', 'Orange'], 'name': 'Fresh Juices'}]    0.485380
# 118                                                                          Ordering a Shrimp Cocktail with spicy cocktail and lemon herb. For beverages, I'll go with red wine, fresh orange juice, and a craft lager. Adding a bowl of cream of mushroom with chopped parsley, grilled chicken breast with garlic butter, and a garden salad with balsamic dressing. Also, I'll get some spicy and mild coleslaw, a vanilla flavored syrup, and to finish it off, a slice of chocolate cake.                                                   [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red', 'White', 'Rose'], 'name': 'Wine'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Orange', 'Apple'], 'name': 'Fresh Juices'}, {'customizations': ['Lager', 'IPA'], 'name': 'Craft Beer'}, {'customizations': ['Balsamic', 'Vinaigrette', 'Ranch'], 'name': 'Garden Salad'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': [], 'name': 'Chocolate Cake'}]                                                                                                  [{'customizations': ['Spicy Cocktail', 'Lemon Herb'], 'name': 'Shrimp Cocktail'}, {'customizations': ['Red'], 'name': 'Wine'}, {'customizations': ['Orange'], 'name': 'Fresh Juices'}, {'customizations': ['Lager'], 'name': 'Craft Beer'}, {'customizations': ['Chopped Parsley'], 'name': 'Cream of Mushroom'}, {'customizations': ['Garlic Butter'], 'name': 'Grilled Chicken Breast'}, {'customizations': ['Balsamic'], 'name': 'Garden Salad'}, {'customizations': ['Spicy', 'Mild'], 'name': 'Coleslaw'}, {'customizations': ['Vanilla'], 'name': 'Flavored Syrups'}, {'customizations': [], 'name': 'Chocolate Cake'}, {'customizations': [], 'name': 'Extra Bun or Bread Roll'}]    0.332253
